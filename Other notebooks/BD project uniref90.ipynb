# %%
# Point Colaboratory to your Google Drive

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
datapath = '/content/gdrive/My Drive/^DATA SCIENCE/^Biological Data/PROJECT/models/' # Luca
# datapath = '/content/gdrive/My Drive/Data Science - Unipd/II Year/I Semester/Biological Data/Project/PROJECT/models/' # Giuliano

# %% [markdown]
# # Building models

# %% [markdown]
# ## Ex 5: build a PSSM model

# %%
# ./binx/ncbi-blast-2.11.0+/bin/psiblast -in_msa ./PROJECT/clustal_omega_uniprot.fasta -db ./data/msa/uniprot_sprot.fasta -out ./PROJECT/output_psiblast_uniprot.out -out_pssm ./PROJECT/pssm_model_uniprot.pssm
# ./binx/ncbi-blast-2.11.0+/bin/psiblast -in_msa ./PROJECT/clustal_omega_uniref50.fasta -db ./data/msa/uniprot_sprot.fasta -out ./PROJECT/output_psiblast_uniref50.out -out_pssm ./PROJECT/pssm_model_uniref50.pssm
# ./binx/ncbi-blast-2.11.0+/bin/psiblast -in_msa ./PROJECT/clustal_omega_uniref90.fasta -db ./data/msa/uniprot_sprot.fasta -out ./PROJECT/output_psiblast_uniref90.out -out_pssm ./PROJECT/pssm_model_uniref90.pssm

# %% [markdown]
# ## Ex 6: build a HMM model

# %%
# ./binx/hmmer-3.3.1/src/hmmbuild ./PROJECT/hmm_model_uniprot.hmm ./PROJECT/clustal_omega_uniprot.fasta
# ./binx/hmmer-3.3.1/src/hmmbuild ./PROJECT/hmm_model_uniref50.hmm ./PROJECT/clustal_omega_uniref50.fasta
# ./binx/hmmer-3.3.1/src/hmmbuild ./PROJECT/hmm_model_uniref90.hmm ./PROJECT/clustal_omega_uniref90.fasta

# %% [markdown]
# ## Ex 7: find significant hits using HMM-SEARCH and PSI-BLAST

# %%
# hmmsearch --tblout ./PROJECT/hmm_search_uniprot.hmmer_tblout --domtblout ./PROJECT/hmm_search_uniprot.hmmer_domtblout ./PROJECT/hmm_model_uniprot.hmm ./data/msa/uniprot_sprot.fasta > ./PROJECT/hmm_search_uniprot.hmmer_align
# hmmsearch --tblout ./PROJECT/hmm_search_uniref50.hmmer_tblout --domtblout ./PROJECT/hmm_search_uniref50.hmmer_domtblout ./PROJECT/hmm_model_uniref50.hmm ./data/msa/uniprot_sprot.fasta > ./PROJECT/hmm_search_uniref50.hmmer_align
# hmmsearch --tblout ./PROJECT/hmm_search_uniref90.hmmer_tblout --domtblout ./PROJECT/hmm_search_uniref90.hmmer_domtblout ./PROJECT/hmm_model_uniref90.hmm ./data/msa/uniprot_sprot.fasta > ./PROJECT/hmm_search_uniref90.hmmer_align

# %%
# ./binx/ncbi-blast-2.11.0+/bin/psiblast -in_pssm ./PROJECT/pssm_model_uniprot.pssm -db ./data/msa/uniprot_sprot.fasta -outfmt 6 -num_iterations 4 -evalue 0.01 > ./PROJECT/psiblast_search_uniprot.txt
# ./binx/ncbi-blast-2.11.0+/bin/psiblast -in_pssm ./PROJECT/pssm_model_uniref50.pssm -db ./data/msa/uniprot_sprot.fasta -outfmt 6 -num_iterations 4 -evalue 0.01 > ./PROJECT/psiblast_search_uniref50.txt
# ./binx/ncbi-blast-2.11.0+/bin/psiblast -in_pssm ./PROJECT/pssm_model_uniref90.pssm -db ./data/msa/uniprot_sprot.fasta -outfmt 6 -num_iterations 4 -evalue 0.01 > ./PROJECT/psiblast_search_uniref90.txt

# %% [markdown]
# ## Ex 8

# %% [markdown]
# #### Read the ground truth file

# %%
# !pip install Bio
from Bio import SeqIO
# Out:
# Collecting Bio
#   Downloading https://files.pythonhosted.org/packages/83/ec/efbae4632107776961f4a1d3607117a4412b9e798609956c664e9c0157f4/bio-0.3.0-py3-none-any.whl (70kB)
#      |████████████████████████████████| 71kB 3.6MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from Bio) (2.23.0)
# Requirement already satisfied: pytest in /usr/local/lib/python3.6/dist-packages (from Bio) (3.6.4)
# Collecting biopython>=1.78
#   Downloading https://files.pythonhosted.org/packages/76/02/8b606c4aa92ff61b5eda71d23b499ab1de57d5e818be33f77b01a6f435a8/biopython-1.78-cp36-cp36m-manylinux1_x86_64.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 6.3MB/s
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->Bio) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->Bio) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->Bio) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->Bio) (2020.12.5)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from pytest->Bio) (1.10.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from pytest->Bio) (51.1.1)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from pytest->Bio) (8.6.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.6/dist-packages (from pytest->Bio) (0.7.1)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.6/dist-packages (from pytest->Bio) (1.4.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.6/dist-packages (from pytest->Bio) (20.3.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from pytest->Bio) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from biopython>=1.78->Bio) (1.19.5)
# Installing collected packages: biopython, Bio
# Successfully installed Bio-0.3.0 biopython-1.78

# %% [markdown]
# Find the proteins containing the target domain (PF08543) in:
# - SwissProt (annotated)
# - TrEMBLE (not annotated) ?????

# %% [markdown]
# Find the proteins containing the target domain (PF08543) in SwissProt -> set of actual positives

# %%
# !pip install Bio
# from Bio import SeqIO
path = datapath + 'protein-matching-PF08543.fasta'
protein_matching = SeqIO.parse(path,'fasta')

list_protein_containing_domain = []
for sequence in protein_matching:
    # print(sequence)
    name = sequence.id # name is in the form A1ADT5|reviewed|Pyridoxine/pyridoxal/pyridoxamine
    # print('name ->', name, '\n')
    list_protein_containing_domain.append(name.split('|')[0])

set_protein_containing_domain = set(list_protein_containing_domain) # this is the ground truth
print(f"Number of proteins in SwissProt containing the target domain: {len(list_protein_containing_domain)}")
# this is the total number of protein in SwissProt
print(f"Actual positives: {set_protein_containing_domain}")
# Out:
# Number of proteins in SwissProt containing the target domain: 150
# Actual positives: {'Q8W1X2', 'Q62LP6', 'P99124', 'B7M6S8', 'Q2L1P5', 'Q5PNC8', 'Q63SC2', 'A3N2D3', 'Q8CTQ7', 'Q5PIK8', 'Q8Z4W1', 'P9WG77', 'Q7WII1', 'Q9RYX0', 'Q6GEY2', 'P76422', 'Q7N3W7', 'B7V753', 'Q1I2L8', 'Q0BSF0', 'Q1J237', 'B2JCI0', 'Q1AYE5', 'Q6D5V1', 'Q9ZL00', 'P56904', 'Q57LS3', 'Q8NQH1', 'Q39I40', 'Q8D4Q2', 'Q8NVH3', 'A6VEZ4', 'Q8K183', 'P40191', 'Q51892', 'B0UUD2', 'O35331', 'Q83KY1', 'B7MY71', 'Q57688', 'Q1CIM6', 'P55882', 'Q1R8V2', 'Q48BL6', 'Q9CNY1', 'Q8ZPM8', 'Q7MGA4', 'A1ADT5', 'Q87FP6', 'P66915', 'Q0II59', 'Q8FTH8', 'Q320Z3', 'P44697', 'O94265', 'A5UA83', 'B1JFM7', 'Q57PI7', 'B7LCG3', 'Q3K4B8', 'Q52975', 'B0KR83', 'O25515', 'O74860', 'B1IX53', 'Q5HRG7', 'Q8Z6Q3', 'Q8FFB5', 'P44690', 'Q0TF48', 'O83153', 'O85786', 'O94266', 'Q141E8', 'Q06490', 'B7UGB9', 'B7LL66', 'Q0THJ1', 'O31620', 'Q5M731', 'B7MHS2', 'Q6G7L7', 'Q2SXQ4', 'Q88C26', 'Q1RBF9', 'P40192', 'B1XA89', 'O67772', 'P66914', 'B5YZW5', 'Q55EK9', 'Q6LP62', 'C4ZVU9', 'A7N5Q6', 'Q1BXQ7', 'Q5E345', 'Q65UE8', 'B6I4Z5', 'Q8FH89', 'O46560', 'A6VNE5', 'P39988', 'Q02DJ3', 'Q83K78', 'Q1LFU5', 'B3H2H2', 'Q4ZL75', 'A8A2R4', 'Q3Z1Z2', 'Q2QWK9', 'O48881', 'Q7VYK4', 'A7ZPL9', 'Q08224', 'Q7W6K7', 'Q87TZ6', 'Q08975', 'P39610', 'Q4K3F6', 'Q32FD7', 'Q8X649', 'A5WB73', 'Q3YZC3', 'B2TX08', 'Q6NG19', 'P53727', 'Q6AFC1', 'Q7CIR8', 'Q3JQA6', 'Q9HT57', 'Q9USL6', 'Q9ZBL1', 'P77150', 'P82197', 'B1LML3', 'Q32DD5', 'O00764', 'B7NPV5', 'Q9ZBR6', 'O14242', 'C3K4G7', 'Q9WZP7', 'Q5HI96', 'Q0I3D2', 'B7N609', 'P61422', 'Q1C792', 'Q66A50', 'Q8XBL0', 'P9WG76'}

# %% [markdown]
# Find all the proteins in the target database (uniprot_sprot.fasta) -> complete ground truth (actual positives + actual negatives)

# %%
path = datapath + 'uniprot_sprot.fasta'
all_sequences = SeqIO.parse(path, 'fasta')

list_all_sequences = []
for sequence in all_sequences:
    name = sequence.id # name is in the form sp|Q6GZX4|001R_FRG3G
    list_all_sequences.append(name.split('|')[1])

num_sequences = len(set(list_all_sequences))
print(f"Total number of proteins in SwissProt: {num_sequences}")
# Out:
# Total number of proteins in SwissProt: 563972

# %% [markdown]
# #### Read the output file of the psi-blast search

# %%
def read_psiblast(path):
    ''' Create a dictionary having as key the protein ID and as value the set of
    tuples (start, end) representing the position of our domain in that protein
    (we assume that the domain may be present in more than one position). '''
    
    positions = {}
    with open(path, 'r') as f:
        for line in f:
            if line:
                line = line.replace('|', ' ')
                (_, _, id, _, _, length, _, gapopen, _, _, 
                    start, end, evalue, bitscore) = line.split()
                    
                positions.setdefault(id, set()).add((start, end)) 
    return positions

# %%
path = datapath + 'psiblast_search_uniref90.txt'
positions_psiblast = read_psiblast(path)
print(f'Number of distint proteins found with psi-blast: {len(positions_psiblast)}')
# Out:
# Number of distint proteins found with psi-blast: 674

# %%
positions_psiblast
# Out:
# {'A0A0H2WZY4': {('162', '278')},
#  'A0AFC3': {('15', '247'), ('20', '244'), ('21', '244')},
#  'A0KPL4': {('124', '317'), ('189', '287')},
#  'A0KTG8': {('124', '295'), ('189', '287')},
#  'A0LP26': {('12', '247'), ('22', '244')},
#  'A0Q299': {('12', '240'), ('7', '246'), ('83', '237')},
#  'A0R980': {('13', '249'), ('27', '249'), ('63', '240')},
#  'A1A2J2': {('23', '276')},
#  'A1A6H3': {('243', '357')},
#  'A1ACX0': {('22', '255'), ('25', '252')},
#  'A1ADT5': {('14', '256'), ('14', '269'), ('18', '272')},
#  
#  'B0SE82': {('16', '254'), ('26', '258')},
#  'B0SMR8': {('16', '254'), ('26', '258')},
#  'B0TTF2': {('189', '287'), ('72', '297')},
#  'B0UUD2': {('1', '260'), ('2', '260'), ('54', '261'), ('74', '181')},
#  'B0V782': {('20', '260')},
#  'B0VM84': {('20', '260')},
#  'B1HX32': {('13', '248'), ('2', '248'), ('44', '224')},
#  'B1I1S3': {('11', '259')},
#  'B1IAN9': {('7', '251')},
#  'B1IAP6': {('13', '246')},
#  'B1IEG7': {('10', '244'), ('17', '238'), ('61', '230')},
#  'B1IHH3': {('3', '246')},
#  'B1IRR4': {('124', '287'), ('124', '295'), ('124', '311')},
#  'B1IX53': {('14', '256'), ('14', '269'), ('18', '272')},
#  'B1IYX7': {('22', '255'), ('25', '252')},
#  'B1J331': {('188', '286')},
#  'B1JFM7': {('4', '264'), ('60', '256')},
#  'B1JM26': {('124', '295')},
#  'B1KV13': {('10', '244'), ('17', '238'), ('61', '230')},
#  'B1KW01': {('3', '246')},
#  'B1LF43': {('124', '287'), ('124', '295'), ('124', '311')},
#  'B1LML3': {('14', '256'), ('14', '269'), ('18', '272')},
#  'B1LN84': {('22', '255'), ('25', '252')},
#  'B1MX61': {('3', '237')},
#  'B1X7J5': {('22', '255'), ('25', '252')},
#  'B1XA89': {('14', '256'), ('14', '269'), ('18', '272')},
#  'B1XG57': {('124', '287'), ('124', '295'), ('124', '311')},
#  'B1Y3E4': {('18', '241')},
#  'B1YJJ2': {('14', '246'), ('36', '238'), ('9', '246')},
#  'B2A1A8': {('17', '260'), ('28', '260'), ('83', '260')},
#  'B2G7Q2': {('14', '246'), ('25', '248'), ('75', '238')},
#  'B2GBV7': {('6', '248')},
#  'B2HTR5': {('20', '252')},
#  'B2IN99': {('7', '251')},
#  'B2INA6': {('2', '247')},
#  'B2JCI0': {('1', '260'), ('2', '260'), ('37', '260'), ('76', '180')},
#  'B2K2H4': {('124', '295')},
#  'B2TQ14': {('16', '258'), ('27', '245')},
#  'B2TX08': {('14', '256'), ('14', '269'), ('18', '272')},
#  'B2TY84': {('22', '255'), ('25', '252')},
#  'B2U1F7': {('124', '287'), ('124', '295'), ('124', '311')},
#  'B2UP55': {('18', '260')},
#  'B2USX2': {('94', '282')},
#  'B2USY3': {('16', '240'), ('19', '207'), ('5', '243')},
#  'B2UY66': {('16', '245'), ('16', '258')},
#  'B2VGJ9': {('121', '295'), ('122', '287')},
#  'B3DQ80': {('38', '297')},
#  'B3E5M9': {('73', '298'), ('73', '308')},
#  'B3H2H2': {('1', '260'), ('2', '260'), ('54', '261'), ('76', '181')},
#  'B3Q1Q5': {('1', '240')},
#  'B3QT42': {('14', '249'), ('25', '256')},
#  'B3W782': {('20', '247')},
#  'B4EW46': {('124', '295'), ('189', '287')},
#  'B4SXX8': {('15', '252'), ('19', '252')},
#  'B4T670': {('121', '295'), ('124', '311'), ('189', '287')},
#  'B4T9W1': {('15', '252'), ('19', '252')},
#  'B4TI51': {('121', '295'), ('124', '311'), ('189', '287')},
#  'B4TNK3': {('15', '252'), ('19', '252')},
#  'B4TVT4': {('121', '295'), ('124', '311'), ('189', '287')},
#  'B5BF36': {('15', '252'), ('19', '252')},
#  'B5BG11': {('121', '295'), ('124', '311'), ('189', '287')},
#  'B5E320': {('12', '251')},
#  'B5E327': {('13', '246')},
#  'B5EEZ1': {('173', '298'), ('74', '306')},
#  'B5ET96': {('10', '252'), ('11', '252')},
#  'B5EXY6': {('15', '252'), ('19', '252')},
#  'B5F696': {('121', '295'), ('124', '311'), ('189', '287')},
#  'B5FB67': {('123', '282'), ('189', '282')},
#  'B5FHT5': {('121', '295'), ('189', '287')},
#  'B5FMW2': {('15', '252'), ('19', '252')},
#  'B5QZ36': {('121', '295'), ('124', '311'), ('189', '287')},
#  'B5R0D9': {('15', '252'), ('19', '252')},
#  'B5RBY7': {('15', '252'), ('19', '252')},
#  'B5REF8': {('121', '295'), ('124', '311'), ('189', '287')},
#  'B5XP99': {('17', '250')},
#  'B5XU40': {('121', '295'), ('124', '311'), ('189', '287')},
#  'B5Y6I0': {('12', '249')},
#  'B5YR91': {('124', '287'), ('124', '295'), ('124', '311')},
#  'B5YV51': {('22', '255'), ('25', '252')},
#  'B5YZW5': {('14', '256'), ('14', '269'), ('18', '272')},
#  'B5Z7K9': {('17', '241'), ('20', '241'), ('6', '244')},
#  'B5Z7L8': {('94', '282')},
#  'B6A3G5': {('3', '249')},
#  'B6ELZ7': {('124', '282')},
#  'B6ERB4': {('10', '252'), ('23', '252')},
#  'B6HYU5': {('22', '255'), ('25', '252')},
#  'B6I423': {('124', '287'), ('124', '295'), ('124', '311')},
#  'B6I4Z5': {('14', '256'), ('14', '269'), ('18', '272')},
#  'B6JM82': {('94', '282')},
#  'B7GKQ7': {('11', '249'), ('18', '249'), ('61', '221')},
#  'B7GQ20': {('38', '297')},
#  'B7H160': {('20', '260')},
#  'B7H7H4': {('13', '249'), ('27', '249'), ('63', '240')},
#  'B7HT69': {('13', '249'), ('27', '249'), ('63', '240')},
#  'B7IAM8': {('20', '260')},
#  'B7IVS8': {('13', '249'), ('27', '249'), ('63', '240')},
#  'B7JN71': {('13', '249'), ('27', '249'), ('63', '240')},
#  'B7L9X5': {('22', '255'), ('25', '252')},
#  'B7LCG3': {('14', '255'), ('14', '269'), ('18', '272')},
#  'B7LGY7': {('124', '287'), ('124', '295'), ('124', '311')},
#  'B7LL66': {('14', '256'), ('14', '269'), ('18', '269')},
#  'B7LQC9': {('124', '287'), ('124', '295'), ('124', '311')},
#  'B7LV66': {('20', '255'), ('25', '252')},
#  'B7LZK1': {('124', '287'), ('124', '295'), ('124', '311')},
#  'B7M485': {('22', '255'), ('25', '252')},
#  'B7M6S8': {('14', '256'), ('14', '269'), ('18', '272')},
#  'B7MAC8': {('124', '287'), ('124', '295')},
#  'B7MEF9': {('22', '255'), ('25', '252')},
#  'B7MHS2': {('14', '256'), ('14', '269'), ('18', '272')},
#  'B7MWQ4': {('22', '255'), ('25', '252')},
#  'B7MY71': {('14', '256'), ('14', '269'), ('18', '272')},
#  'B7N0K1': {('124', '287'), ('124', '295')},
#  'B7N609': {('14', '256'), ('14', '269'), ('18', '272')},
#  'B7NCD4': {('22', '255'), ('25', '252')},
#  'B7ND40': {('124', '287'), ('124', '295'), ('124', '311')},
#  'B7NJR5': {('124', '287'), ('124', '295'), ('124', '311')},
#  'B7NPM9': {('22', '255'), ('25', '252')},
#  'B7NPV5': {('14', '256'), ('14', '269'), ('18', '272')},
#  'B7UFC1': {('22', '252'), ('25', '249')},
#  'B7UGB9': {('14', '256'), ('14', '269'), ('18', '272')},
#  'B7UIW0': {('124', '287'), ('124', '295'), ('124', '311')},
#  'B7V753': {('4', '264'), ('57', '264'), ('79', '184')},
#  'B7VIX1': {('125', '282')},
#  'B7VS66': {('12', '252'), ('23', '252')},
#  'B8CVJ1': {('189', '287'), ('72', '297')},
#  'B8DET2': {('10', '247'), ('21', '244')},
#  'B8DJ66': {('13', '249')},
#  'B8DSX7': {('35', '293')},
#  'B8EE43': {('124', '295'), ('189', '287')},
#  'B8F7P4': {('10', '256')},
#  'B8FB71': {('135', '247'), ('200', '291')},
#  'B8FJW2': {('24', '239'), ('6', '249'), ('7', '249')},
#  'B8FUD3': {('9', '248')},
#  'B8G7I8': {('14', '249'), ('23', '249'), ('24', '239')},
#  'B8GJF9': {('11', '240'), ('11', '246')},
#  'B8I3J5': {('15', '255'), ('26', '249')},
#  'B8J4C1': {('5', '239')},
#  'B8ZN14': {('7', '251')},
#  'B8ZN21': {('1', '246')},
#  'B9E564': {('21', '258'), ('23', '258')},
#  'B9E8D6': {('11', '242'), ('21', '236')},
#  'B9J2L4': {('13', '249'), ('27', '249'), ('63', '240')},
#  'B9JK65': {('11', '250')},
#  'B9KD06': {('6', '242')},
#  'B9KL69': {('16', '244')},
#  'B9LIA5': {('14', '249'), ('23', '249')},
#  'C0PYX3': {('121', '295'), ('124', '311'), ('189', '287')},
#  'C0Q0Y8': {('15', '252'), ('19', '252')},
#  'C0QAT7': {('33', '289')},
#  'C0QWJ2': {('15', '248'), ('25', '254'), ('51', '239')},
#  'C0ZGJ5': {('13', '257'), ('27', '250'), ('63', '222')},
#  'C1A163': {('16', '255')},
#  'C1AE25': {('18', '257')},
#  'C1C666': {('7', '251')},
#  'C1C673': {('13', '246')},
#  'C1CD69': {('7', '251')},
#  'C1CD76': {('13', '246')},
#  'C1CJG8': {('7', '251')},
#  'C1CJH5': {('1', '246')},
#  'C1CQI2': {('7', '251')},
#  'C1CQI9': {('13', '246')},
#  'C1DCM4': {('23', '251')},
#  'C1DGT9': {('188', '286')},
#  'C1EVE5': {('13', '249'), ('27', '249'), ('63', '240')},
#  'C1FR28': {('3', '246')},
#  'C1FSC2': {('10', '244'), ('17', '238'), ('61', '230')},
#  'C1KZ32': {('15', '247'), ('21', '244')},
#  'C3K4G7': {('4', '264'), ('60', '256'), ('79', '192')},
#  'C3KDB8': {('135', '294'), ('188', '286')},
#  'C3KZ28': {('3', '246')},
#  'C3L062': {('10', '244'), ('17', '238'), ('61', '230')},
#  'C3L626': {('13', '249'), ('27', '249'), ('63', '240')},
#  'C3LQY0': {('125', '282'), ('189', '282')},
#  'C3PBW0': {('13', '249'), ('27', '249'), ('63', '240')},
#  'C4KZE2': {('20', '244'), ('59', '244'), ('9', '247')},
#  'C4L8H9': {('22', '252'), ('31', '252'), ('68', '243')},
#  'C4XIJ3': {('5', '249')},
#  'C4ZQW9': {('124', '287'), ('124', '295'), ('124', '311')},
#  'C4ZSI8': {('22', '255'), ('25', '252')},
#  'C4ZVU9': {('14', '256'), ('14', '269'), ('18', '272')},
#  'C5BHH2': {('124', '295'), ('189', '287')},
#  'C5D2N0': {('13', '250'), ('27', '250')},
#  'C6DBE0': {('21', '253')},
#  'C6DDL3': {('124', '295')},
#  'D9TT10': {('150', '289')},
#  'E9AD19': {('175', '303')},
#  'K7VCB9': {('22', '261')},
#  'O00764': {('6', '279'), ('78', '272'), ('94', '199')},
#  'O01824': {('101', '278'), ('115', '247'), ('17', '286'), ('17', '287')},
#  'O05074': {('124', '295'), ('125', '314'), ('189', '287')},
#  'O14242': {('3', '271'), ('3', '288'), ('88', '272')},
#  'O25515': {('22', '257'), ('6', '259'), ('6', '264')},
#  'O25516': {('16', '240'), ('5', '243'), ('55', '207')},
#  'O25529': {('94', '282')},
#  'O27587': {('176', '282')},
#  'O28204': {('15', '248'), ('26', '242')},
#  'O31620': {('20', '253'), ('20', '260'), ('6', '260')},
#  'O31714': {('129', '272')},
#  'O35331': {('6', '279'), ('78', '272'), ('91', '193')},
#  'O46560': {('104', '203'), ('16', '289'), ('88', '282')},
#  'O48881': {('31', '297'), ('31', '298'), ('35', '287')},
#  'O58877': {('11', '244'), ('21', '249'), ('21', '251')},
#  'O60116': {('167', '287')},
#  'O67772': {('2', '249')},
#  'O74860': {('12', '246'), ('63', '230'), ('63', '240')},
#  'O83153': {('18', '251'), ('18', '254'), ('3', '254'), ('5', '254')},
#  'O85786': {('19', '252'), ('3', '262'), ('4', '262')},
#  'O94265': {('1', '271'), ('1', '274'), ('1', '275')},
#  'O94266': {('35', '313'), ('35', '314'), ('36', '295'), ('36', '314')},
#  'P0A9J6': {('149', '273'), ('175', '225')},
#  'P0A9J7': {('149', '273'), ('175', '225')},
#  'P0AEW9': {('160', '276')},
#  'P0AEX0': {('160', '276')},
#  'P0AEX1': {('160', '276')},
#  'P0AEX2': {('160', '276')},
#  'P22824': {('140', '278')},
#  'P23386': {('179', '288')},
#  'P26420': {('174', '264')},
#  'P26421': {('167', '277')},
#  'P30235': {('147', '279')},
#  'P32143': {('162', '283')},
#  'P36945': {('122', '267'), ('122', '273')},
#  'P39593': {('10', '250'), ('26', '226')},
#  'P39610': {('5', '255'), ('6', '262'), ('7', '257')},
#  'P39988': {('1', '274'), ('2', '274'), ('50', '255')},
#  'P40191': {('14', '256'), ('14', '269'), ('18', '272')},
#  'P40192': {('19', '276'), ('23', '276'), ('95', '260')},
#  'P40386': {('249', '492')},
#  'P41835': {('262', '526')},
#  'P44331': {('161', '296'), ('165', '278')},
#  'P44690': {('1', '263'), ('2', '263'), ('54', '263'), ('76', '181')},
#  'P44697': {('20', '257'), ('4', '264'), ('5', '264')},
#  'P47143': {('195', '332')},
#  'P50845': {('175', '284')},
#  'P53727': {('7', '284'), ('7', '291'), ('80', '283')},
#  'P55262': {('215', '350')},
#  'P55882': {('5', '264'), ('6', '265'), ('7', '253')},
#  'P55883': {('15', '252'), ('19', '252')},
#  'P56904': {('1', '262'), ('1', '265'), ('18', '263')},
#  'P57168': {('130', '297'), ('189', '287')},
#  'P57931': {('10', '256'), ('21', '256')},
#  'P61422': {('228', '485'), ('228', '486'), ('241', '474')},
#  'P66914': {('2', '254'), ('2', '265')},
#  'P66915': {('3', '255'), ('3', '268')},
#  'P66922': {('11', '243'), ('16', '241'), ('58', '237')},
#  'P66923': {('11', '243'), ('16', '241'), ('58', '237')},
#  'P76422': {('2', '264'), ('6', '265'), ('7', '255')},
#  'P76423': {('22', '255'), ('25', '252')},
#  'P76658': {('124', '287'), ('124', '295'), ('124', '311')},
#  'P77150': {('1', '263'), ('56', '255'), ('77', '182')},
#  'P77493': {('185', '283')},
#  'P82197': {('6', '279'), ('78', '272'), ('94', '189')},
#  'P83534': {('161', '297')},
#  'P96051': {('26', '251')},
#  'P99124': {('3', '255'), ('3', '268')},
#  'P9WG76': {('2', '254'), ('2', '265')},
#  'P9WG77': {('2', '254'), ('2', '265')},
#  'Q02DJ3': {('4', '264'), ('57', '264'), ('79', '256')},
#  'Q02YS4': {('11', '248'), ('34', '240')},
#  'Q03CB3': {('20', '247')},
#  'Q03GM6': {('7', '254')},
#  'Q03NR9': {('8', '246')},
#  'Q03XM8': {('18', '253'), ('20', '247')},
#  'Q03YX1': {('2', '237'), ('57', '206')},
#  'Q04LH2': {('13', '246')},
#  'Q04LH9': {('7', '251')},
#  'Q04V49': {('23', '256'), ('36', '256'), ('74', '224')},
#  'Q04YC8': {('23', '256'), ('36', '256'), ('74', '224')},
#  'Q06490': {('44', '297'), ('44', '319'), ('46', '297')},
#  'Q07Y78': {('130', '295'), ('189', '287')},
#  'Q08224': {('22', '275'), ('22', '298'), ('24', '273')},
#  'Q08975': {('22', '275'), ('22', '298'), ('24', '273')},
#  'Q0A4T7': {('148', '295'), ('189', '287')},
#  'Q0AZ87': {('6', '256')},
#  'Q0BSF0': {('2', '262'), ('73', '262'), ('75', '256')},
#  'Q0BVF4': {('18', '256'), ('33', '261')},
#  'Q0C190': {('199', '299')},
#  'Q0HFL0': {('124', '295'), ('189', '287')},
#  'Q0HYC0': {('124', '295'), ('189', '287')},
#  'Q0I129': {('20', '255'), ('9', '255')},
#  'Q0I1X5': {('123', '294'), ('188', '286')},
#  'Q0I3D2': {('1', '260'), ('2', '260'), ('54', '261'), ('74', '181')},
#  'Q0II59': {('6', '279'), ('78', '272'), ('94', '189')},
#  'Q0STA0': {('4', '247')},
#  'Q0T0L1': {('124', '287'), ('124', '295'), ('124', '311')},
#  'Q0T335': {('22', '255'), ('25', '252')},
#  'Q0TD55': {('124', '287'), ('124', '295'), ('124', '311')},
#  'Q0TF48': {('14', '256'), ('14', '269'), ('18', '272')},
#  'Q0TFY8': {('22', '255'), ('25', '252')},
#  'Q0THJ1': {('1', '263'), ('56', '255'), ('77', '182')},
#  'Q0TQV3': {('4', '246')},
#  'Q0VM60': {('135', '298'), ('190', '288')},
#  'Q0W1L9': {('8', '247'), ('8', '255')},
#  'Q12RC7': {('125', '295'), ('189', '287')},
#  'Q141E8': {('1', '261')},
#  'Q162K5': {('6', '243')},
#  'Q17WK1': {('184', '282'), ('94', '282')},
#  'Q186F4': {('7', '215'), ('7', '248')},
#  'Q18GX8': {('17', '247')},
#  'Q1ASC4': {('14', '237')},
#  'Q1AYE5': {('79', '264'), ('8', '264'), ('8', '265'), ('82', '186')},
#  'Q1BXQ7': {('1', '257'), ('2', '258'), ('53', '256'), ('76', '256')},
#  'Q1C374': {('124', '295')},
#  'Q1C792': {('1', '262'), ('2', '262'), ('72', '181'), ('74', '262')},
#  'Q1CIM6': {('1', '262'), ('2', '262'), ('72', '181'), ('74', '262')},
#  'Q1CMD4': {('124', '295')},
#  'Q1CT14': {('94', '282')},
#  'Q1CT25': {('17', '241'), ('56', '208'), ('6', '244')},
#  'Q1H3A0': {('202', '300')},
#  'Q1I2L8': {('4', '264'), ('60', '256'), ('79', '256')},
#  'Q1I411': {('134', '294'), ('188', '286')},
#  'Q1J237': {('10', '273'), ('64', '273'), ('85', '225')},
#  'Q1J4Q3': {('179', '276')},
#  'Q1LFU5': {('27', '273'), ('36', '270'), ('90', '270')},
#  'Q1M5U3': {('10', '249')},
#  'Q1QNS3': {('199', '296')},
#  'Q1R1M6': {('124', '297'), ('189', '287')},
#  'Q1R6S9': {('124', '287'), ('124', '295'), ('124', '311')},
#  'Q1R8V2': {('14', '256'), ('14', '269'), ('18', '272')},
#  'Q1R9W8': {('22', '255'), ('25', '252')},
#  'Q1RBF9': {('1', '263'), ('56', '255'), ('77', '182')},
#  'Q21VL4': {('16', '253')},
#  'Q24XQ1': {('9', '248')},
#  'Q253G3': {('12', '252')},
#  'Q2FF34': {('11', '243'), ('16', '241'), ('58', '237')},
#  'Q2FNE1': {('18', '256')},
#  'Q2FWG2': {('11', '243'), ('16', '241'), ('58', '237')},
#  'Q2G2P8': {('30', '247')},
#  'Q2K0X8': {('1', '240')},
#  'Q2L1P5': {('27', '269'), ('38', '266'), ('38', '269')},
#  'Q2LWX9': {('10', '251')},
#  'Q2NGG1': {('17', '270')},
#  'Q2NGH3': {('16', '273'), ('27', '260')},
#  'Q2NWD9': {('123', '295')},
#  'Q2QWK9': {('57', '322'), ('73', '322')},
#  'Q2RGX6': {('18', '248'), ('28', '256')},
#  'Q2SN34': {('173', '287'), ('89', '295')},
#  'Q2SXQ4': {('1', '257'), ('2', '258'), ('4', '256')},
#  'Q2W993': {('136', '299')},
#  'Q2YUL1': {('11', '243'), ('16', '241'), ('58', '237')},
#  'Q312G9': {('14', '249'), ('24', '249')},
#  'Q31IC2': {('120', '294')},
#  'Q31WY3': {('124', '287'), ('124', '295'), ('124', '311')},
#  'Q320Z3': {('1', '263'), ('56', '255'), ('77', '182')},
#  'Q323B8': {('22', '255'), ('25', '252')},
#  'Q32BR2': {('124', '287'), ('124', '295'), ('124', '311')},
#  'Q32DD5': {('14', '256'), ('14', '269'), ('18', '272')},
#  'Q32EA0': {('22', '255'), ('25', '252')},
#  'Q32FD7': {('1', '263'), ('56', '255'), ('77', '182')},
#  'Q38ZL9': {('9', '246')},
#  'Q39I40': {('1', '257'), ('2', '258'), ('53', '256'), ('76', '256')},
#  'Q39X60': {('199', '298'), ('74', '306')},
#  'Q3A526': {('199', '298')},
#  'Q3AE32': {('25', '253'), ('26', '236'), ('8', '253')},
#  'Q3IHX7': {('190', '287')},
#  'Q3IP35': {('16', '255')},
#  'Q3J061': {('16', '244')},
#  'Q3J7Y0': {('147', '295'), ('189', '287')},
#  'Q3JQA6': {('1', '257'), ('2', '258'), ('4', '256')},
#  'Q3K1L7': {('13', '233'), ('6', '244')},
#  'Q3K4B8': {('4', '264'), ('56', '256')},
#  'Q3KJ28': {('134', '294'), ('188', '286')},
#  'Q3STQ8': {('199', '292')},
#  'Q3YXJ0': {('124', '287'), ('124', '295'), ('124', '311')},
#  'Q3YZC3': {('14', '256'), ('14', '269'), ('18', '272')},
#  'Q3Z0A6': {('22', '255'), ('25', '252'), ('25', '259')},
#  'Q3Z1Z2': {('1', '263'), ('56', '255'), ('77', '182')},
#  'Q466J4': {('17', '250'), ('64', '233'), ('8', '250')},
#  'Q48BL6': {('4', '264'), ('5', '264'), ('79', '184')},
#  'Q48P39': {('133', '294'), ('188', '286')},
#  'Q49396': {('179', '281')},
#  'Q493X3': {('123', '298'), ('155', '298')},
#  'Q49Z40': {('16', '244'), ('7', '244')},
#  'Q4K3F6': {('4', '264'), ('63', '256'), ('79', '193')},
#  'Q4KJA9': {('125', '294'), ('188', '286')},
#  'Q4L7X4': {('15', '243'), ('3', '243')},
#  'Q4L872': {('130', '303')},
#  'Q4QKN8': {('124', '295'), ('125', '314'), ('189', '287')},
#  'Q4QNC8': {('22', '255'), ('58', '206'), ('6', '255')},
#  'Q4ZL75': {('4', '264'), ('5', '264'), ('79', '184')},
#  'Q4ZZ15': {('133', '294'), ('188', '286')},
#  'Q51892': {('1', '264'), ('2', '264'), ('61', '183'), ('67', '256')},
#  'Q52975': {('22', '71')},
#  'Q53W83': {('173', '293')},
#  'Q55EK9': {('1', '265'), ('79', '228'), ('80', '193')},
#  'Q57233': {('22', '255'), ('6', '255'), ('61', '206')},
#  'Q57688': {('2', '224'), ('2', '226'), ('3', '233')},
#  'Q57JQ9': {('121', '295'), ('124', '311'), ('189', '287')},
#  'Q57LS3': {('19', '276'), ('23', '276'), ('95', '260')},
#  'Q57MJ3': {('15', '252'), ('19', '252')},
#  'Q57PI7': {('1', '262'), ('2', '262'), ('74', '262'), ('76', '181')},
#  'Q5E0Q5': {('13', '255'), ('14', '255')},
#  'Q5E2L7': {('123', '282'), ('189', '282')},
#  'Q5E345': {('1', '264'), ('2', '263'), ('64', '208'), ('64', '263')},
#  'Q5FS52': {('157', '284')},
#  'Q5HEA7': {('11', '243'), ('16', '241'), ('58', '237')},
#  'Q5HI96': {('3', '260'), ('6', '250'), ('6', '260')},
#  'Q5HM37': {('130', '303')},
#  'Q5HMC9': {('16', '243'), ('3', '243')},
#  'Q5HRG7': {('3', '260'), ('6', '250'), ('6', '260')},
#  'Q5JEK6': {('158', '269')},
#  'Q5KZU2': {('14', '251'), ('28', '207')},
#  'Q5L6R4': {('12', '252')},
#  'Q5M731': {('29', '295'), ('29', '297'), ('31', '292')},
#  'Q5PC86': {('121', '295'), ('124', '311'), ('189', '287')},
#  'Q5PIK8': {('1', '262'), ('2', '262'), ('74', '262'), ('76', '181')},
#  'Q5PMV9': {('15', '252'), ('19', '252')},
#  'Q5PNC8': {('19', '276'), ('23', '276'), ('95', '260')},
#  'Q5WDW4': {('11', '248'), ('4', '248')},
#  'Q5WKY9': {('125', '296')},
#  'Q5X9Y3': {('179', '276')},
#  'Q607M3': {('121', '285'), ('121', '293')},
#  'Q62LP6': {('1', '257'), ('2', '258'), ('4', '256')},
#  'Q63GK4': {('13', '249'), ('27', '249'), ('63', '240')},
#  'Q63SC2': {('1', '257'), ('2', '258'), ('4', '256')},
#  'Q65DJ9': {('13', '249'), ('20', '249'), ('63', '240')},
#  'Q65T41': {('135', '295'), ('189', '284')},
#  'Q65UE8': {('1', '261'), ('2', '261'), ('54', '259'), ('76', '181')},
#  'Q665V3': {('124', '295')},
#  'Q66A50': {('1', '262'), ('2', '262'), ('72', '181'), ('74', '262')},
#  'Q6A9C5': {('27', '256')},
#  'Q6AFC1': {('2', '258'), ('3', '258'), ('73', '258'), ('74', '259')},
#  'Q6AQZ6': {('25', '250'), ('9', '250')},
#  'Q6D164': {('121', '295')},
#  'Q6D299': {('21', '253'), ('27', '253')},
#  'Q6D5V1': {('1', '261'), ('2', '261'), ('75', '253'), ('76', '181')},
#  'Q6FAS9': {('23', '252')},
#  'Q6G7L7': {('3', '255'), ('3', '268')},
#  'Q6G7L8': {('11', '243'), ('16', '241'), ('58', '237')},
#  'Q6GEY2': {('3', '255'), ('3', '268')},
#  'Q6GEY3': {('11', '243'), ('16', '241'), ('58', '237')},
#  'Q6HP18': {('13', '249'), ('27', '249'), ('63', '240')},
#  'Q6LP62': {('4', '260'), ('59', '258'), ('77', '182')},
#  'Q6LPQ4': {('19', '250'), ('29', '257')},
#  'Q6LUZ5': {('124', '286'), ('189', '285')},
#  'Q6LY53': {('21', '253'), ('5', '252')},
#  'Q6NG19': {('2', '255'), ('2', '256'), ('55', '188'), ('55', '254')},
#  'Q723Z1': {('15', '247'), ('21', '244')},
#  'Q729I7': {('10', '249')},
#  'Q72U64': {('20', '256'), ('32', '256'), ('74', '246')},
#  'Q73E73': {('13', '249'), ('27', '249'), ('63', '240')},
#  'Q74BF6': {('135', '298'), ('74', '306')},
#  'Q7AAQ7': {('124', '287'), ('124', '295'), ('124', '311')},
#  'Q7CIR8': {('1', '262'), ('2', '262'), ('72', '181'), ('74', '262')},
#  'Q7CPR9': {('121', '295'), ('124', '311'), ('189', '287')},
#  'Q7M9U1': {('144', '284')},
#  'Q7MGA4': {('4', '260'), ('75', '260'), ('78', '182')},
#  'Q7MNY3': {('125', '282'), ('189', '282')},
#  'Q7N0C3': {('124', '295'), ('189', '287')},
#  'Q7N3W7': {('1', '262'), ('2', '262'), ('60', '262'), ('76', '181')},
#  'Q7UBI8': {('124', '287'), ('124', '295'), ('124', '311')},
#  'Q7UFW7': {('164', '268')},
#  'Q7VM30': {('124', '295'), ('156', '287')},
#  'Q7VQQ6': {('121', '298')},
#  'Q7VU32': {('79', '269')},
#  'Q7VYK4': {('1', '274'), ('18', '274'), ('89', '274')},
#  'Q7W6K7': {('1', '274'), ('18', '274'), ('89', '274')},
#  'Q7WII1': {('1', '274'), ('18', '274'), ('89', '274')},
#  'Q81IG9': {('13', '249'), ('27', '249'), ('63', '240')},
#  'Q81Z96': {('13', '249'), ('27', '249'), ('63', '240')},
#  'Q824E8': {('12', '252')},
#  'Q830K4': {('10', '246')},
#  'Q83B60': {('169', '299'), ('191', '289')},
#  'Q83K78': {('14', '256'), ('14', '269'), ('18', '272')},
#  'Q83KH2': {('22', '255'), ('25', '252')},
#  'Q83KY1': {('1', '263'), ('56', '255'), ('77', '182')},
#  'Q87FP6': {('4', '260'), ('75', '260'), ('78', '182')},
#  'Q87JW7': {('10', '252'), ('23', '252'), ('63', '252')},
#  'Q87SJ9': {('125', '282'), ('127', '282')},
#  'Q87TZ6': {('4', '264'), ('5', '264')},
#  'Q87VF4': {('133', '294'), ('188', '286')},
#  'Q88C26': {('4', '264'), ('60', '256')},
#  'Q88D93': {('188', '286')},
#  'Q890C2': {('13', '248'), ('20', '226'), ('23', '224')},
#  'Q893Q9': {('14', '262')},
#  'Q8CRN9': {('16', '243'), ('3', '243')},
#  'Q8CTQ7': {('3', '260'), ('6', '250'), ('6', '260')},
#  'Q8D4Q2': {('4', '260'), ('75', '260'), ('78', '182')},
#  'Q8DEH7': {('125', '282'), ('189', '282')},
#  'Q8DQJ9': {('13', '246')},
#  'Q8DQK5': {('7', '251')},
#  'Q8E093': {('13', '233'), ('6', '244'), ('76', '203')},
#  'Q8E5X0': {('13', '233'), ('6', '244')},
#  'Q8EAZ2': {('124', '295'), ('189', '287')},
#  'Q8ESJ1': {('6', '241')},
#  'Q8ESZ2': {('14', '242'), ('47', '218'), ('49', '216'), ('9', '244')},
#  'Q8F0X6': {('20', '256'), ('32', '256'), ('74', '246')},
#  'Q8FDH5': {('124', '287'), ('124', '295'), ('124', '311')},
#  'Q8FFB5': {('14', '256'), ('14', '269'), ('18', '272')},
#  'Q8FFY0': {('22', '255'), ('25', '252')},
#  'Q8FH89': {('1', '263'), ('56', '255'), ('77', '182')},
#  'Q8FTH8': {('223', '472'), ('223', '481')},
#  'Q8G7X0': {('38', '297')},
#  'Q8GLU7': {('124', '295'), ('189', '287')},
#  'Q8K183': {('6', '279'), ('78', '272'), ('94', '194')},
#  'Q8KA54': {('155', '297'), ('189', '287')},
#  'Q8NQH1': {('242', '491'), ('242', '499')},
#  'Q8NVH3': {('3', '255'), ('3', '268')},
#  'Q8NVH4': {('11', '243'), ('16', '241'), ('58', '237')},
#  'Q8NZD9': {('179', '276')},
#  'Q8PS50': {('5', '250'), ('58', '233'), ('8', '250')},
#  'Q8R1Q9': {('193', '281')},
#  'Q8R807': {('18', '251'), ('2', '252'), ('59', '204')},
#  'Q8TMD5': {('17', '242'), ('8', '242')},
#  'Q8U191': {('21', '217'), ('21', '252'), ('8', '252')},
#  'Q8UAS9': {('12', '229')},
#  'Q8W1X2': {('17', '269'), ('91', '270'), ('93', '193')},
#  'Q8X649': {('1', '263'), ('56', '255'), ('77', '182')},
#  'Q8X7G3': {('22', '255'), ('25', '252')},
#  'Q8XBL0': {('14', '256'), ('14', '269'), ('18', '272')},
#  'Q8XEW9': {('121', '295'), ('124', '311'), ('189', '287')},
#  'Q8XKQ7': {('4', '246')},
#  'Q8YA46': {('10', '247'), ('21', '244')},
#  'Q8Z4W1': {('19', '276'), ('23', '276'), ('95', '260')},
#  'Q8Z5C8': {('15', '252'), ('19', '252')},
#  'Q8Z6Q3': {('1', '213'), ('2', '221'), ('74', '212'), ('76', '181')},
#  'Q8ZI60': {('124', '295')},
#  'Q8ZPM8': {('1', '262'), ('2', '262'), ('74', '262'), ('76', '181')},
#  'Q92EW7': {('10', '247'), ('21', '244')},
#  'Q97EL4': {('20', '262'), ('9', '262')},
#  'Q97RR9': {('13', '246')},
#  'Q97RS6': {('7', '251')},
#  'Q9CF42': {('172', '274')},
#  'Q9CG46': {('18', '240'), ('3', '240'), ('77', '238')},
#  'Q9CME6': {('124', '287'), ('124', '295'), ('125', '313')},
#  'Q9CNY1': {('1', '259'), ('2', '258'), ('54', '253'), ('76', '181')},
#  'Q9H477': {('192', '280')},
#  'Q9HT57': {('4', '264'), ('57', '264'), ('79', '184')},
#  'Q9JRZ9': {('45', '261')},
#  'Q9K7L2': {('6', '250')},
#  'Q9KMX5': {('367', '479')},
#  'Q9LIQ4': {('18', '256')},
#  'Q9RGS6': {('17', '245'), ('4', '245'), ('59', '229')},
#  'Q9RYX0': {('74', '163'), ('82', '295'), ('9', '295')},
#  'Q9USL6': {('14', '265'), ('14', '275'), ('14', '293')},
#  'Q9UZQ4': {('11', '252'), ('21', '252')},
#  'Q9WZP7': {('1', '205'), ('1', '206')},
#  'Q9ZBL1': {('12', '268'), ('12', '270'), ('12', '277'), ('29', '268')},
#  'Q9ZBR6': {('26', '257'), ('27', '263'), ('27', '267'), ('27', '269')},
#  'Q9ZKZ0': {('94', '282')},
#  'Q9ZKZ9': {('16', '240'), ('19', '207'), ('5', '243')},
#  'Q9ZL00': {('20', '256'), ('5', '258'), ('5', '263')}}

# %% [markdown]
# #### Read the output file of the hmm search

# %%
def read_hmm(path):

    ''' Create a dictionary having as key the protein ID and as value the set of
    tuples (start, end) representing the position of our domain in that protein
    (we assume that the domain may be present in more than one position). '''
  
    positions = {}
    with open(path,'r') as f:
        for line in f:
            if line[0] != "#": # and line[0] != "-":
              line=line.replace('|', ' ')
              (_, id, _, _, tlen, _, _, qlen,  
              full_seq_evalue, full_seq_score, _, _, _, dcevalue, dievalue, dscore, _, _, _ , 
              align_from, align_to, env_from, env_to, accuracy, description) = line.strip().split()[:25]
              #exist multiple scores and alignment. Above I took all of them, but in the below dictionary
              #I have put the same used in github reference
            
              positions.setdefault(id, set()).add( (align_from, align_to) )
   
    return positions

# %%
path = datapath + 'hmm_search_uniref90.hmmer_domtblout'
positions_hmm = read_hmm(path)
print(f'Number of distint proteins found with hmm: {len(positions_hmm)}')
# Out:
# Number of distint proteins found with hmm: 412

# %%
positions_hmm
# Out:
# {'A0A0H2WZY4': {('167', '228')},
#  'A0AFC3': {('47', '219')},
#  'A0KPL4': {('189', '288')},
#  'A0KTG8': {('189', '288')},
#  'A0R980': {('189', '238')},
#  'A1A6H3': {('241', '348')},
#  'A1ACX0': {('121', '241')},
#  'A1ADT5': {('88', '276')},
#  'A1AFX4': {('189', '287')},
#  'A1AV12': {('199', '299')},
#  'A1JQJ2': {('67', '226')},
#  'A1RGD1': {('189', '288')},
#  'A1S3I3': {('189', '289')},
#  'A1SZY2': {('190', '289')},
#  'A3D837': {('189', '288')},
#  'A3MZC0': {('189', '288')},
#  'A3N2D3': {('73', '270')},
#  'A3NJS6': {('93', '244')},
#  'A3P5E2': {('93', '244')},
#  'A3QAN3': {('189', '288')},
#  'A4SIG6': {('189', '288')},
#  'A4VR47': {('188', '287')},
#  'A4WEI4': {('189', '288')},
#  'A4XPU9': {('188', '287')},
#  'A4Y9Z9': {('189', '288')},
#  'A4YYB6': {('198', '303')},
#  'A5EN78': {('198', '302')},
#  'A5EWS4': {('190', '288')},
#  'A5G6F4': {('199', '299')},
#  'A5HYZ4': {('62', '206')},
#  'A5N1D3': {('67', '210')},
#  'A5UA83': {('74', '273')},
#  'A5UCC3': {('189', '287')},
#  'A5UEH8': {('189', '287')},
#  'A5W9W6': {('188', '287')},
#  'A5WB73': {('76', '184')},
#  'A6GXW4': {('145', '240')},
#  'A6TE31': {('189', '288')},
#  'A6TMN6': {('56', '214')},
#  'A6UPE5': {('87', '219')},
#  'A6VDB5': {('188', '286')},
#  'A6VEZ4': {('78', '185')},
#  'A6VNE5': {('68', '181')},
#  'A6VP06': {('189', '287')},
#  'A6VPG7': {('58', '208')},
#  'A6W0Z9': {('189', '236'), ('61', '89')},
#  'A6W6A1': {('85', '238')},
#  'A6WJS7': {('189', '288')},
#  'A7FPT1': {('62', '206')},
#  'A7GAL1': {('61', '206')},
#  'A7GKR3': {('78', '225')},
#  'A7MP93': {('189', '287')},
#  'A7MWN3': {('189', '288')},
#  'A7N5Q6': {('76', '261')},
#  'A7ZA59': {('63', '225')},
#  'A7ZE26': {('185', '284')},
#  'A7ZNS3': {('120', '241')},
#  'A7ZPL9': {('88', '276')},
#  'A7ZRT3': {('189', '287')},
#  'A8A1W9': {('192', '241')},
#  'A8A2R4': {('88', '276')},
#  'A8A4K6': {('189', '287')},
#  'A8AEC1': {('190', '247')},
#  'A8APT1': {('189', '288')},
#  'A8FIR7': {('63', '237')},
#  'A8FZZ3': {('189', '289')},
#  'A8H086': {('189', '289')},
#  'A8M9N5': {('79', '215')},
#  'A9CES5': {('181', '239')},
#  'A9KDJ2': {('191', '290')},
#  'A9L2P0': {('189', '288')},
#  'Q9CME6': {('189', '287')},
#  'Q9CNY1': {('75', '271')},
#  'Q9HT57': {('78', '185')},
#  'Q9HUG9': {('188', '286')},
#  'Q9JRZ9': {('89', '257')},
#  'Q9RYX0': {('98', '193')},
#  'Q9USL6': {('11', '277')},
#  'Q9VVW8': {('162', '203')},
#  'Q9WZP7': {('1', '211')},
#  'Q9ZBL1': {('15', '268')},
#  'Q9ZBR6': {('9', '255')},
#  'Q9ZL00': {('4', '256')}}

# %% [markdown]
# #### Model evaluation

# %%
# !pip install Bio
# from Bio import SeqIO
import math
import json
import pandas as pd
import numpy as np

# %% [markdown]
# #### Useful functions to compute metrics

# %% [markdown]
# CONFIDENTIAL!!! :-)
#
# In $\verb!utils.py!$ there are 5 functions:
#
# - $\verb!computeMetrics!$
# - $\verb!createPositionSet!$
# - $\verb!evaluateSequencesSH2!$
# - $\verb!getSeqLength!$
# - $\verb!evaluatePositionsSH2!$
#
# But for point 8) are needed only:
# - $\verb!computeMetrics!$
# - $\verb!evaluateSequencesSH2!$
#
# So I use only them in the following.

# %%
# import math
def metrics(true_positive, true_negative, false_positive, false_negative):
  
    accuracy = (true_positive + true_negative) / (true_positive + true_negative + false_negative + false_positive)
    precision = true_positive / (true_positive + false_positive)
    sensitivity = true_positive / (true_positive + false_negative)
    specificity = true_negative / (true_negative + false_positive)
    weighted_accuracy = (sensitivity + specificity) / 2
    mcc_numerator = (true_positive * true_negative) - (false_positive * false_negative)
    mcc_denominator_squared = (true_positive + false_positive) * (true_positive + false_negative) * (true_negative + false_positive) * (true_negative + false_negative)
    mcc = mcc_numerator / math.sqrt(mcc_denominator_squared)
    f1_score = 2 * (precision * sensitivity) / (precision + sensitivity)
    
    return {
            "Accuracy": accuracy,
            "Weighted accuracy": weighted_accuracy,
            "Precision": precision,
            "Sensitivity": sensitivity,
            "Specificity": specificity,
            "MCC": mcc,
            "F-score": f1_score
            }

# %%
def metrics_results(predictions, actual_positives, ground_truth_size):
    """
    predictions = dict of the type {'A0A0H2WZY4': {('167', '228')}, ... }
    actual_positives = set of sequences containing PF08543
    ground_truth_size = number of actual positives + actual negatives (= SwissPort size)
    """
    predicted_sequences = set(predictions.keys())
    
    true_positive = len(predicted_sequences & actual_positives)
    
    # # If there aren't true postive later there will be a division by 0
    # if true_positive == 0:
    #     print("No true positive!")
    #     return
    
    false_negative = len(actual_positives) - true_positive
    false_positive = len(predicted_sequences) - true_positive
    true_negative = ground_truth_size - true_positive - false_positive - false_negative
    
    conf_matrix = pd.DataFrame(np.array([[true_positive, false_positive], [false_negative, true_negative]]), 
                               index=['Positive pred', 'Negative pred'], 
                               columns=['Actual positive', 'Actual negative'])

    return conf_matrix, metrics(true_positive, true_negative, false_positive, false_negative)

# %% [markdown]
# #### Evaluate psi-blast

# %%
conf_matrix_psiblast, metric_results_psiblast = metrics_results(positions_psiblast, set_protein_containing_domain, num_sequences )
print('CLASSIFICATION METRICS')
for k in metric_results_psiblast:
    print(f'{k}: {metric_results_psiblast[k]:.3}')
    
print('\nCONFUSION MATRIX')    
conf_matrix_psiblast
# Out:
# CLASSIFICATION METRICS
# Accuracy: 0.999
# Weighted accuracy: 1.0
# Precision: 0.223
# Sensitivity: 1.0
# Specificity: 0.999
# MCC: 0.472
# F-score: 0.364
#
# CONFUSION MATRIX
#                Actual positive  Actual negative
# Positive pred              150              524
# Negative pred                0           563298

# %% [markdown]
# #### Evaluate hmm

# %%
conf_matrix_hmm, metric_results_hmm = metrics_results(positions_hmm, set_protein_containing_domain, num_sequences )
print('CLASSIFICATION METRICS')
for k in metric_results_hmm:
    print(f'{k}: {metric_results_hmm[k]:.3}')
    
print('\nCONFUSION MATRIX')    
conf_matrix_hmm
# Out:
# CLASSIFICATION METRICS
# Accuracy: 1.0
# Weighted accuracy: 0.993
# Precision: 0.359
# Sensitivity: 0.987
# Specificity: 1.0
# MCC: 0.595
# F-score: 0.527
#
# CONFUSION MATRIX
#                Actual positive  Actual negative
# Positive pred              148              264
# Negative pred                2           563558

# %% [markdown]
# ### Comment on the results

# %% [markdown]
# We have so many false positives and very few false negatives. Probably we should try to retrieve less hits, since their correct number is 150, but our models selected much more sequences (674 with psiblast and 412 with hmm).

# %% [markdown]
# ## Ex 9

# %% [markdown]
# #### Read the ground truth file for the positions

# %%
path = datapath + 'protein-matching-PF08543.json'

with open(path, "r") as file:
    position_file = json.load(file)
    
ground_truth_positions = {}
for elem in position_file:
    id = elem['metadata']['accession']
    length = elem['metadata']['length']

    ground_truth_positions.setdefault(id, dict()).update([('length', length), ('positions', set())])

    for entry in elem['entries']:
        if entry['accession']=='PF08543':
            for location in entry['entry_protein_locations']:

                position_tuple=(str(location['fragments'][0]['start']),
                                str(location['fragments'][0]['end']))

                ground_truth_positions[id]['positions'].add(position_tuple)

# %%
print(len(ground_truth_positions))
# Out:
# 150

# %%
for item in ground_truth_positions.items():
  print(item)
# Out:
# ('A1ADT5', {'length': 283, 'positions': {('88', '265')}})
# ('A3N2D3', {'length': 286, 'positions': {('64', '256')}})
# ('A5UA83', {'length': 288, 'positions': {('71', '264')}})
# ('A5WB73', {'length': 290, 'positions': {('74', '257')}})
# ('A6VEZ4', {'length': 288, 'positions': {('77', '259')}})
# ('A6VNE5', {'length': 286, 'positions': {('62', '259')}})
# ('A7N5Q6', {'length': 289, 'positions': {('75', '260')}})
# ('A7ZPL9', {'length': 283, 'positions': {('88', '265')}})
# ('A8A2R4', {'length': 283, 'positions': {('88', '265')}})
# ('B0KR83', {'length': 290, 'positions': {('76', '257')}})
# ('B0UUD2', {'length': 286, 'positions': {('64', '260')}})
# ('B1IX53', {'length': 283, 'positions': {('88', '265')}})
# ('B1JFM7', {'length': 290, 'positions': {('76', '257')}})
# ('B1LML3', {'length': 283, 'positions': {('88', '265')}})
# ('B1XA89', {'length': 283, 'positions': {('88', '265')}})
# ('B2JCI0', {'length': 287, 'positions': {('74', '261')}})
# ('B2TX08', {'length': 283, 'positions': {('88', '265')}})
# ('B3H2H2', {'length': 286, 'positions': {('64', '256')}})
# ('B5YZW5', {'length': 283, 'positions': {('88', '265')}})
# ('B6I4Z5', {'length': 283, 'positions': {('88', '265')}})
# ('B7LCG3', {'length': 283, 'positions': {('88', '265')}})
# ('B7LL66', {'length': 283, 'positions': {('88', '266')}})
# ('B7M6S8', {'length': 283, 'positions': {('88', '265')}})
# ('B7MHS2', {'length': 283, 'positions': {('88', '265')}})
# ('B7MY71', {'length': 283, 'positions': {('88', '265')}})
# ('B7N609', {'length': 283, 'positions': {('88', '265')}})
# ('B7NPV5', {'length': 283, 'positions': {('88', '265')}})
# ('B7UGB9', {'length': 283, 'positions': {('88', '265')}})
# ('B7V753', {'length': 290, 'positions': {('77', '262')}})
# ('C3K4G7', {'length': 290, 'positions': {('69', '256')}})
# ('C4ZVU9', {'length': 283, 'positions': {('88', '265')}})
# ('O00764', {'length': 312, 'positions': {('94', '275')}})
# ('O14242', {'length': 309, 'positions': {('92', '244')}})
# ('O25515', {'length': 270, 'positions': {('15', '262')}})
# ('O31620', {'length': 271, 'positions': {('13', '258')}})
# ('O35331', {'length': 312, 'positions': {('95', '273')}})
# ('O46560', {'length': 322, 'positions': {('104', '284')}})
# ('O48881', {'length': 523, 'positions': {('42', '285')}})
# ('O67772', {'length': 255, 'positions': {('10', '251')}})
# ('O74860', {'length': 340, 'positions': {('66', '241')}})
# ('O83153', {'length': 269, 'positions': {('11', '258')}})
# ('O85786', {'length': 263, 'positions': {('13', '256')}})
# ('O94265', {'length': 506, 'positions': {('12', '275')}})
# ('O94266', {'length': 551, 'positions': {('45', '301')}})
# ('P39610', {'length': 271, 'positions': {('13', '260')}})
# ('P39988', {'length': 312, 'positions': {('78', '234')}})
# ('P40191', {'length': 283, 'positions': {('88', '265')}})
# ('P40192', {'length': 288, 'positions': {('93', '269')}})
# ('P44690', {'length': 288, 'positions': {('71', '264')}})
# ('P44697', {'length': 269, 'positions': {('14', '262')}})
# ('P53727', {'length': 317, 'positions': {('80', '243')}})
# ('P55882', {'length': 266, 'positions': {('13', '260')}})
# ('P56904', {'length': 266, 'positions': {('12', '258')}})
# ('P61422', {'length': 490, 'positions': {('235', '479')}})
# ('P66914', {'length': 265, 'positions': {('13', '258')}})
# ('P66915', {'length': 276, 'positions': {('14', '260')}})
# ('P76422', {'length': 266, 'positions': {('13', '260')}})
# ('P77150', {'length': 287, 'positions': {('67', '256')}})
# ('P82197', {'length': 312, 'positions': {('94', '274')}})
# ('P99124', {'length': 276, 'positions': {('14', '260')}})
# ('P9WG76', {'length': 265, 'positions': {('13', '258')}})
# ('P9WG77', {'length': 265, 'positions': {('13', '258')}})
# ('Q02DJ3', {'length': 288, 'positions': {('77', '263')}})
# ('Q06490', {'length': 572, 'positions': {('55', '307')}})
# ('Q08224', {'length': 551, 'positions': {('33', '283')}})
# ('Q08975', {'length': 551, 'positions': {('33', '283')}})
# ('Q0BSF0', {'length': 286, 'positions': {('90', '262')}})
# ('Q0I3D2', {'length': 286, 'positions': {('64', '260')}})
# ('Q0II59', {'length': 312, 'positions': {('94', '274')}})
# ('Q0TF48', {'length': 283, 'positions': {('88', '265')}})
# ('Q0THJ1', {'length': 287, 'positions': {('67', '256')}})
# ('Q141E8', {'length': 288, 'positions': {('75', '262')}})
# ('Q1AYE5', {'length': 290, 'positions': {('112', '265')}})
# ('Q1BXQ7', {'length': 286, 'positions': {('74', '258')}})
# ('Q1C792', {'length': 286, 'positions': {('75', '263')}})
# ('Q1CIM6', {'length': 286, 'positions': {('75', '263')}})
# ('Q1I2L8', {'length': 290, 'positions': {('76', '257')}})
# ('Q1J237', {'length': 299, 'positions': {('83', '262')}})
# ('Q1LFU5', {'length': 288, 'positions': {('89', '268')}})
# ('Q1R8V2', {'length': 283, 'positions': {('88', '265')}})
# ('Q1RBF9', {'length': 287, 'positions': {('67', '256')}})
# ('Q2L1P5', {'length': 296, 'positions': {('90', '266')}})
# ('Q2QWK9', {'length': 548, 'positions': {('66', '310')}})
# ('Q2SXQ4', {'length': 287, 'positions': {('64', '258')}})
# ('Q320Z3', {'length': 287, 'positions': {('67', '256')}})
# ('Q32DD5', {'length': 283, 'positions': {('88', '265')}})
# ('Q32FD7', {'length': 287, 'positions': {('67', '256')}})
# ('Q39I40', {'length': 286, 'positions': {('66', '258')}})
# ('Q3JQA6', {'length': 287, 'positions': {('64', '258')}})
# ('Q3K4B8', {'length': 290, 'positions': {('71', '256')}})
# ('Q3YZC3', {'length': 283, 'positions': {('88', '265')}})
# ('Q3Z1Z2', {'length': 287, 'positions': {('67', '256')}})
# ('Q48BL6', {'length': 288, 'positions': {('68', '263')}})
# ('Q4K3F6', {'length': 290, 'positions': {('70', '256')}})
# ('Q4ZL75', {'length': 288, 'positions': {('69', '263')}})
# ('Q51892', {'length': 289, 'positions': {('67', '263')}})
# ('Q52975', {'length': 90, 'positions': {('27', '72')}})
# ('Q55EK9', {'length': 302, 'positions': {('92', '265')}})
# ('Q57688', {'length': 417, 'positions': {('10', '235')}})
# ('Q57LS3', {'length': 288, 'positions': {('93', '269')}})
# ('Q57PI7', {'length': 286, 'positions': {('72', '256')}})
# ('Q5E345', {'length': 289, 'positions': {('75', '264')}})
# ('Q5HI96', {'length': 276, 'positions': {('13', '259')}})
# ('Q5HRG7', {'length': 276, 'positions': {('13', '259')}})
# ('Q5M731', {'length': 522, 'positions': {('40', '283')}})
# ('Q5PIK8', {'length': 286, 'positions': {('72', '256')}})
# ('Q5PNC8', {'length': 288, 'positions': {('93', '269')}})
# ('Q62LP6', {'length': 287, 'positions': {('64', '258')}})
# ('Q63SC2', {'length': 287, 'positions': {('64', '258')}})
# ('Q65UE8', {'length': 286, 'positions': {('68', '262')}})
# ('Q66A50', {'length': 286, 'positions': {('75', '263')}})
# ('Q6AFC1', {'length': 283, 'positions': {('91', '258')}})
# ('Q6D5V1', {'length': 286, 'positions': {('75', '253')}})
# ('Q6G7L7', {'length': 276, 'positions': {('14', '260')}})
# ('Q6GEY2', {'length': 276, 'positions': {('14', '260')}})
# ('Q6LP62', {'length': 291, 'positions': {('75', '260')}})
# ('Q6NG19', {'length': 283, 'positions': {('91', '255')}})
# ('Q7CIR8', {'length': 286, 'positions': {('75', '263')}})
# ('Q7MGA4', {'length': 290, 'positions': {('75', '260')}})
# ('Q7N3W7', {'length': 287, 'positions': {('74', '262')}})
# ('Q7VYK4', {'length': 283, 'positions': {('91', '272')}})
# ('Q7W6K7', {'length': 283, 'positions': {('90', '272')}})
# ('Q7WII1', {'length': 283, 'positions': {('90', '272')}})
# ('Q83K78', {'length': 283, 'positions': {('88', '265')}})
# ('Q83KY1', {'length': 287, 'positions': {('67', '256')}})
# ('Q87FP6', {'length': 289, 'positions': {('75', '260')}})
# ('Q87TZ6', {'length': 288, 'positions': {('69', '263')}})
# ('Q88C26', {'length': 290, 'positions': {('74', '257')}})
# ('Q8CTQ7', {'length': 276, 'positions': {('13', '259')}})
# ('Q8D4Q2', {'length': 290, 'positions': {('75', '260')}})
# ('Q8FFB5', {'length': 283, 'positions': {('88', '265')}})
# ('Q8FH89', {'length': 287, 'positions': {('67', '256')}})
# ('Q8FTH8', {'length': 739, 'positions': {('232', '479')}})
# ('Q8K183', {'length': 312, 'positions': {('94', '273')}})
# ('Q8NQH1', {'length': 763, 'positions': {('251', '498')}})
# ('Q8NVH3', {'length': 276, 'positions': {('14', '260')}})
# ('Q8W1X2', {'length': 309, 'positions': {('93', '199')}})
# ('Q8X649', {'length': 287, 'positions': {('67', '256')}})
# ('Q8XBL0', {'length': 283, 'positions': {('88', '265')}})
# ('Q8Z4W1', {'length': 288, 'positions': {('93', '269')}})
# ('Q8Z6Q3', {'length': 228, 'positions': {('72', '214')}})
# ('Q8ZPM8', {'length': 286, 'positions': {('72', '256')}})
# ('Q9CNY1', {'length': 286, 'positions': {('68', '253')}})
# ('Q9HT57', {'length': 288, 'positions': {('77', '262')}})
# ('Q9RYX0', {'length': 298, 'positions': {('101', '271')}})
# ('Q9USL6', {'length': 327, 'positions': {('23', '275')}})
# ('Q9WZP7', {'length': 398, 'positions': {('9', '208')}})
# ('Q9ZBL1', {'length': 279, 'positions': {('23', '272')}})
# ('Q9ZBR6', {'length': 269, 'positions': {('20', '262')}})
# ('Q9ZL00', {'length': 269, 'positions': {('14', '261')}})

# %% [markdown]
# #### Useful functions to compute metrics

# %% [markdown]
# CONFIDENTIAL!!! :-)
#
# In $\verb!utils.py!$ there are 5 functions:
#
# - $\verb!computeMetrics!$
# - $\verb!createPositionSet!$
# - $\verb!evaluateSequencesSH2!$
# - $\verb!getSeqLength!$
# - $\verb!evaluatePositionsSH2!$
#
# But for point 9) are needed only:
# - $\verb!computeMetrics!$
# - $\verb!createPositionSet!$
# - $\verb!getSeqLength!$
# - $\verb!evaluatePositionsSH2!$
#
# So I use only them in the following.

# %%
def createPositionSet(position_set):
    """
    position_set = {('88', '265'), ...}
    return a set {88, 89, ..., 265, ...}
    """
    positions = set()
    for pos in position_set: # pos is a tuple of two strings
        p = [i for i in range( int(pos[0]), int(pos[1])+1 )]
        positions = positions.union(p)
    return positions

# %% [markdown]
# This is the original function.
#
# I'm not able to run it because it calls a command line in Linux.
#
# If you can, please try to see if the below function provides the same result as my version.

# %% [markdown]
# I get the following error...
#
# `Error: [blastdbcmd] DB contains no accession info.`

# %%
############### ORIGINAL FUNCTION
'''
def getSeqLength(entry):
    """
    Get sequence length from reference dataset
    """   
    cmd = 'blastdbcmd -entry "{}" -db ../../data/SwissProt_humans_reference_all.fasta'.format(entry)
    results = subprocess.run(
            cmd, shell=True, universal_newlines=True, 
            stdout=subprocess.PIPE
            ).stdout
    results = results.split('\n')
    results.pop(0)
    return len("".join(results))
'''

# %%
path = datapath + 'uniprot_sprot.fasta'
all_sequences = SeqIO.parse(path, 'fasta')

# %%
##################### MY VERSION
def getSeqLength(entry, all_sequences):

  """
  Get sequence length from reference dataset
  """ 
#   path = datapath + 'uniprot_sprot.fasta'
#   all_sequences = SeqIO.parse(path, 'fasta')

  list_all_sequences = []
  for sequence in all_sequences:
      name = sequence.id # name is in the form sp|Q6GZX4|001R_FRG3G
      name = name.split('|')[1]
      if name==entry:
        #print(sequence.seq)
        #print(len(sequence.seq))
        length=len(sequence.seq)
  return length

# %%
#-------------------------DEBUG
entry='Q6GZX4'
getSeqLength(entry, all_sequences)
# Out:
# 256

# %%
def evaluatePositions(predicted_positions, ground_truth_positions):
    """
    predicted_positions: {'A0A0H2WZY4': {('162', '278')}, ...}
    ground_truth_positions: {'A1ADT5': {'length': 283, 'positions': {('88', '265')}}, ...}
    
    """
    global_tp, global_fp, global_fn, global_tn = [], [], [], []
    
    # scores per sequence
    log_scores = []

    for id in predicted_positions:
        if id in ground_truth_positions:
            sequence_length = ground_truth_positions[id]['length']
            ground_truth_positions_seq = createPositionSet(ground_truth_positions[id]['positions']) 
            ####################################################################################
            # Here there was an error: there was reference_positions = createPositionSet(reference_positions[seqid]['positions']), 
            # which modifies reference_positions! So we had correct results only for the first protein!
            ####################################################################################
            predicted_positions_seq = createPositionSet(predicted_positions[id])    

            overlapping_positions  = ground_truth_positions_seq & predicted_positions_seq

            true_positive = len(overlapping_positions)
            false_positive = len(predicted_positions_seq - overlapping_positions)
            false_negative = len(ground_truth_positions_seq -  overlapping_positions)
            true_negative  = sequence_length - true_positive - false_positive - false_negative

            global_tp.append(true_positive)
            global_fp.append(false_positive)
            global_fn.append(false_negative)
            global_tn.append(true_negative)
            
            log_scores.append(metrics(true_positive, true_negative, false_positive, false_negative))


        ##############
        # HA SENSO? ci mette una vita per calcolare la lunghezza delle sequence con getSeqLength 
        # e non so se sia utile/sensato comprendere le sequenze senza dominio in questo esercizio
        ##############
        # else:
        #     # false positive sequence
        #     predicted_positions_seq = createPositionSet(predicted_positions[id])

        #     true_positive = 0
        #     false_positive = len(predicted_positions_seq)
        #     false_negative = 0
        #     true_negative = 0
            
        #     lenSeq = getSeqLength(id)
            
        #     log_scores.append(
        #         {
        #             'Precision': 0,
        #             'Sensitivity': 0,
        #             'Specificity': lenSeq / (lenSeq + false_positive),
        #             'F1-score': 0,
        #             'MCC': 0
        #         }
        #     )

        #     list_tp.append(true_positive)
        #     list_fp.append(false_positive)
        #     list_fn.append(false_negative)
        #     list_tn.append(true_negative)
                   
    metrics_global = metrics(true_positive=sum(global_tp), true_negative=sum(global_tn), 
                             false_positive=sum(global_fp), false_negative=sum(global_fn))
    
    conf_matrix = pd.DataFrame(np.array([[sum(global_tp), sum(global_fp)], [sum(global_fn), sum(global_tn)]]), 
                               index=['Positive pred', 'Negative pred'], 
                               columns=['Actual positive', 'Actual negative'])
    
    return metrics_global, log_scores, conf_matrix

# %% [markdown]
# #### Evaluate psi-blast

# %%
metrics_global_psiblast, log_score_psiblast, conf_matrix_psiblast_pos = evaluatePositions(positions_psiblast, ground_truth_positions)

# %%
print('CLASSIFICATION METRICS')
for k in metrics_global_psiblast:
    print(f'{k}: {metrics_global_psiblast[k]:.3}')
print('\nCONFUSION MATRIX')    
conf_matrix_psiblast_pos
# Out:
# CLASSIFICATION METRICS
# Accuracy: 0.795
# Weighted accuracy: 0.715
# Precision: 0.759
# Sensitivity: 0.999
# Specificity: 0.43
# MCC: 0.569
# F-score: 0.862
#
# CONFUSION MATRIX
#                Actual positive  Actual negative
# Positive pred            29573             9413
# Negative pred               26             7099

# %%
# This is the output considering also the retrieved sequences without the domain
metrics_global_psiblast
# Out:
# {'Accuracy': 0.2367829747669103,
#  'F1-score': 0.3334987313222441,
#  'MCC': 0.10470260431297877,
#  'Precision': 0.20015431367638797,
#  'Sensitivity': 0.9991215919456738,
#  'Specificity': 0.05666642719733071}

# %%
# old version
metrics_global_psiblast
# Out:
# {'Accuracy': 0.0033580173508824087,
#  'F1-score': 0.003297408696239738,
#  'MCC': 0.0016815567089388617,
#  'Precision': 0.0016514270630994038,
#  'Sensitivity': 1.0,
#  'Specificity': 0.0017122360584731998}

# %%
log_score_psiblast
# Out:
# [{'Accuracy': 0.9521072796934866,
#   'F-score': 0.9512670565302145,
#   'MCC': 0.9085663242927233,
#   'Precision': 0.9070631970260223,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9100719424460432,
#   'Weighted accuracy': 0.9550359712230216},
#  {'Accuracy': 0.9582577132486388,
#   'F-score': 0.957169459962756,
#   'MCC': 0.9198108458946662,
#   'Precision': 0.9178571428571428,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9217687074829932,
#   'Weighted accuracy': 0.9608843537414966},
#  {'Accuracy': 0.9398496240601504,
#   'F-score': 0.96875,
#   'MCC': 0.32307445639837323,
#   'Precision': 0.9393939393939394,
#   'Sensitivity': 1.0,
#   'Specificity': 0.1111111111111111,
#   'Weighted accuracy': 0.5555555555555556},
#  {'Accuracy': 0.9714285714285714,
#   'F-score': 0.9722222222222222,
#   'MCC': 0.944400281603035,
#   'Precision': 0.9459459459459459,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9428571428571428,
#   'Weighted accuracy': 0.9714285714285714},
#  {'Accuracy': 0.9511278195488722,
#   'F-score': 0.9744597249508841,
#   'MCC': 0.5137529591375243,
#   'Precision': 0.9501915708812261,
#   'Sensitivity': 1.0,
#   'Specificity': 0.2777777777777778,
#   'Weighted accuracy': 0.6388888888888888},
#  {'Accuracy': 0.9541108986615678,
#   'F-score': 0.953125,
#   'MCC': 0.9122114196882196,
#   'Precision': 0.9104477611940298,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9139784946236559,
#   'Weighted accuracy': 0.956989247311828},
#  {'Accuracy': 0.9311594202898551,
#   'F-score': 0.962962962962963,
#   'MCC': 0.5658595623783126,
#   'Precision': 0.9285714285714286,
#   'Sensitivity': 1.0,
#   'Specificity': 0.3448275862068966,
#   'Weighted accuracy': 0.6724137931034483},
#  {'Accuracy': 0.9311594202898551,
#   'F-score': 0.962962962962963,
#   'MCC': 0.5658595623783126,
#   'Precision': 0.9285714285714286,
#   'Sensitivity': 1.0,
#   'Specificity': 0.3448275862068966,
#   'Weighted accuracy': 0.6724137931034483},
#  {'Accuracy': 0.9311594202898551,
#   'F-score': 0.962962962962963,
#   'MCC': 0.5658595623783126,
#   'Precision': 0.9285714285714286,
#   'Sensitivity': 1.0,
#   'Specificity': 0.3448275862068966,
#   'Weighted accuracy': 0.6724137931034483},
#  {'Accuracy': 0.9311594202898551,
#   'F-score': 0.962962962962963,
#   'MCC': 0.5658595623783126,
#   'Precision': 0.9285714285714286,
#   'Sensitivity': 1.0,
#   'Specificity': 0.3448275862068966,
#   'Weighted accuracy': 0.6724137931034483},
#  {'Accuracy': 0.9311594202898551,
#   'F-score': 0.962962962962963,
#   'MCC': 0.5658595623783126,
#   'Precision': 0.9285714285714286,
#   'Sensitivity': 1.0,
#   'Specificity': 0.3448275862068966,
#   'Weighted accuracy': 0.6724137931034483},
#  {'Accuracy': 0.9553903345724907,
#   'F-score': 0.976470588235294,
#   'MCC': 0.6177452512179262,
#   'Precision': 0.9540229885057471,
#   'Sensitivity': 1.0,
#   'Specificity': 0.4,
#   'Weighted accuracy': 0.7},
#  {'Accuracy': 0.9323308270676691,
#   'F-score': 0.96484375,
#   'MCC': 0.2214872542011953,
#   'Precision': 0.9320754716981132,
#   'Sensitivity': 1.0,
#   'Specificity': 0.05263157894736842,
#   'Weighted accuracy': 0.5263157894736842},
#  {'Accuracy': 0.942652329749104,
#   'F-score': 0.9689922480620156,
#   'MCC': 0.6490854338534775,
#   'Precision': 0.9398496240601504,
#   'Sensitivity': 1.0,
#   'Specificity': 0.4482758620689655,
#   'Weighted accuracy': 0.7241379310344828},
#  {'Accuracy': 0.9607843137254902,
#   'F-score': 0.979591836734694,
#   'MCC': 0.5066376759456405,
#   'Precision': 0.967741935483871,
#   'Sensitivity': 0.9917355371900827,
#   'Specificity': 0.38461538461538464,
#   'Weighted accuracy': 0.6881754609027336},
#  {'Accuracy': 0.966789667896679,
#   'F-score': 0.9820359281437125,
#   'MCC': 0.7857555374961619,
#   'Precision': 0.9647058823529412,
#   'Sensitivity': 1.0,
#   'Specificity': 0.64,
#   'Weighted accuracy': 0.8200000000000001},
#  {'Accuracy': 0.9851150202976996,
#   'F-score': 0.9783037475345168,
#   'MCC': 0.9675108209332924,
#   'Precision': 0.9575289575289575,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9775967413441955,
#   'Weighted accuracy': 0.9887983706720977},
#  {'Accuracy': 0.9616788321167883,
#   'F-score': 0.958904109589041,
#   'MCC': 0.9258603030033398,
#   'Precision': 0.9210526315789473,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9306930693069307,
#   'Weighted accuracy': 0.9653465346534653},
#  {'Accuracy': 0.9516728624535316,
#   'F-score': 0.973305954825462,
#   'MCC': 0.7185839205486354,
#   'Precision': 0.9713114754098361,
#   'Sensitivity': 0.9753086419753086,
#   'Specificity': 0.7307692307692307,
#   'Weighted accuracy': 0.8530389363722697},
#  {'Accuracy': 0.9868938401048493,
#   'F-score': 0.9802371541501977,
#   'MCC': 0.9708632497358547,
#   'Precision': 0.9612403100775194,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9805825242718447,
#   'Weighted accuracy': 0.9902912621359223},
#  {'Accuracy': 0.9320754716981132,
#   'F-score': 0.9647058823529412,
#   'MCC': 0.22145668244818656,
#   'Precision': 0.9318181818181818,
#   'Sensitivity': 1.0,
#   'Specificity': 0.05263157894736842,
#   'Weighted accuracy': 0.5263157894736842},
#  {'Accuracy': 0.9320754716981132,
#   'F-score': 0.9647058823529412,
#   'MCC': 0.22145668244818656,
#   'Precision': 0.9318181818181818,
#   'Sensitivity': 1.0,
#   'Specificity': 0.05263157894736842,
#   'Weighted accuracy': 0.5263157894736842},
#  {'Accuracy': 0.9320754716981132,
#   'F-score': 0.9647058823529412,
#   'MCC': 0.22145668244818656,
#   'Precision': 0.9318181818181818,
#   'Sensitivity': 1.0,
#   'Specificity': 0.05263157894736842,
#   'Weighted accuracy': 0.5263157894736842},
#  {'Accuracy': 0.9592592592592593,
#   'F-score': 0.9783037475345168,
#   'MCC': 0.6919280878563022,
#   'Precision': 0.9575289575289575,
#   'Sensitivity': 1.0,
#   'Specificity': 0.5,
#   'Weighted accuracy': 0.75},
#  {'Accuracy': 0.9591078066914498,
#   'F-score': 0.9783037475345168,
#   'MCC': 0.6752526714141045,
#   'Precision': 0.9575289575289575,
#   'Sensitivity': 1.0,
#   'Specificity': 0.47619047619047616,
#   'Weighted accuracy': 0.7380952380952381},
#  {'Accuracy': 0.9630996309963099,
#   'F-score': 0.9802371541501977,
#   'MCC': 0.7370954758229071,
#   'Precision': 0.9612403100775194,
#   'Sensitivity': 1.0,
#   'Specificity': 0.

#  {'Accuracy': 0.7137809187279152,
#   'F-score': 0.8146453089244851,
#   'MCC': 0.39634290701972047,
#   'Precision': 0.6872586872586872,
#   'Sensitivity': 1.0,
#   'Specificity': 0.22857142857142856,
#   'Weighted accuracy': 0.6142857142857143},
#  {'Accuracy': 0.7137809187279152,
#   'F-score': 0.8146453089244851,
#   'MCC': 0.39634290701972047,
#   'Precision': 0.6872586872586872,
#   'Sensitivity': 1.0,
#   'Specificity': 0.22857142857142856,
#   'Weighted accuracy': 0.6142857142857143},
#  {'Accuracy': 0.7137809187279152,
#   'F-score': 0.8146453089244851,
#   'MCC': 0.39634290701972047,
#   'Precision': 0.6872586872586872,
#   'Sensitivity': 1.0,
#   'Specificity': 0.22857142857142856,
#   'Weighted accuracy': 0.6142857142857143},
#  {'Accuracy': 0.7137809187279152,
#   'F-score': 0.8146453089244851,
#   'MCC': 0.39634290701972047,
#   'Precision': 0.6872586872586872,
#   'Sensitivity': 1.0,
#   'Specificity': 0.22857142857142856,
#   'Weighted accuracy': 0.6142857142857143},
#  {'Accuracy': 0.7137809187279152,
#   'F-score': 0.8146453089244851,
#   'MCC': 0.39634290701972047,
#   'Precision': 0.6872586872586872,
#   'Sensitivity': 1.0,
#   'Specificity': 0.22857142857142856,
#   'Weighted accuracy': 0.6142857142857143},
#  {'Accuracy': 0.7137809187279152,
#   'F-score': 0.8146453089244851,
#   'MCC': 0.39634290701972047,
#   'Precision': 0.6872586872586872,
#   'Sensitivity': 1.0,
#   'Specificity': 0.22857142857142856,
#   'Weighted accuracy': 0.6142857142857143},
#  {'Accuracy': 0.7137809187279152,
#   'F-score': 0.8146453089244851,
#   'MCC': 0.39634290701972047,
#   'Precision': 0.6872586872586872,
#   'Sensitivity': 1.0,
#   'Specificity': 0.22857142857142856,
#   'Weighted accuracy': 0.6142857142857143},
#  {'Accuracy': 0.7137809187279152,
#   'F-score': 0.8146453089244851,
#   'MCC': 0.39634290701972047,
#   'Precision': 0.6872586872586872,
#   'Sensitivity': 1.0,
#   'Specificity': 0.22857142857142856,
#   'Weighted accuracy': 0.6142857142857143},
#  {'Accuracy': 0.7137809187279152,
#   'F-score': 0.8146453089244851,
#   'MCC': 0.39634290701972047,
#   'Precision': 0.6872586872586872,
#   'Sensitivity': 1.0,
#   'Specificity': 0.22857142857142856,
#   'Weighted accuracy': 0.6142857142857143},
#  {'Accuracy': 0.7137809187279152,
#   'F-score': 0.8146453089244851,
#   'MCC': 0.39634290701972047,
#   'Precision': 0.6872586872586872,
#   'Sensitivity': 1.0,
#   'Specificity': 0.22857142857142856,
#   'Weighted accuracy': 0.6142857142857143},
#  {'Accuracy': 0.7137809187279152,
#   'F-score': 0.8146453089244851,
#   'MCC': 0.39634290701972047,
#   'Precision': 0.6872586872586872,
#   'Sensitivity': 1.0,
#   'Specificity': 0.22857142857142856,
#   'Weighted accuracy': 0.6142857142857143},
#  {'Accuracy': 0.7137809187279152,
#   'F-score': 0.8146453089244851,
#   'MCC': 0.39634290701972047,
#   'Precision': 0.6872586872586872,
#   'Sensitivity': 1.0,
#   'Specificity': 0.22857142857142856,
#   'Weighted accuracy': 0.6142857142857143},
#  {'Accuracy': 0.7137809187279152,
#   'F-score': 0.8146453089244851,
#   'MCC': 0.39634290701972047,
#   'Precision': 0.6872586872586872,
#   'Sensitivity': 1.0,
#   'Specificity': 0.22857142857142856,
#   'Weighted accuracy': 0.6142857142857143},
#  {'Accuracy': 0.7137809187279152,
#   'F-score': 0.8146453089244851,
#   'MCC': 0.39634290701972047,
#   'Precision': 0.6872586872586872,
#   'Sensitivity': 1.0,
#   'Specificity': 0.22857142857142856,
#   'Weighted accuracy': 0.6142857142857143},
#  {'Accuracy': 0.7137809187279152,
#   'F-score': 0.8146453089244851,
#   'MCC': 0.39634290701972047,
#   'Precision': 0.6872586872586872,
#   'Sensitivity': 1.0,
#   'Specificity': 0.22857142857142856,
#   'Weighted accuracy': 0.6142857142857143},
#  {'Accuracy': 0.7137809187279152,
#   'F-score': 0.8146453089244851,
#   'MCC': 0.39634290701972047,
#   'Precision': 0.6872586872586872,
#   'Sensitivity': 1.0,
#   'Specificity': 0.22857142857142856,
#   'Weighted accuracy': 0.6142857142857143},
#  {'Accuracy': 0.7137809187279152,
#   'F-score': 0.8146453089244851,
#   'MCC': 0.39634290701972047,
#   'Precision': 0.6872586872586872,
#   'Sensitivity': 1.0,
#   'Specificity': 0.22857142857142856,
#   'Weighted accuracy': 0.6142857142857143},
#  {'Accuracy': 0.7137809187279152,
#   'F-score': 0.8146453089244851,
#   'MCC': 0.39634290701972047,
#   'Precision': 0.6872586872586872,
#   'Sensitivity': 1.0,
#   'Specificity': 0.22857142857142856,
#   'Weighted accuracy': 0.6142857142857143},
#  {'Accuracy': 0.7137809187279152,
#   'F-score': 0.8146453089244851,
#   'MCC': 0.39634290701972047,
#   'Precision': 0.6872586872586872,
#   'Sensitivity': 1.0,
#   'Specificity': 0.22857142857142856,
#   'Weighted accuracy': 0.6142857142857143},
#  {'Accuracy': 0.7137809187279152,
#   'F-score': 0.8146453089244851,
#   'MCC': 0.39634290701972047,
#   'Precision': 0.6872586872586872,
#   'Sensitivity': 1.0,
#   'Specificity': 0.22857142857142856,
#   'Weighted accuracy': 0.6142857142857143},
#  {'Accuracy': 0.7137809187279152,
#   'F-score': 0.8146453089244851,
#   'MCC': 0.39634290701972047,
#   'Precision': 0.6872586872586872,
#   'Sensitivity': 1.0,
#   'Specificity': 0.22857142857142856,
#   'Weighted accuracy': 0.6142857142857143},
#  {'Accuracy': 0.7137809187279152,
#   'F-score': 0.8146453089244851,
#   'MCC': 0.39634290701972047,
#   'Precision': 0.6872586872586872,
#   'Sensitivity': 1.0,
#   'Specificity': 0.22857142857142856,
#   'Weighted accuracy': 0.6142857142857143},
#  {'Accuracy': 0.7137809187279152,
#   'F-score': 0.8146453089244851,
#   'MCC': 0.39634290701972047,
#   'Precision': 0.6872586872586872,
#   'Sensitivity': 1.0,
#   'Specificity': 0.22857142857142856,
#   'Weighted accuracy': 0.6142857142857143},
#  {'Accuracy': 0.7137809187279152,
#   'F-score': 0.8146453089244851,
#   'MCC': 0.39634290701972047,
#   'Precision': 0.6872586872586872,
#   'Sensitivity': 1.0,
#   'Specificity': 0.22857142857142856,
#   'Weighted accuracy': 0.6142857142857143},
#  {'Accuracy': 0.7137809187279152,
#   'F-score': 0.8146453089244851,
#   'MCC': 0.39634290701972047,
#   'Precision': 0.6872586872586872,
#   'Sensitivity': 1.0,
#   'Specificity': 0.22857142857142856,
#   'Weighted accuracy': 0.6142857142857143},
#  {'Accuracy': 0.777027027027027,
#   'F-score': 0.8428571428571429,
#   'MCC': 0.5695711070444791,
#   'Precision': 0.7283950617283951,
#   'Sensitivity': 1.0,
#   'Specificity': 0.44537815126050423,
#   'Weighted accuracy': 0.7226890756302521},
#  {'Accuracy': 0.7534722222222222,
#   'F-score': 0.8446389496717724,
#   'MCC': 0.41662239443911303,
#   'Precision': 0.7338403041825095,
#   'Sensitivity': 0.9948453608247423,
#   'Specificity': 0.2553191489361702,
#   'Weighted accuracy': 0.6250822548804562},
#  {'Accuracy': 0.7534722222222222,
#   'F-score': 0.8446389496717724,
#   'MCC': 0.41662239443911303,
#   'Precision': 0.7338403041825095,
#   'Sensitivity': 0.9948453608247423,
#   'Specificity': 0.2553191489361702,
#   'Weighted accuracy': 0.6250822548804562},
#  {'Accuracy': 0.71875,
#   'F-score': 0.8137931034482759,
#   'MCC': 0.43060187658166393,
#   'Precision': 0.686046511627907,
#   'Sensitivity': 1.0,
#   'Specificity': 0.2702702702702703,
#   'Weighted accuracy': 0.6351351351351351},
#  {'Accuracy': 0.71875,
#   'F-score': 0.8137931034482759,
#   'MCC': 0.43060187658166393,
#   'Precision': 0.686046511627907,
#   'Sensitivity': 1.0,
#   'Specificity': 0.2702702702702703,
#   'Weighted accuracy': 0.6351351351351351},
#  {'Accuracy': 0.71875,
#   'F-score': 0.8137931034482759,
#   'MCC': 0.43060187658166393,
#   'Precision': 0.686046511627907,
#   'Sensitivity': 1.0,
#   'Specificity': 0.2702702702702703,
#   'Weighted accuracy': 0.6351351351351351},
#  {'Accuracy': 0.71875,
#   'F-score': 0.8137931034482759,
#   'MCC': 0.43060187658166393,
#   'Precision': 0.686046511627907,
#   'Sensitivity': 1.0,
#   'Specificity': 0.2702702702702703,
#   'Weighted accuracy': 0.6351351351351351},
#  {'Accuracy': 0.7051282051282052,
#   'F-score': 0.7982456140350876,
#   'MCC': 0.44063656673227414,
#   'Precision': 0.6642335766423357,
#   'Sensitivity': 1.0,
#   'Specificity': 0.2923076923076923,
#   'Weighted accuracy': 0.6461538461538462},
#  {'Accuracy': 0.7681660899653979,
#   'F-score': 0.8546637744034707,
#   'MCC': 0.450305488460974,
#   'Precision': 0.7462121212121212,
#   'Sensitivity': 1.0,
#   'Specificity': 0.2717391304347826,
#   'Weighted accuracy': 0.6358695652173914},
#  {'Accuracy': 0.7377622377622378,
#   'F-score': 0.840764331210191,
#   'MCC': 0.3273268353539886,
#   'Precision': 0.7252747252747253,
#   'Sensitivity': 1.0,
#   'Specificity': 0.14772727272727273,
#   'Weighted accuracy': 0.5738636363636364},
#  {'Accuracy': 0.6784452296819788,
#   'F-score': 0.800875273522976,
#   'MCC': 0.2451723660021555,
#   'Precision': 0.6678832116788321,
#   'Sensitivity': 1.0,
#   'Specificity': 0.09,
#   'Weighted accuracy': 0.545},
#  {'Accuracy': 0.6784452296819788,
#   'F-score': 0.800875273522976,
#   'MCC': 0.2451723660021555,
#   'Precision': 0.6678832116788321,
#   'Sensitivity': 1.0,
#   'Specificity': 0.09,
#   'Weighted accuracy': 0.545},
#  {'Accuracy': 0.5242718446601942,
#   'F-score': 0.592797783933518,
#   'MCC': 0.33867309026875975,
#   'Precision': 0.421259842519685,
#   'Sensitivity': 1.0,
#   'Specificity': 0.
#
# CONFUSION MATRIX
#                Actual positive  Actual negative
# Positive pred            25323              951
# Negative pred             3886            15377

# %%
metrics_global_hmm
# Out:
# {'Accuracy': 0.00891588785046729,
#  'F1-score': 0.00900850387814223,
#  'MCC': -0.012017725454758646,
#  'Precision': 0.004524971836274878,
#  'Sensitivity': 0.9836734693877551,
#  'Specificity': 0.004431508778518449}

# %%
log_score_hmm
# Out:
# [{'Accuracy': 0.9734693877551021,
#   'F-score': 0.9737373737373737,
#   'MCC': 0.9471360338761622,
#   'Precision': 0.964,
#   'Sensitivity': 0.9836734693877551,
#   'Specificity': 0.963265306122449,
#   'Weighted accuracy': 0.9734693877551021},
#  {'Accuracy': 0.9726277372262774,
#   'F-score': 0.9696969696969697,
#   'MCC': 0.9449035066900258,
#   'Precision': 0.96,
#   'Sensitivity': 0.9795918367346939,
#   'Specificity': 0.966996699669967,
#   'Weighted accuracy': 0.9732942682023304},
#  {'Accuracy': 0.9398496240601504,
#   'F-score': 0.967871485943775,
#   'MCC': 0.5017285475203439,
#   'Precision': 0.9601593625498008,
#   'Sensitivity': 0.9757085020242915,
#   'Specificity': 0.47368421052631576,
#   'Weighted accuracy': 0.7246963562753036},
#  {'Accuracy': 0.9516728624535316,
#   'F-score': 0.9741550695825051,
#   'MCC': 0.6104374621209737,
#   'Precision': 0.9645669291338582,
#   'Sensitivity': 0.9839357429718876,
#   'Specificity': 0.55,
#   'Weighted accuracy': 0.7669678714859438},
#  {'Accuracy': 0.9712643678160919,
#   'F-score': 0.9696969696969696,
#   'MCC': 0.9427257693209954,
#   'Precision': 0.9561752988047809,
#   'Sensitivity': 0.9836065573770492,
#   'Specificity': 0.960431654676259,
#   'Weighted accuracy': 0.9720191060266541},
#  {'Accuracy': 0.943609022556391,
#   'F-score': 0.9698189134808854,
#   'MCC': 0.5415271450304141,
#   'Precision': 0.9678714859437751,
#   'Sensitivity': 0.9717741935483871,
#   'Specificity': 0.5555555555555556,
#   'Weighted accuracy': 0.7636648745519714},
#  {'Accuracy': 0.9330855018587361,
#   'F-score': 0.9632653061224489,
#   'MCC': 0.5910209337705788,
#   'Precision': 0.9554655870445344,
#   'Sensitivity': 0.9711934156378601,
#   'Specificity': 0.5769230769230769,
#   'Weighted accuracy': 0.7740582462804685},
#  {'Accuracy': 0.9473684210526315,
#   'F-score': 0.9718875502008033,
#   'MCC': 0.5613356128475158,
#   'Precision': 0.968,
#   'Sensitivity': 0.9758064516129032,
#   'Specificity': 0.5555555555555556,
#   'Weighted accuracy': 0.7656810035842294},
#  {'Accuracy': 0.9433962264150944,
#   'F-score': 0.9699398797595191,
#   'MCC': 0.5022568799137046,
#   'Precision': 0.9565217391304348,
#   'Sensitivity': 0.983739837398374,
#   'Specificity': 0.42105263157894735,
#   'Weighted accuracy': 0.7023962344886607},
#  {'Accuracy': 0.9433962264150944,
#   'F-score': 0.9699398797595191,
#   'MCC': 0.5022568799137046,
#   'Precision': 0.9565217391304348,
#   'Sensitivity': 0.983739837398374,
#   'Specificity': 0.42105263157894735,
#   'Weighted accuracy': 0.7023962344886607},
#  {'Accuracy': 0.9433962264150944,
#   'F-score': 0.9699398797595191,
#   'MCC': 0.5022568799137046,
#   'Precision': 0.9565217391304348,
#   'Sensitivity': 0.983739837398374,
#   'Specificity': 0.42105263157894735,
#   'Weighted accuracy': 0.7023962344886607},
#  {'Accuracy': 0.9565217391304348,
#   'F-score': 0.9760956175298805,
#   'MCC': 0.7483806075862223,
#   'Precision': 0.9607843137254902,
#   'Sensitivity': 0.9919028340080972,
#   'Specificity': 0.6551724137931034,
#   'Weighted accuracy': 0.8235376239006003},
#  {'Accuracy': 0.9565217391304348,
#   'F-score': 0.9760956175298805,
#   'MCC': 0.7483806075862223,
#   'Precision': 0.9607843137254902,
#   'Sensitivity': 0.9919028340080972,
#   'Specificity': 0.6551724137931034,
#   'Weighted accuracy': 0.8235376239006003},
#  {'Accuracy': 0.9565217391304348,
#   'F-score': 0.9760956175298805,
#   'MCC': 0.7483806075862223,
#   'Precision': 0.9607843137254902,
#   'Sensitivity': 0.9919028340080972,
#   'Specificity': 0.6551724137931034,
#   'Weighted accuracy': 0.8235376239006003},
#  {'Accuracy': 0.9565217391304348,
#   'F-score': 0.9760956175298805,
#   'MCC': 0.7483806075862223,
#   'Precision': 0.9607843137254902,
#   'Sensitivity': 0.9919028340080972,
#   'Specificity': 0.6551724137931034,
#   'Weighted accuracy': 0.8235376239006003},
#  {'Accuracy': 0.9565217391304348,
#   'F-score': 0.9760956175298805,
#   'MCC': 0.7483806075862223,
#   'Precision': 0.9607843137254902,
#   'Sensitivity': 0.9919028340080972,
#   'Specificity': 0.6551724137931034,
#   'Weighted accuracy': 0.8235376239006003},
#  {'Accuracy': 0.966789667896679,
#   'F-score': 0.9818181818181818,
#   'MCC': 0.7923459414522204,
#   'Precision': 0.9759036144578314,
#   'Sensitivity': 0.9878048780487805,
#   'Specificity': 0.76,
#   'Weighted accuracy': 0.8739024390243902},
#  {'Accuracy': 0.9732313575525813,
#   'F-score': 0.97165991902834,
#   'MCC': 0.9465553534032797,
#   'Precision': 0.96,
#   'Sensitivity': 0.9836065573770492,
#   'Specificity': 0.96415770609319,
#   'Weighted accuracy': 0.9738821317351196},
#  {'Accuracy': 0.956989247311828,
#   'F-score': 0.976190476190476,
#   'MCC': 0.7566586450877236,
#   'Precision': 0.968503937007874,
#   'Sensitivity': 0.984,
#   'Specificity': 0.7241379310344828,
#   'Weighted accuracy': 0.8540689655172413},
#  {'Accuracy': 0.9742895805142084,
#   'F-score': 0.9619238476953909,
#   'MCC': 0.9425561714985242,
#   'Precision': 0.9561752988047809,
#   'Sensitivity': 0.967741935483871,
#   'Specificity': 0.9775967413441955,
#   'Weighted accuracy': 0.9726693384140332},
#  {'Accuracy': 0.9505703422053232,
#   'F-score': 0.9737373737373738,
#   'MCC': 0.5724157662267353,
#   'Precision': 0.9601593625498008,
#   'Sensitivity': 0.9877049180327869,
#   'Specificity': 0.47368421052631576,
#   'Weighted accuracy': 0.7306945642795514},
#  {'Accuracy': 0.9782214156079855,
#   'F-score': 0.9770114942528736,
#   'MCC': 0.956736594620131,
#   'Precision': 0.9622641509433962,
#   'Sensitivity': 0.9922178988326849,
#   'Specificity': 0.9659863945578231,
#   'Weighted accuracy': 0.979102146695254},
#  {'Accuracy': 0.9686274509803922,
#   'F-score': 0.983739837398374,
#   'MCC': 0.6101702158477521,
#   'Precision': 0.968,
#   'Sensitivity': 1.0,
#   'Specificity': 0.38461538461538464,
#   'Weighted accuracy': 0.6923076923076923},
#  {'Accuracy': 0.9442379182156134,
#   'F-score': 0.9700598802395209,
#   'MCC': 0.5712714903795025,
#   'Precision': 0.9604743083003953,
#   'Sensitivity': 0.9798387096774194,
#   'Specificity': 0.5238095238095238,
#   'Weighted accuracy': 0.7518241167434716},
#  {'Accuracy': 0.9407407407407408,
#   'F-score': 0.9681274900398407,
#   'MCC': 0.5559754458088889,
#   'Precision': 0.9566929133858267,
#   'Sensitivity': 0.9798387096774194,
#   'Specificity': 0.5,
#   'Weighted accuracy': 0.7399193548387097},
#  {'Accuracy': 0.9737876802096985,
#   'F-score': 0.9598393574297188,
#   'MCC': 0.9404012813846199,
#   'Precision': 0.956,
#   'Sensitivity': 0.9637096774193549,
#   'Specificity': 0.9786407766990292,
#   'Weighted accuracy': 0.971175227059192},
#  {'Accuracy': 0.9745916515426497,
#   'F-score': 0.9726562499999999,
#   'MCC': 0.9495759870136153,
#   'Precision': 0.9540229885057471,
#   'Sensitivity': 0.9920318725099602,
#   'Specificity': 0.96,
#   'Weighted accuracy': 0.9760159362549801},
#  {'Accuracy': 0.9745916515426497,
#   'F-score': 0.9726562499999999,
#   'MCC': 0.9495759870136153,
#   'Precision': 0.9540229885057471,
#   'Sensitivity': 0.9920318725099602,
#   'Specificity': 0.96,
#   'Weighted accuracy': 0.9760159362549801},
#  {'Accuracy': 0.948339483394834,
#   'F-score': 0.9717741935483871,
#   'MCC': 0.6674263674614306,
#   'Precision': 0.9717741935483871,
#   'Sensitivity': 0.9717741935483871,
#   'Specificity': 0.6956521739130435,
#   'Weighted accuracy': 0.8337131837307152},
#  {'Accuracy': 0.9420289855072463,
#   'F-score': 0.9676113360323887,
#   'MCC': 0.6917492670668715,
#   'Precision': 0.9676113360323887,
#   'Sensitivity': 0.9676113360323887,
#   'Specificity': 0.7241379310344828,
#   'Weighted accuracy': 0.8458746335334357},
#  {'Accuracy': 0.9737762237762237,
#   'F-score': 0.970873786407767,
#   'MCC': 0.9475181407084856,
#   'Precision': 0.9541984732824428,
#   'Sensitivity': 0.9881422924901185,
#   'Specificity': 0.9623824451410659,
#   'Weighted accuracy': 0.9752623688155921},
#  {'Accuracy': 0.9420289855072463,
#   'F-score': 0.9676113360323887,
#   'MCC': 0.6917492670668715,
#   'Precision': 0.9676113360323887,
#   'Sensitivity': 0.9676113360323887,
#   'Specificity': 0.7241379310344828,
#   'Weighted accuracy': 0.8458746335334357},
#  {'Accuracy': 0.9420289855072463,
#   'F-score': 0.9676113360323887,
#   'MCC': 0.6917492670668715,
#   'Precision': 0.9676113360323887,
#   'Sensitivity': 0.9676113360323887,
#   'Specificity': 0.7241379310344828,
#   'Weighted accuracy': 0.8458746335334357},
#  {'Accuracy': 0.9553903345724907,
#   'F-score': 0.9759036144578314,
#   'MCC': 0.6769565953823716,
#   'Precision': 0.972,
#   'Sensitivity': 0.9798387096774194,
#   'Specificity': 0.6666666666666666,
#   'Weighted accuracy': 0.823252688172043},
#  {'Accuracy': 0.8873517786561265,
#   'F-score': 0.8834355828220859,
#   'MCC': 0.7850759359258491,
#   'Precision': 0.96,
#   'Sensitivity': 0.8181818181818182,
#   'Specificity': 0.9628099173553719,
#   'Weighted accuracy': 0.890495867768595},
#  {'Accuracy': 0.9571865443425076,
#   'F-score': 0.9730769230769232,
#   'MCC': 0.8765251772048047,
#   'Precision': 0.947565543071161,
#   'Sensitivity': 1.0,
#   'Specificity': 0.

#   'Sensitivity': 1.0,
#   'Specificity': 0.9903846153846154,
#   'Weighted accuracy': 0.9951923076923077},
#  {'Accuracy': 1.0,
#   'F-score': 1.0,
#   'MCC': 1.0,
#   'Precision': 1.0,
#   'Sensitivity': 1.0,
#   'Specificity': 1.0,
#   'Weighted accuracy': 1.0},
#  {'Accuracy': 0.9930795847750865,
#   'F-score': 0.9946236559139785,
#   'MCC': 0.9849149180499008,
#   'Precision': 0.9946236559139785,
#   'Sensitivity': 0.9946236559139785,
#   'Specificity': 0.9902912621359223,
#   'Weighted accuracy': 0.9924574590249504},
#  {'Accuracy': 0.9583333333333334,
#   'F-score': 0.9695431472081217,
#   'MCC': 0.9047077327383709,
#   'Precision': 0.955,
#   'Sensitivity': 0.9845360824742269,
#   'Specificity': 0.9042553191489362,
#   'Weighted accuracy': 0.9443957008115815},
#  {'Accuracy': 0.9896193771626297,
#   'F-score': 0.9919137466307278,
#   'MCC': 0.9774489708382916,
#   'Precision': 0.9945945945945946,
#   'Sensitivity': 0.989247311827957,
#   'Specificity': 0.9902912621359223,
#   'Weighted accuracy': 0.9897692869819397},
#  {'Accuracy': 0.9195804195804196,
#   'F-score': 0.9411764705882352,
#   'MCC': 0.8148354608738259,
#   'Precision': 0.9292929292929293,
#   'Sensitivity': 0.9533678756476683,
#   'Specificity': 0.8494623655913979,
#   'Weighted accuracy': 0.9014151206195331},
#  {'Accuracy': 0.9858657243816255,
#   'F-score': 0.9891891891891893,
#   'MCC': 0.9692601511677407,
#   'Precision': 0.9786096256684492,
#   'Sensitivity': 1.0,
#   'Specificity': 0.96,
#   'Weighted accuracy': 0.98},
#  {'Accuracy': 0.9858657243816255,
#   'F-score': 0.9891891891891893,
#   'MCC': 0.9692601511677407,
#   'Precision': 0.9786096256684492,
#   'Sensitivity': 1.0,
#   'Specificity': 0.96,
#   'Weighted accuracy': 0.98},
#  {'Accuracy': 0.9125874125874126,
#   'F-score': 0.9347258485639687,
#   'MCC': 0.8058201028150206,
#   'Precision': 0.9086294416243654,
#   'Sensitivity': 0.9623655913978495,
#   'Specificity': 0.82,
#   'Weighted accuracy': 0.8911827956989247},
#  {'Accuracy': 0.7062937062937062,
#   'F-score': 0.7307692307692308,
#   'MCC': 0.5427463895880401,
#   'Precision': 1.0,
#   'Sensitivity': 0.5757575757575758,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7878787878787878},
#  {'Accuracy': 0.9335664335664335,
#   'F-score': 0.9518987341772152,
#   'MCC': 0.8445845904058519,
#   'Precision': 0.9494949494949495,
#   'Sensitivity': 0.9543147208121827,
#   'Specificity': 0.8876404494382022,
#   'Weighted accuracy': 0.9209775851251925},
#  {'Accuracy': 0.9335664335664335,
#   'F-score': 0.9518987341772152,
#   'MCC': 0.8445845904058519,
#   'Precision': 0.9494949494949495,
#   'Sensitivity': 0.9543147208121827,
#   'Specificity': 0.8876404494382022,
#   'Weighted accuracy': 0.9209775851251925},
#  {'Accuracy': 0.9195804195804196,
#   'F-score': 0.9411764705882352,
#   'MCC': 0.8148354608738259,
#   'Precision': 0.9292929292929293,
#   'Sensitivity': 0.9533678756476683,
#   'Specificity': 0.8494623655913979,
#   'Weighted accuracy': 0.9014151206195331},
#  {'Accuracy': 0.9967948717948718,
#   'F-score': 0.9972602739726028,
#   'MCC': 0.9934209812066782,
#   'Precision': 0.994535519125683,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9923076923076923,
#   'Weighted accuracy': 0.9961538461538462},
#  {'Accuracy': 1.0,
#   'F-score': 1.0,
#   'MCC': 1.0,
#   'Precision': 1.0,
#   'Sensitivity': 1.0,
#   'Specificity': 1.0,
#   'Weighted accuracy': 1.0},
#  {'Accuracy': 0.9475524475524476,
#   'F-score': 0.9584487534626039,
#   'MCC': 0.8933423917420741,
#   'Precision': 0.9202127659574468,
#   'Sensitivity': 1.0,
#   'Specificity': 0.8672566371681416,
#   'Weighted accuracy': 0.9336283185840708},
#  {'Accuracy': 0.9399293286219081,
#   'F-score': 0.9510086455331412,
#   'MCC': 0.8808986843469497,
#   'Precision': 0.9065934065934066,
#   'Sensitivity': 1.0,
#   'Specificity': 0.8559322033898306,
#   'Weighted accuracy': 0.9279661016949152},
#  {'Accuracy': 0.7628205128205128,
#   'F-score': 0.7430555555555557,
#   'MCC': 0.6146265530852415,
#   'Precision': 1.0,
#   'Sensitivity': 0.5911602209944752,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7955801104972375},
#  {'Accuracy': 0.7660256410256411,
#   'F-score': 0.7474048442906575,
#   'MCC': 0.6190035709626225,
#   'Precision': 1.0,
#   'Sensitivity': 0.5966850828729282,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7983425414364641},
#  {'Accuracy': 0.9838187702265372,
#   'F-score': 0.9760765550239235,
#   'MCC': 0.9644921761190882,
#   'Precision': 1.0,
#   'Sensitivity': 0.9532710280373832,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.9766355140186915},
#  {'Accuracy': 0.8964401294498382,
#   'F-score': 0.9053254437869822,
#   'MCC': 0.8107900205234753,
#   'Precision': 0.827027027027027,
#   'Sensitivity': 1.0,
#   'Specificity': 0.7948717948717948,
#   'Weighted accuracy': 0.8974358974358974},
#  {'Accuracy': 0.7670807453416149,
#   'F-score': 0.7386759581881532,
#   'MCC': 0.6182958420625582,
#   'Precision': 1.0,
#   'Sensitivity': 0.585635359116022,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7928176795580111},
#  {'Accuracy': 0.9823321554770318,
#   'F-score': 0.986449864498645,
#   'MCC': 0.9618111786460244,
#   'Precision': 0.9732620320855615,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9504950495049505,
#   'Weighted accuracy': 0.9752475247524752},
#  {'Accuracy': 0.7660256410256411,
#   'F-score': 0.7456445993031359,
#   'MCC': 0.61356254994377,
#   'Precision': 0.9907407407407407,
#   'Sensitivity': 0.5977653631284916,
#   'Specificity': 0.9924812030075187,
#   'Weighted accuracy': 0.7951232830680052},
#  {'Accuracy': 0.7197231833910035,
#   'F-score': 0.7412140575079872,
#   'MCC': 0.5595858751191587,
#   'Precision': 1.0,
#   'Sensitivity': 0.5888324873096447,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7944162436548223},
#  {'Accuracy': 0.7735191637630662,
#   'F-score': 0.7909967845659164,
#   'MCC': 0.6284479361972941,
#   'Precision': 1.0,
#   'Sensitivity': 0.6542553191489362,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.8271276595744681},
#  {'Accuracy': 0.7724358974358975,
#   'F-score': 0.7543252595155708,
#   'MCC': 0.6275031973829137,
#   'Precision': 1.0,
#   'Sensitivity': 0.6055555555555555,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.8027777777777778},
#  {'Accuracy': 0.6993006993006993,
#   'F-score': 0.7171052631578948,
#   'MCC': 0.5360804954032455,
#   'Precision': 1.0,
#   'Sensitivity': 0.558974358974359,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7794871794871795},
#  {'Accuracy': 0.698961937716263,
#   'F-score': 0.7147540983606556,
#   'MCC': 0.4974556564950586,
#   'Precision': 0.9478260869565217,
#   'Sensitivity': 0.5736842105263158,
#   'Specificity': 0.9393939393939394,
#   'Weighted accuracy': 0.7565390749601276},
#  {'Accuracy': 0.7307692307692307,
#   'F-score': 0.7372013651877133,
#   'MCC': 0.5755415728117464,
#   'Precision': 1.0,
#   'Sensitivity': 0.5837837837837838,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7918918918918919},
#  {'Accuracy': 0.7307692307692307,
#   'F-score': 0.7372013651877133,
#   'MCC': 0.5755415728117464,
#   'Precision': 1.0,
#   'Sensitivity': 0.5837837837837838,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7918918918918919},
#  {'Accuracy': 0.9517241379310345,
#   'F-score': 0.9565217391304348,
#   'MCC': 0.9068097493789022,
#   'Precision': 0.9166666666666666,
#   'Sensitivity': 1.0,
#   'Specificity': 0.8970588235294118,
#   'Weighted accuracy': 0.9485294117647058},
#  {'Accuracy': 0.7307692307692307,
#   'F-score': 0.7372013651877133,
#   'MCC': 0.5755415728117464,
#   'Precision': 1.0,
#   'Sensitivity': 0.5837837837837838,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7918918918918919},
#  {'Accuracy': 0.7097902097902098,
#   'F-score': 0.71864406779661,
#   'MCC': 0.5497581104556419,
#   'Precision': 1.0,
#   'Sensitivity': 0.5608465608465608,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7804232804232805},
#  {'Accuracy': 0.7097902097902098,
#   'F-score': 0.71864406779661,
#   'MCC': 0.5497581104556419,
#   'Precision': 1.0,
#   'Sensitivity': 0.5608465608465608,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7804232804232805},
#  {'Accuracy': 0.7097902097902098,
#   'F-score': 0.71864406779661,
#   'MCC': 0.5497581104556419,
#   'Precision': 1.0,
#   'Sensitivity': 0.5608465608465608,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7804232804232805},
#  {'Accuracy': 0.7097902097902098,
#   'F-score': 0.71864406779661,
#   'MCC': 0.5497581104556419,
#   'Precision': 1.0,
#   'Sensitivity': 0.5608465608465608,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7804232804232805},
#  {'Accuracy': 0.8464912280701754,
#   'F-score': 0.8605577689243028,
#   'MCC': 0.7314130399200133,
#   'Precision': 1.0,
#   'Sensitivity': 0.7552447552447552,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.8776223776223776},
#  {'Accuracy': 0.9895833333333334,
#   'F-score': 0.9919571045576407,
#   'MCC': 0.9774359925864138,
#   'Precision': 1.0,
#   'Sensitivity': 0.9840425531914894,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.9920212765957447},
#  {'Accuracy': 0.788235294117647,
#   'F-score': 0.7464788732394366,
#   'MCC': 0.6333321288881192,
#   'Precision': 0.9814814814814815,
#   'Sensitivity': 0.6022727272727273,
#   'Specificity': 0.9878048780487805,
#   'Weighted accuracy': 0.7950388026607539},
#  {'Accuracy': 0.7251655629139073,
#   'F-score': 0.6867924528301886,
#   'MCC': 0.5632611910678613,
#   'Precision': 1.0,
#   'Sensitivity': 0.5229885057471264,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7614942528735632},
#  {'Accuracy': 0.7212543554006968,
#   'F-score': 0.7333333333333334,
#   'MCC': 0.5632727948792533,
#   'Precision': 1.0,
#   'Sensitivity': 0.5789473684210527,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7894736842105263},
#  {'Accuracy': 0.7212543554006968,
#   'F-score': 0.7333333333333334,
#   'MCC': 0.5632727948792533,
#   'Precision': 1.0,
#   'Sensitivity': 0.5789473684210527,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7894736842105263},
#  {'Accuracy': 0.7212543554006968,
#   'F-score': 0.7333333333333334,
#   'MCC': 0.5632727948792533,
#   'Precision': 1.0,
#   'Sensitivity': 0.5789473684210527,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7894736842105263},
#  {'Accuracy': 0.7212543554006968,
#   'F-score': 0.7333333333333334,
#   'MCC': 0.5632727948792533,
#   'Precision': 1.0,
#   'Sensitivity': 0.5789473684210527,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7894736842105263},
#  {'Accuracy': 0.7212543554006968,
#   'F-score': 0.7333333333333334,
#   'MCC': 0.5632727948792533,
#   'Precision': 1.0,
#   'Sensitivity': 0.5789473684210527,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7894736842105263},
#  {'Accuracy': 0.7212543554006968,
#   'F-score': 0.7333333333333334,
#   'MCC': 0.5632727948792533,
#   'Precision': 1.0,
#   'Sensitivity': 0.5789473684210527,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7894736842105263},
#  {'Accuracy': 0.7212543554006968,
#   'F-score': 0.7333333333333334,
#   'MCC': 0.5632727948792533,
#   'Precision': 1.0,
#   'Sensitivity': 0.5789473684210527,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7894736842105263},
#  {'Accuracy': 0.7212543554006968,
#   'F-score': 0.7333333333333334,
#   'MCC': 0.5632727948792533,
#   'Precision': 1.0,
#   'Sensitivity': 0.5789473684210527,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7894736842105263},
#  {'Accuracy': 0.7212543554006968,
#   'F-score': 0.7315436241610739,
#   'MCC': 0.5634889235450589,
#   'Precision': 1.0,
#   'Sensitivity': 0.5767195767195767,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7883597883597884},
#  {'Accuracy': 0.7212543554006968,
#   'F-score': 0.7333333333333334,
#   'MCC': 0.5632727948792533,
#   'Precision': 1.0,
#   'Sensitivity': 0.5789473684210527,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7894736842105263},
#  {'Accuracy': 0.9765886287625418,
#   'F-score': 0.9801699716713881,
#   'MCC': 0.9527413339320994,
#   'Precision': 1.0,
#   'Sensitivity': 0.9611111111111111,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.9805555555555556},
#  {'Accuracy': 0.7281879194630873,
#   'F-score': 0.6966292134831461,
#   'MCC': 0.5505418697537773,
#   'Precision': 0.96875,
#   'Sensitivity': 0.543859649122807,
#   'Specificity': 0.9763779527559056,
#   'Weighted accuracy': 0.7601188009393562},
#  {'Accuracy': 0.7448275862068966,
#   'F-score': 0.7448275862068965,
#   'MCC': 0.5934065934065934,
#   'Precision': 1.0,
#   'Sensitivity': 0.5934065934065934,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7967032967032968},
#  {'Accuracy': 0.9615384615384616,
#   'F-score': 0.9721518987341773,
#   'MCC': 0.9125806477509484,
#   'Precision': 0.9504950495049505,
#   'Sensitivity': 0.9948186528497409,
#   'Specificity': 0.8924731182795699,
#   'Weighted accuracy': 0.9436458855646555},
#  {'Accuracy': 0.7517241379310344,
#   'F-score': 0.7534246575342465,
#   'MCC': 0.6021937915964948,
#   'Precision': 1.0,
#   'Sensitivity': 0.6043956043956044,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.8021978021978022},
#  {'Accuracy': 0.9651567944250871,
#   'F-score': 0.9747474747474748,
#   'MCC': 0.9197065816384945,
#   'Precision': 0.9601990049751243,
#   'Sensitivity': 0.9897435897435898,
#   'Specificity': 0.9130434782608695,
#   'Weighted accuracy': 0.9513935340022297},
#  {'Accuracy': 0.9686411149825784,
#   'F-score': 0.9773299748110831,
#   'MCC': 0.9280500398459434,
#   'Precision': 0.9603960396039604,
#   'Sensitivity': 0.9948717948717949,
#   'Specificity': 0.9130434782608695,
#   'Weighted accuracy': 0.9539576365663323},
#  {'Accuracy': 0.7447552447552448,
#   'F-score': 0.7456445993031359,
#   'MCC': 0.587331958580525,
#   'Precision': 0.9907407407407407,
#   'Sensitivity': 0.5977653631284916,
#   'Specificity': 0.9906542056074766,
#   'Weighted accuracy': 0.7942097843679841},
#  {'Accuracy': 0.9895104895104895,
#   'F-score': 0.9919137466307278,
#   'MCC': 0.9770174242241496,
#   'Precision': 0.989247311827957,
#   'Sensitivity': 0.9945945945945946,
#   'Specificity': 0.9801980198019802,
#   'Weighted accuracy': 0.9873963071982874},
#  {'Accuracy': 0.7413793103448276,
#   'F-score': 0.7440273037542662,
#   'MCC': 0.5890036453698295,
#   'Precision': 1.0,
#   'Sensitivity': 0.592391304347826,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7961956521739131},
#  {'Accuracy': 0.7413793103448276,
#   'F-score': 0.7440273037542662,
#   'MCC': 0.5890036453698295,
#   'Precision': 1.0,
#   'Sensitivity': 0.592391304347826,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7961956521739131},
#  {'Accuracy': 0.7448275862068966,
#   'F-score': 0.7549668874172186,
#   'MCC': 0.5928123641025734,
#   'Precision': 1.0,
#   'Sensitivity': 0.6063829787234043,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.8031914893617021},
#  {'Accuracy': 0.9861111111111112,
#   'F-score': 0.9891891891891893,
#   'MCC': 0.970221242282562,
#   'Precision': 1.0,
#   'Sensitivity': 0.9786096256684492,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.9893048128342246},
#  {'Accuracy': 0.7448275862068966,
#   'F-score': 0.7448275862068965,
#   'MCC': 0.5934065934065934,
#   'Precision': 1.0,
#   'Sensitivity': 0.5934065934065934,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7967032967032968},
#  {'Accuracy': 0.9810725552050473,
#   'F-score': 0.9813664596273292,
#   'MCC': 0.9628392207078355,
#   'Precision': 1.0,
#   'Sensitivity': 0.9634146341463414,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.9817073170731707},
#  {'Accuracy': 0.7256944444444444,
#   'F-score': 0.7476038338658146,
#   'MCC': 0.5667098401868051,
#   'Precision': 1.0,
#   'Sensitivity': 0.5969387755102041,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.