# %%
# Point Colaboratory to your Google Drive

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
datapath = '/content/gdrive/My Drive/^DATA SCIENCE/^Biological Data/PROJECT/models/' # Luca
# datapath = '/content/gdrive/My Drive/Data Science - Unipd/II Year/I Semester/Biological Data/Project/PROJECT/models/' # Giuliano

# %% [markdown]
# # Building models

# %% [markdown]
# ## Ex 5: build a PSSM model

# %%
# ./binx/ncbi-blast-2.11.0+/bin/psiblast -in_msa ./PROJECT/clustal_omega_uniref90_100hits.fasta -db ./data/msa/uniprot_sprot.fasta -out ./PROJECT/output_psiblast_uniref90_100hits.out -out_pssm ./PROJECT/pssm_model_uniref90_100hits.pssm

# %% [markdown]
# ## Ex 6: build a HMM model

# %%
# ./binx/hmmer-3.3.1/src/hmmbuild ./PROJECT/hmm_model_uniref90_100hits.hmm ./PROJECT/clustal_omega_uniref90_100hits.fasta

# %% [markdown]
# ## Ex 7: find significant hits using HMM-SEARCH and PSI-BLAST

# %%
# hmmsearch --tblout ./PROJECT/hmm_search_uniref90_100hits.hmmer_tblout --domtblout ./PROJECT/hmm_search_uniref90_100hits.hmmer_domtblout ./PROJECT/hmm_model_uniref90_100hits.hmm ./data/msa/uniprot_sprot.fasta > ./PROJECT/hmm_search_uniref90_100hits.hmmer_align

# %%
# ./binx/ncbi-blast-2.11.0+/bin/psiblast -in_pssm ./PROJECT/pssm_model_uniref90_100hits.pssm -db ./data/msa/uniprot_sprot.fasta -outfmt 6 -num_iterations 2 -evalue 0.0001 > ./PROJECT/psiblast_search_uniref90_100hits_2iter_eval0001.txt

# %% [markdown]
# ## Ex 8

# %% [markdown]
# #### Read the ground truth file

# %%
# !pip install Bio
from Bio import SeqIO
# Out:
# Collecting Bio
#   Downloading https://files.pythonhosted.org/packages/83/ec/efbae4632107776961f4a1d3607117a4412b9e798609956c664e9c0157f4/bio-0.3.0-py3-none-any.whl (70kB)
#      |████████████████████████████████| 71kB 3.2MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from Bio) (2.23.0)
# Requirement already satisfied: pytest in /usr/local/lib/python3.6/dist-packages (from Bio) (3.6.4)
# Collecting biopython>=1.78
#   Downloading https://files.pythonhosted.org/packages/76/02/8b606c4aa92ff61b5eda71d23b499ab1de57d5e818be33f77b01a6f435a8/biopython-1.78-cp36-cp36m-manylinux1_x86_64.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 7.7MB/s
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->Bio) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->Bio) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->Bio) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->Bio) (2.10)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from pytest->Bio) (51.1.1)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.6/dist-packages (from pytest->Bio) (0.7.1)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from pytest->Bio) (1.10.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.6/dist-packages (from pytest->Bio) (1.4.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.6/dist-packages (from pytest->Bio) (20.3.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from pytest->Bio) (8.6.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from pytest->Bio) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from biopython>=1.78->Bio) (1.19.5)
# Installing collected packages: biopython, Bio
# Successfully installed Bio-0.3.0 biopython-1.78

# %% [markdown]
# Find the proteins containing the target domain (PF08543) in:
# - SwissProt (annotated)
# - TrEMBLE (not annotated) ?????

# %% [markdown]
# Find the proteins containing the target domain (PF08543) in SwissProt -> set of actual positives

# %%
# !pip install Bio
# from Bio import SeqIO
path = datapath + 'protein-matching-PF08543.fasta'
protein_matching = SeqIO.parse(path,'fasta')

list_protein_containing_domain = []
for sequence in protein_matching:
    # print(sequence)
    name = sequence.id # name is in the form A1ADT5|reviewed|Pyridoxine/pyridoxal/pyridoxamine
    # print('name ->', name, '\n')
    list_protein_containing_domain.append(name.split('|')[0])

set_protein_containing_domain = set(list_protein_containing_domain) # this is the ground truth
print(f"Number of proteins in SwissProt containing the target domain: {len(list_protein_containing_domain)}")
# this is the total number of protein in SwissProt
print(f"Actual positives: {set_protein_containing_domain}")
# Out:
# Number of proteins in SwissProt containing the target domain: 150
# Actual positives: {'O83153', 'P9WG77', 'P76422', 'O74860', 'Q8W1X2', 'P44690', 'Q6LP62', 'A6VEZ4', 'O94265', 'Q7CIR8', 'B7M6S8', 'P53727', 'Q7VYK4', 'Q8Z4W1', 'Q57LS3', 'Q83KY1', 'Q8D4Q2', 'Q32FD7', 'Q8NQH1', 'Q9RYX0', 'Q9ZBL1', 'Q48BL6', 'B7UGB9', 'Q52975', 'Q7MGA4', 'O67772', 'Q9HT57', 'Q4ZL75', 'P44697', 'Q1CIM6', 'B7LL66', 'A5UA83', 'Q6NG19', 'A3N2D3', 'Q87FP6', 'Q32DD5', 'Q1C792', 'Q7W6K7', 'B3H2H2', 'A7ZPL9', 'Q2SXQ4', 'Q55EK9', 'Q83K78', 'Q0BSF0', 'Q8FH89', 'Q9ZBR6', 'Q3Z1Z2', 'Q5PIK8', 'Q8ZPM8', 'Q06490', 'B0KR83', 'A5WB73', 'Q08975', 'C3K4G7', 'O00764', 'Q0II59', 'P66914', 'B5YZW5', 'P99124', 'Q141E8', 'A6VNE5', 'B7MHS2', 'Q9CNY1', 'B1IX53', 'O25515', 'Q8CTQ7', 'Q5M731', 'Q0THJ1', 'Q87TZ6', 'B2JCI0', 'B0UUD2', 'Q0TF48', 'B7V753', 'O48881', 'A7N5Q6', 'Q62LP6', 'Q88C26', 'Q57PI7', 'Q6AFC1', 'B1XA89', 'P77150', 'B1JFM7', 'Q0I3D2', 'P40191', 'Q8Z6Q3', 'A8A2R4', 'Q7WII1', 'A1ADT5', 'Q08224', 'Q2QWK9', 'Q63SC2', 'Q8FFB5', 'Q02DJ3', 'Q4K3F6', 'P39988', 'B7MY71', 'Q8X649', 'P56904', 'Q1RBF9', 'Q1I2L8', 'O31620', 'Q5HRG7', 'P61422', 'Q39I40', 'Q8NVH3', 'Q6G7L7', 'P40192', 'Q51892', 'P66915', 'Q6D5V1', 'Q8XBL0', 'Q6GEY2', 'Q7N3W7', 'Q5PNC8', 'Q320Z3', 'B7LCG3', 'Q8K183', 'Q1BXQ7', 'Q2L1P5', 'B6I4Z5', 'O46560', 'P55882', 'O94266', 'Q1J237', 'Q3K4B8', 'P39610', 'Q1LFU5', 'Q3JQA6', 'Q9WZP7', 'P82197', 'C4ZVU9', 'Q9ZL00', 'Q57688', 'B7N609', 'B2TX08', 'P9WG76', 'Q5E345', 'O85786', 'Q3YZC3', 'O14242', 'Q1R8V2', 'Q65UE8', 'Q8FTH8', 'B7NPV5', 'Q66A50', 'B1LML3', 'Q1AYE5', 'Q9USL6', 'Q5HI96', 'O35331'}

# %% [markdown]
# Find all the proteins in the target database (uniprot_sprot.fasta) -> complete ground truth (actual positives + actual negatives)

# %%
path = datapath + 'uniprot_sprot.fasta'
all_sequences = SeqIO.parse(path, 'fasta')

list_all_sequences = []
for sequence in all_sequences:
    name = sequence.id # name is in the form sp|Q6GZX4|001R_FRG3G
    list_all_sequences.append(name.split('|')[1])

num_sequences = len(set(list_all_sequences))
print(f"Total number of proteins in SwissProt: {num_sequences}")
# Out:
# Total number of proteins in SwissProt: 563972

# %% [markdown]
# #### Read the output file of the psi-blast search

# %%
def read_psiblast(path):
    ''' Create a dictionary having as key the protein ID and as value the set of
    tuples (start, end) representing the position of our domain in that protein
    (we assume that the domain may be present in more than one position). '''
    
    positions = {}
    with open(path, 'r') as f:
        for line in f:
            if line:
                line = line.replace('|', ' ')
                (_, _, id, _, _, length, _, gapopen, _, _, 
                    start, end, evalue, bitscore) = line.split()
                    
                positions.setdefault(id, set()).add((start, end)) 
    return positions

# %%
path = datapath + 'psiblast_search_uniref90_100hits_2iter_eval0001.txt'
positions_psiblast = read_psiblast(path)
print(f'Number of distint proteins found with psi-blast: {len(positions_psiblast)}')
# Out:
# Number of distint proteins found with psi-blast: 244

# %%
positions_psiblast
# Out:
# {'A0A0H2WZY4': {('157', '278')},
#  'A0AFC3': {('20', '237')},
#  'A1A6H3': {('243', '368')},
#  'A1ADT5': {('14', '276'), ('89', '256')},
#  'A1AV12': {('134', '298')},
#  'A1S0R2': {('321', '476')},
#  'A2BLC0': {('305', '488')},
#  'A2SU11': {('61', '233')},
#  'A3N2D3': {('54', '264'), ('76', '181')},
#  'A5HYZ4': {('61', '229')},
#  'A5UA83': {('54', '266'), ('76', '181')},
#  'A5VK99': {('36', '240')},
#  'A5WB73': {('60', '256')},
#  'A5WDP1': {('23', '236')},
#  'A6GXW4': {('103', '241')},
#  'A6VEZ4': {('57', '267')},
#  'A6VNE5': {('61', '264'), ('76', '181')},
#  'A6WJS7': {('189', '287')},
#  'A7FPT1': {('61', '229')},
#  'A7GAL1': {('61', '229')},
#  'A7HUC7': {('185', '300')},
#  'A7N5Q6': {('75', '263'), ('77', '252')},
#  'A7ZA59': {('63', '240')},
#  'A7ZNS3': {('25', '241')},
#  'A7ZPL9': {('14', '276'), ('89', '256')},
#  'A8A2R4': {('14', '276'), ('89', '256')},
#  'A8FIR7': {('63', '232')},
#  'A8FZZ3': {('189', '287')},
#  'A9KDJ2': {('191', '289')},
#  'A9N9S2': {('191', '289')},
#  'B0KR83': {('60', '256')},
#  'B0UUD2': {('54', '264'), ('76', '181')},
#  'B1HX32': {('45', '229')},
#  'B1IBZ5': {('179', '276')},
#  'B1IEG7': {('61', '229')},
#  'B1IX53': {('14', '276'), ('89', '256')},
#  'B1JFM7': {('60', '256')},
#  'B1LML3': {('14', '276'), ('89', '256')},
#  'B1XA89': {('14', '276'), ('89', '256')},
#  'B2G7Q2': {('36', '240')},
#  'B2IPT7': {('179', '276')},
#  'B2JCI0': {('56', '263'), ('76', '180')},
#  'B2TX08': {('14', '276'), ('89', '256')},
#  'B3E5M9': {('134', '298')},
#  'B3H2H2': {('54', '264'), ('76', '181')},
#  'B5E4T0': {('179', '276')},
#  'B5YZW5': {('14', '276'), ('89', '256')},
#  'B5Z7K9': {('56', '223')},
#  'B6I4Z5': {('14', '276'), ('89', '256')},
#  'B7GKQ7': {('61', '229')},
#  'B7LCG3': {('14', '276'), ('89', '256')},
#  'B7LL66': {('14', '276'), ('89', '256')},
#  'B7M6S8': {('14', '276'), ('89', '256')},
#  'B7MHS2': {('14', '276'), ('89', '256')},
#  'B7MY71': {('14', '276'), ('89', '256')},
#  'B7N609': {('14', '276'), ('89', '256')},
#  'B7NPV5': {('14', '276'), ('89', '256')},
#  'B7UGB9': {('14', '276'), ('89', '256')},
#  'B7V753': {('57', '267')},
#  'B8CVJ1': {('189', '287')},
#  'B8FB71': {('135', '291')},
#  'B8ZQ64': {('179', '276')},
#  'C0QWJ2': {('51', '238')},
#  'C1C7G0': {('179', '276')},
#  'C1CEF2': {('179', '276')},
#  'C1CKT7': {('179', '276')},
#  'C1CRA6': {('179', '276')},
#  'C1FSC2': {('61', '229')},
#  'C3K4G7': {('60', '256')},
#  'C3L062': {('61', '229')},
#  'C4ZVU9': {('14', '276'), ('89', '256')},
#  'E9AD19': {('189', '303')},
#  'O00764': {('78', '277'), ('95', '203')},
#  'O01824': {('101', '285'), ('118', '266')},
#  'O14242': {('57', '274'), ('88', '271')},
#  'O25515': {('22', '250'), ('6', '257')},
#  'O31620': {('1', '253'), ('20', '246')},
#  'O35331': {('78', '277'), ('91', '199')},
#  'O46560': {('105', '209'), ('88', '280')},
#  'O48881': {('32', '286'), ('35', '274')},
#  'O60116': {('158', '287')},
#  'O67377': {('299', '465')},
#  'O67772': {('3', '249'), ('4', '242')},
#  'O74860': {('57', '239'), ('63', '169')},
#  'O83153': {('18', '248'), ('18', '254')},
#  'O85786': {('1', '253'), ('19', '253')},
#  'O94265': {('1', '263'), ('1', '271')},
#  'O94266': {('35', '296'), ('36', '295')},
#  'P0A9J6': {('107', '273')},
#  'P0A9J7': {('107', '273')},
#  'P30235': {('147', '288')},
#  'P36945': {('122', '267')},
#  'P39610': {('1', '250'), ('7', '248')},
#  'P39988': {('50', '230')},
#  'P40191': {('14', '276'), ('89', '256')},
#  'P40192': {('19', '280'), ('94', '260')},
#  'P44331': {('161', '278')},
#  'P44690': {('54', '266'), ('76', '181')},
#  'P44697': {('21', '250'), ('6', '257')},
#  'P47143': {('154', '317')},
#  'P53727': {('80', '282')},
#  'P55882': {('1', '249'), ('1', '254')},
#  'P56904': {('18', '252'), ('19', '252')},
#  'P57168': {('189', '283')},
#  'P61422': {('225', '474'), ('241', '468')},
#  'P66914': {('1', '254'), ('19', '248')},
#  'P66915': {('7', '255'), ('8', '247')},
#  'P76422': {('1', '253'), ('3', '249')},
#  'P77150': {('57', '266')},
#  'P77493': {('185', '283')},
#  'P82197': {('78', '270'), ('95', '199')},
#  'P83534': {('161', '297')},
#  'P94368': {('145', '245')},
#  'P96051': {('26', '264')},
#  'P99124': {('7', '255'), ('8', '247')},
#  'P9WF10': {('276', '427')},
#  'P9WF11': {('276', '427')},
#  'P9WG76': {('1', '254'), ('19', '248')},
#  'P9WG77': {('1', '254'), ('19', '248')},
#  'Q02DJ3': {('57', '267')},
#  'Q03XM8': {('20', '243')},
#  'Q04KC3': {('179', '276')},
#  'Q06490': {('45', '296'), ('46', '296')},
#  'Q07Y78': {('189', '287')},
#  'Q08224': {('23', '274'), ('24', '273')},
#  'Q08975': {('23', '274'), ('24', '273')},
#  'Q0A4T7': {('148', '287')},
#  'Q0BSF0': {('49', '266'), ('51', '256')},
#  'Q0C190': {('198', '308')},
#  'Q0I3D2': {('54', '264'), ('76', '181')},
#  'Q0II59': {('78', '270'), ('95', '224')},
#  'Q0TF48': {('14', '276'), ('89', '256')},
#  'Q0THJ1': {('57', '266')},
#  'Q141E8': {('75', '264')},
#  'Q1AYE5': {('79', '267')},
#  'Q1BXQ7': {('53', '256')},
#  'Q1C792': {('74', '265'), ('76', '181')},
#  'Q1CIM6': {('74', '265'), ('76', '181')},
#  'Q1H3A0': {('202', '300')},
#  'Q1I2L8': {('60', '256')},
#  'Q1J237': {('64', '276')},
#  'Q1LFU5': {('88', '280'), ('89', '267')},
#  'Q1R8V2': {('14', '276'), ('89', '256')},
#  'Q1RBF9': {('57', '266')},
#  'Q2G2P8': {('127', '240')},
#  'Q2L1P5': {('38', '281'), ('81', '281')},
#  'Q2QWK9': {('57', '307'), ('73', '300')},
#  'Q2SXQ4': {('3', '256')},
#  'Q2W993': {('136', '299')},
#  'Q320Z3': {('57', '266')},
#  'Q32DD5': {('14', '276'), ('89', '256')},
#  'Q32FD7': {('57', '266')},
#  'Q39I40': {('53', '256')},
#  'Q3JQA6': {('3', '256')},
#  'Q3K4B8': {('63', '256')},
#  'Q3YZC3': {('14', '276'), ('89', '256')},
#  'Q3Z1Z2': {('57', '266')},
#  'Q466J4': {('64', '232')},
#  'Q48BL6': {('60', '267')},
#  'Q48P39': {('188', '286')},
#  'Q4K3F6': {('63', '256')},
#  'Q4KJA9': {('188', '286')},
#  'Q4ZL75': {('60', '267')},
#  'Q4ZZ15': {('188', '286')},
#  'Q51892': {('73', '183'), ('75', '267')},
#  'Q52975': {('28', '72')},
#  'Q55EK9': {('79', '228'), ('94', '182')},
#  'Q57688': {('2', '224')},
#  'Q57LS3': {('19', '280'), ('94', '260')},
#  'Q57PI7': {('61', '265'), ('76', '181')},
#  'Q5E345': {('76', '267'), ('77', '208')},
#  'Q5F8G9': {('40', '268')},
#  'Q5FS52': {('128', '284')},
#  'Q5HI96': {('1', '248'), ('6', '247')},
#  'Q5HRG7': {('1', '248'), ('6', '247')},
#  'Q5M731': {('21', '284'), ('31', '272')},
#  'Q5PIK8': {('61', '265'), ('76', '181')},
#  'Q5PNC8': {('19', '280'), ('94', '274')},
#  'Q5WKY9': {('125', '296')},
#  'Q62LP6': {('3', '256')},
#  'Q63SC2': {('3', '256')},
#  'Q65DJ9': {('63', '231')},
#  'Q65UE8': {('54', '264'), ('76', '181')},
#  'Q66A50': {('74', '265'), ('76', '181')},
#  'Q6AFC1': {('53', '261'), ('68', '259')},
#  'Q6D5V1': {('75', '253')},
#  'Q6G7L7': {('7', '255'), ('8', '247')},
#  'Q6GEY2': {('7', '255'), ('8', '247')},
#  'Q6LP62': {('75', '263'), ('77', '182')},
#  'Q6NG19': {('49', '262'), ('74', '181')},
#  'Q7CIR8': {('74', '265'), ('76', '181')},
#  'Q7M9U1': {('144', '284')},
#  'Q7MGA4': {('75', '263'), ('77', '182')},
#  'Q7MNY3': {('130', '282')},
#  'Q7N3W7': {('60', '265')},
#  'Q7UFW7': {('121', '268')},
#  'Q7VU32': {('78', '263')},
#  'Q7VYK4': {('88', '277'), ('89', '192')},
#  'Q7W6K7': {('88', '277'), ('89', '267')},
#  'Q7WII1': {('88', '277'), ('89', '267')},
#  'Q833Y3': {('27', '246')},
#  'Q83B60': {('191', '289')},
#  'Q83K78': {('14', '276'), ('89', '256')},
#  'Q83KY1': {('57', '266')},
#  'Q87FP6': {('75', '261'), ('77', '261')},
#  'Q87TZ6': {('60', '267')},
#  'Q87VF4': {('188', '286')},
#  'Q88C26': {('60', '256')},
#  'Q890C2': {('46', '224')},
#  'Q8CTQ7': {('1', '248'), ('6', '247')},
#  'Q8D4Q2': {('75', '263'), ('77', '182')},
#  'Q8DEH7': {('129', '282')},
#  'Q8DPP1': {('179', '276')},
#  'Q8ESZ2': {('48', '218'), ('49', '215')},
#  'Q8FFB5': {('14', '276'), ('89', '256')},
#  'Q8FH89': {('57', '266')},
#  'Q8FTH8': {('223', '467'), ('223', '472')},
#  'Q8K183': {('78', '277'), ('95', '188')},
#  'Q8KA54': {('189', '283')},
#  'Q8NQH1': {('242', '486'), ('242', '491')},
#  'Q8NVH3': {('7', '255'), ('8', '247')},
#  'Q8PS50': {('58', '232')},
#  'Q8R807': {('59', '216')},
#  'Q8W1X2': {('91', '269'), ('93', '194')},
#  'Q8X649': {('57', '266')},
#  'Q8XBL0': {('14', '276'), ('89', '256')},
#  'Q8Z4W1': {('19', '280'), ('94', '260')},
#  'Q8Z6Q3': {('61', '212'), ('76', '181')},
#  'Q8ZPM8': {('61', '265'), ('76', '181')},
#  'Q8ZV04': {('306', '461')},
#  'Q97QL2': {('179', '276')},
#  'Q9CIU7': {('27', '261')},
#  'Q9CNY1': {('54', '253'), ('76', '181')},
#  'Q9HT57': {('57', '267')},
#  'Q9JRZ9': {('40', '277'), ('80', '265')},
#  'Q9KMX5': {('367', '477')},
#  'Q9RGS6': {('59', '229')},
#  'Q9RYX0': {('82', '275')},
#  'Q9USL6': {('14', '265'), ('14', '275')},
#  'Q9WZP7': {('2', '215')},
#  'Q9ZBL1': {('15', '268'), ('29', '262')},
#  'Q9ZBR6': {('26', '250'), ('27', '257')},
#  'Q9ZKZ9': {('19', '222')},
#  'Q9ZL00': {('21', '249'), ('5', '256')}}

# %% [markdown]
# #### Read the output file of the hmm search

# %%
def read_hmm(path):

    ''' Create a dictionary having as key the protein ID and as value the set of
    tuples (start, end) representing the position of our domain in that protein
    (we assume that the domain may be present in more than one position). '''
  
    positions = {}
    with open(path,'r') as f:
        for line in f:
            if line[0] != "#": # and line[0] != "-":
              line=line.replace('|', ' ')
              (_, id, _, _, tlen, _, _, qlen,  
              full_seq_evalue, full_seq_score, _, _, _, dcevalue, dievalue, dscore, _, _, _ , 
              align_from, align_to, env_from, env_to, accuracy, description) = line.strip().split()[:25]
              #exist multiple scores and alignment. Above I took all of them, but in the below dictionary
              #I have put the same used in github reference
            
              positions.setdefault(id, set()).add( (align_from, align_to) )
   
    return positions

# %%
path = datapath + 'hmm_search_uniref90_100hits.hmmer_domtblout'
positions_hmm = read_hmm(path)
print(f'Number of distint proteins found with hmm: {len(positions_hmm)}')
# Out:
# Number of distint proteins found with hmm: 301

# %%
positions_hmm
# Out:
# {'A0A0H2WZY4': {('173', '229')},
#  'A0KTG8': {('189', '289')},
#  'A1A6H3': {('243', '348')},
#  'A1ACX0': {('69', '239')},
#  'A1ADT5': {('89', '278')},
#  'A1AV12': {('199', '299')},
#  'A1RGD1': {('189', '289')},
#  'A1S3I3': {('125', '148'), ('189', '289')},
#  'A3D837': {('189', '289')},
#  'A3N2D3': {('76', '270')},
#  'A3NJS6': {('197', '237'), ('88', '141')},
#  'A3P5E2': {('197', '237'), ('88', '141')},
#  'A4VR47': {('187', '287')},
#  'A4XPU9': {('188', '287')},
#  'A4Y9Z9': {('189', '289')},
#  'A5EWS4': {('190', '289'), ('309', '351')},
#  'A5G6F4': {('199', '299')},
#  'A5GMH7': {('200', '269')},
#  'A5HYZ4': {('61', '145')},
#  'A5N1D3': {('75', '147')},
#  'A5UA83': {('76', '273')},
#  'A5W9W6': {('188', '287')},
#  'A5WB73': {('79', '186')},
#  'A6TL31': {('247', '329')},
#  'A6VDB5': {('188', '287')},
#  'A6VEZ4': {('79', '260')},
#  'A6VNE5': {('75', '182')},
#  'A6VPG7': {('59', '206')},
#  'A6W6A1': {('28', '62'), ('87', '239')},
#  'A6WJS7': {('189', '289')},
#  'A7FPT1': {('61', '145')},
#  'A7GAL1': {('61', '160')},
#  'A7N5Q6': {('77', '259')},
#  'A7ZNS3': {('71', '239')},
#  'A7ZPL9': {('89', '278')},
#  'A8A1W9': {('69', '239')},
#  'A8A2R4': {('89', '278')},
#  'A8AEC1': {('85', '247')},
#  'A8FZZ3': {('189', '289')},
#  'A9CES5': {('183', '241')},
#  'A9KDJ2': {('191', '290')},
#  'A9L2P0': {('189', '289')},
#  'A9MPW3': {('189', '288')},
#  'A9N5X8': {('189', '288')},
#  'A9N9S2': {('191', '290')},
#  'B0KL32': {('188', '287')},
#  'B0KR83': {('79', '258')},
#  'B0R808': {('175', '227')},
#  'B0UUD2': {('76', '268')},
#  'B1IEG7': {('61', '147')},
#  'B1IX53': {('89', '278')},
#  'B1IYX7': {('69', '239')},
#  'B1J331': {('188', '287')},
#  'B1JFM7': {('79', '258')},
#  'B1KV13': {('61', '146')},
#  'B1LML3': {('89', '278')},
#  'B1LN84': {('69', '239')},
#  'B1X7J5': {('69', '239')},
#  'B1XA89': {('89', '278')},
#  'B2IDA4': {('250', '292')},
#  'B2JCI0': {('76', '243')},
#  'B2TX08': {('89', '278')},
#  'B2TY84': {('71', '239')},
#  'B3E5M9': {('199', '299')},
#  'B3H2H2': {('76', '270')},
#  'B3QJ47': {('196', '302')},
#  'B4T670': {('189', '288')},
#  'B4TI51': {('189', '288')},
#  'B4TVT4': {('189', '288')},
#  'B5BG11': {('189', '288')},
#  'B5F696': {('189', '288')},
#  'B5FB67': {('189', '288')},
#  'B5FHT5': {('189', '288')},
#  'B5QZ36': {('189', '288')},
#  'B5REF8': {('189', '288')},
#  'B5YV51': {('69', '239')},
#  'B5YZW5': {('89', '278')},
#  'B6HYU5': {('69', '239')},
#  'B6I4Z5': {('89', '278')},
#  'B7L9X5': {('69', '239')},
#  'B7LCG3': {('89', '278')},
#  'B7LL66': {('89', '278')},
#  'B7LV66': {('68', '236')},
#  'B7M485': {('69', '239')},
#  'B7M6S8': {('89', '278')},
#  'B7MEF9': {('69', '239')},
#  'B7MHS2': {('89', '278')},
#  'B7MWQ4': {('70', '239')},
#  'B7MY71': {('89', '278')},
#  'B7N609': {('89', '278')},
#  'B7NCD4': {('72', '239')},
#  'B7NPM9': {('69', '239')},
#  'B7NPV5': {('89', '278')},
#  'B7UFC1': {('87', '236')},
#  'B7UGB9': {('89', '278')},
#  'B7V388': {('188', '287')},
#  'B7V753': {('79', '260')},
#  'B8CVJ1': {('189', '289')},
#  'B8EE43': {('189', '289')},
#  'B8FB71': {('200', '303'), ('334', '366')},
#  'B9E564': {('75', '147')},
#  'C0PYX3': {('189', '288')},
#  'C1FSC2': {('61', '147')},
#  'C3K4G7': {('78', '185')},
#  'C3KDB8': {('188', '287')},
#  'C3L062': {('61', '146')},
#  'C4ZSI8': {('69', '239')},
#  'C4ZVU9': {('89', '278')},
#  'E9AD19': {('193', '246')},
#  'O00764': {('95', '199')},
#  'O01824': {('115', '266')},
#  'O14242': {('88', '268')},
#  'O25515': {('6', '250')},
#  'O29891': {('130', '177')},
#  'O31620': {('7', '246')},
#  'O35331': {('95', '192')},
#  'O46560': {('105', '199')},
#  'O48881': {('33', '279')},
#  'O67772': {('3', '247')},
#  'O74860': {('65', '174')},
#  'O82480': {('179', '205')},
#  'O83153': {('5', '249')},
#  'O85786': {('4', '249')},
#  'O94265': {('1', '264')},
#  'O94266': {('36', '295')},
#  'P0A9J6': {('174', '224')},
#  'P0A9J7': {('174', '224')},
#  'P39610': {('7', '249')},
#  'P39988': {('79', '223')},
#  'P40191': {('89', '278')},
#  'P40192': {('94', '278')},
#  'P44331': {('123', '156'), ('173', '222')},
#  'P44690': {('76', '273')},
#  'P44697': {('6', '250')},
#  'P53727': {('58', '243')},
#  'P55882': {('5', '251')},
#  'P56904': {('1', '250')},
#  'P57168': {('189', '288')},
#  'P61422': {('225', '469')},
#  'P66914': {('4', '249')},
#  'P66915': {('7', '248')},
#  'P76422': {('6', '251')},
#  'P76423': {('69', '239')},
#  'P77150': {('76', '184')},
#  'P77493': {('183', '231')},
#  'P82197': {('95', '189')},
#  'P83534': {('171', '223')},
#  'P99124': {('7', '248')},
#  'P9WG76': {('4', '249')},
#  'P9WG77': {('4', '249')},
#  'Q02DJ3': {('79', '260')},
#  'Q02F21': {('188', '287')},
#  'Q04V49': {('74', '227')},
#  'Q04YC8': {('74', '227')},
#  'Q06490': {('46', '297')},
#  'Q07RN1': {('196', '300'), ('63', '99')},
#  'Q07Y78': {('189', '289')},
#  'Q08224': {('24', '274')},
#  'Q08975': {('24', '274')},
#  'Q0A4T7': {('189', '288')},
#  'Q0AZ87': {('63', '143')},
#  'Q0BSF0': {('76', '258')},
#  'Q0HFL0': {('189', '289')},
#  'Q0HYC0': {('189', '289')},
#  'Q0I3D2': {('76', '268')},
#  'Q0II59': {('95', '189')},
#  'Q0T335': {('71', '239')},
#  'Q0TF48': {('89', '278')},
#  'Q0TFY8': {('72', '239')},
#  'Q0THJ1': {('76', '184')},
#  'Q0VM60': {('190', '289')},
#  'Q12RC7': {('189', '289')},
#  'Q13AN7': {('196', '301')},
#  'Q141E8': {('77', '245')},
#  'Q1AYE5': {('100', '262')},
#  'Q1BXQ7': {('75', '254')},
#  'Q1C792': {('76', '182')},
#  'Q1CIM6': {('76', '182')},
#  'Q1I2L8': {('79', '262')},
#  'Q1I411': {('188', '287')},
#  'Q1J237': {('85', '272')},
#  'Q1LFU5': {('89', '279')},
#  'Q1R8V2': {('89', '278')},
#  'Q1R9W8': {('69', '239')},
#  'Q1RBF9': {('76', '184')},
#  'Q219E2': {('196', '300')},
#  'Q2IZP7': {('196', '301')},
#  'Q2L1P5': {('89', '281')},
#  'Q2NGH3': {('207', '234'), ('52', '102')},
#  'Q2QWK9': {('57', '304')},
#  'Q2RY67': {('200', '300')},
#  'Q2SXQ4': {('75', '254')},
#  'Q2T5T2': {('197', '239'), ('89', '142')},
#  'Q2W993': {('198', '300')},
#  'Q320Z3': {('76', '184')},
#  'Q323B8': {('69', '239')},
#  'Q32DD5': {('89', '278')},
#  'Q32EA0': {('92', '239')},
#  'Q32FD7': {('76', '187')},
#  'Q39I40': {('75', '254')},
#  'Q3IU78': {('176', '228')},
#  'Q3JME7': {('197', '237'), ('88', '141')},
#  'Q3JQA6': {('75', '254')},
#  'Q3K4B8': {('78', '185')},
#  'Q3KJ28': {('188', '287')},
#  'Q3STQ8': {('199', '301')},
#  'Q3YZC3': {('89', '278')},
#  'Q3Z0A6': {('70', '238')},
#  'Q3Z1Z2': {('76', '183')},
#  'Q48BL6': {('78', '186')},
#  'Q48P39': {('188', '287')},
#  'Q4K3F6': {('78', '185')},
#  'Q4KJA9': {('188', '287')},
#  'Q4ZL75': {('78', '258')},
#  'Q4ZZ15': {('188', '287')},
#  'Q51892': {('76', '184')},
#  'Q55EK9': {('93', '184')},
#  'Q57688': {('2', '228')},
#  'Q57JQ9': {('189', '288')},
#  'Q57LS3': {('94', '278')},
#  'Q57PI7': {('76', '248')},
#  'Q5E2L7': {('189', '288')},
#  'Q5E345': {('77', '183')},
#  'Q5FS52': {('190', '292')},
#  'Q5HI96': {('6', '247')},
#  'Q5HRG7': {('6', '247')},
#  'Q5HRX2': {('225', '270')},
#  'Q5JEK6': {('158', '205')},
#  'Q5M731': {('31', '277')},
#  'Q5PC86': {('189', '288')},
#  'Q5PIK8': {('76', '248')},
#  'Q5PNC8': {('94', '278')},
#  'Q607M3': {('187', '287')},
#  'Q62LP6': {('75', '254')},
#  'Q63L73': {('197', '237'), ('88', '141')},
#  'Q63SC2': {('75', '254')},
#  'Q65UE8': {('75', '183')},
#  'Q66A50': {('76', '182')},
#  'Q6AFC1': {('74', '246')},
#  'Q6D5V1': {('75', '183')},
#  'Q6G7L7': {('7', '248')},
#  'Q6GEY2': {('7', '248')},
#  'Q6LP62': {('76', '260')},
#  'Q6N2R5': {('196', '303')},
#  'Q6NG19': {('74', '250')},
#  'Q72U64': {('74', '231')},
#  'Q7CIR8': {('76', '182')},
#  'Q7CPR9': {('189', '288')},
#  'Q7MGA4': {('77', '259')},
#  'Q7N3W7': {('75', '183')},
#  'Q7VYK4': {('89', '269')},
#  'Q7W6K7': {('89', '269')},
#  'Q7WII1': {('89', '269')},
#  'Q83B60': {('191', '290')},
#  'Q83K78': {('89', '278')},
#  'Q83KH2': {('71', '239')},
#  'Q83KY1': {('76', '206')},
#  'Q87FP6': {('77', '257')},
#  'Q87TZ6': {('78', '186')},
#  'Q87VF4': {('188', '287')},
#  'Q88C26': {('79', '186')},
#  'Q88D93': {('188', '287')},
#  'Q89HR3': {('202', '305'), ('67', '103')},
#  'Q8CMQ7': {('225', '270')},
#  'Q8CTQ7': {('6', '247')},
#  'Q8D4Q2': {('77', '259')},
#  'Q8E093': {('76', '201')},
#  'Q8EAZ2': {('189', '289')},
#  'Q8ESZ2': {('59', '220')},
#  'Q8F0X6': {('74', '231')},
#  'Q8FFB5': {('89', '278')},
#  'Q8FFY0': {('69', '239')},
#  'Q8FH89': {('76', '184')},
#  'Q8FTH8': {('222', '470')},
#  'Q8K183': {('95', '193')},
#  'Q8KA54': {('188', '288')},
#  'Q8NQH1': {('242', '488')},
#  'Q8NVH3': {('7', '248')},
#  'Q8U191': {('79', '233')},
#  'Q8W1X2': {('92', '193')},
#  'Q8X649': {('76', '184')},
#  'Q8X7G3': {('69', '239')},
#  'Q8XBL0': {('89', '278')},
#  'Q8XEW9': {('189', '288')},
#  'Q8Z4W1': {('94', '278')},
#  'Q8Z6Q3': {('76', '182')},
#  'Q8ZPM8': {('76', '248')},
#  'Q9CIU7': {('142', '261')},
#  'Q9CNY1': {('76', '270')},
#  'Q9HMK2': {('175', '227')},
#  'Q9HT57': {('79', '260')},
#  'Q9HUG9': {('188', '287')},
#  'Q9JRZ9': {('89', '261')},
#  'Q9RGS6': {('59', '205')},
#  'Q9RYX0': {('87', '194')},
#  'Q9USL6': {('13', '286')},
#  'Q9VVW8': {('162', '205')},
#  'Q9WZP7': {('2', '212')},
#  'Q9ZBL1': {('16', '263')},
#  'Q9ZBR6': {('11', '249')},
#  'Q9ZL00': {('5', '249')}}

# %% [markdown]
# #### Model evaluation

# %%
# !pip install Bio
# from Bio import SeqIO
import math
import json
import pandas as pd
import numpy as np

# %% [markdown]
# #### Useful functions to compute metrics

# %% [markdown]
# CONFIDENTIAL!!! :-)
#
# In $\verb!utils.py!$ there are 5 functions:
#
# - $\verb!computeMetrics!$
# - $\verb!createPositionSet!$
# - $\verb!evaluateSequencesSH2!$
# - $\verb!getSeqLength!$
# - $\verb!evaluatePositionsSH2!$
#
# But for point 8) are needed only:
# - $\verb!computeMetrics!$
# - $\verb!evaluateSequencesSH2!$
#
# So I use only them in the following.

# %%
# import math
def metrics(true_positive, true_negative, false_positive, false_negative):
  
    accuracy = (true_positive + true_negative) / (true_positive + true_negative + false_negative + false_positive)
    precision = true_positive / (true_positive + false_positive)
    sensitivity = true_positive / (true_positive + false_negative)
    specificity = true_negative / (true_negative + false_positive)
    weighted_accuracy = (sensitivity + specificity) / 2
    mcc_numerator = (true_positive * true_negative) - (false_positive * false_negative)
    mcc_denominator_squared = (true_positive + false_positive) * (true_positive + false_negative) * (true_negative + false_positive) * (true_negative + false_negative)
    mcc = mcc_numerator / math.sqrt(mcc_denominator_squared)
    f1_score = 2 * (precision * sensitivity) / (precision + sensitivity)
    
    return {
            "Accuracy": accuracy,
            "Weighted accuracy": weighted_accuracy,
            "Precision": precision,
            "Sensitivity": sensitivity,
            "Specificity": specificity,
            "MCC": mcc,
            "F-score": f1_score
            }

# %%
def metrics_results(predictions, actual_positives, ground_truth_size):
    """
    predictions = dict of the type {'A0A0H2WZY4': {('167', '228')}, ... }
    actual_positives = set of sequences containing PF08543
    ground_truth_size = number of actual positives + actual negatives (= SwissPort size)
    """
    predicted_sequences = set(predictions.keys())
    
    true_positive = len(predicted_sequences & actual_positives)
    
    # # If there aren't true postive later there will be a division by 0
    # if true_positive == 0:
    #     print("No true positive!")
    #     return
    
    false_negative = len(actual_positives) - true_positive
    false_positive = len(predicted_sequences) - true_positive
    true_negative = ground_truth_size - true_positive - false_positive - false_negative
    
    conf_matrix = pd.DataFrame(np.array([[true_positive, false_positive], [false_negative, true_negative]]), 
                               index=['Positive pred', 'Negative pred'], 
                               columns=['Actual positive', 'Actual negative'])

    return conf_matrix, metrics(true_positive, true_negative, false_positive, false_negative)

# %% [markdown]
# #### Evaluate psi-blast

# %%
conf_matrix_psiblast, metric_results_psiblast = metrics_results(positions_psiblast, set_protein_containing_domain, num_sequences )
print('CLASSIFICATION METRICS')
for k in metric_results_psiblast:
    print(f'{k}: {metric_results_psiblast[k]:.3}')
    
print('\nCONFUSION MATRIX')    
conf_matrix_psiblast
# Out:
# CLASSIFICATION METRICS
# Accuracy: 1.0
# Weighted accuracy: 1.0
# Precision: 0.615
# Sensitivity: 1.0
# Specificity: 1.0
# MCC: 0.784
# F-score: 0.761
#
# CONFUSION MATRIX
#                Actual positive  Actual negative
# Positive pred              150               94
# Negative pred                0           563728

# %% [markdown]
# #### Evaluate hmm

# %%
conf_matrix_hmm, metric_results_hmm = metrics_results(positions_hmm, set_protein_containing_domain, num_sequences )
print('CLASSIFICATION METRICS')
for k in metric_results_hmm:
    print(f'{k}: {metric_results_hmm[k]:.3}')
    
print('\nCONFUSION MATRIX')    
conf_matrix_hmm
# Out:
# CLASSIFICATION METRICS
# Accuracy: 1.0
# Weighted accuracy: 0.997
# Precision: 0.495
# Sensitivity: 0.993
# Specificity: 1.0
# MCC: 0.701
# F-score: 0.661
#
# CONFUSION MATRIX
#                Actual positive  Actual negative
# Positive pred              149              152
# Negative pred                1           563670

# %% [markdown]
# ### Comment on the results

# %% [markdown]
# ## Ex 9

# %% [markdown]
# #### Read the ground truth file for the positions

# %%
path = datapath + 'protein-matching-PF08543.json'

with open(path, "r") as file:
    position_file = json.load(file)
    
ground_truth_positions = {}
for elem in position_file:
    id = elem['metadata']['accession']
    length = elem['metadata']['length']

    ground_truth_positions.setdefault(id, dict()).update([('length', length), ('positions', set())])

    for entry in elem['entries']:
        if entry['accession']=='PF08543':
            for location in entry['entry_protein_locations']:

                position_tuple=(str(location['fragments'][0]['start']),
                                str(location['fragments'][0]['end']))

                ground_truth_positions[id]['positions'].add(position_tuple)

# %%
print(len(ground_truth_positions))
# Out:
# 150

# %%
for item in ground_truth_positions.items():
  print(item)
# Out:
# ('A1ADT5', {'length': 283, 'positions': {('88', '265')}})
# ('A3N2D3', {'length': 286, 'positions': {('64', '256')}})
# ('A5UA83', {'length': 288, 'positions': {('71', '264')}})
# ('A5WB73', {'length': 290, 'positions': {('74', '257')}})
# ('A6VEZ4', {'length': 288, 'positions': {('77', '259')}})
# ('A6VNE5', {'length': 286, 'positions': {('62', '259')}})
# ('A7N5Q6', {'length': 289, 'positions': {('75', '260')}})
# ('A7ZPL9', {'length': 283, 'positions': {('88', '265')}})
# ('A8A2R4', {'length': 283, 'positions': {('88', '265')}})
# ('B0KR83', {'length': 290, 'positions': {('76', '257')}})
# ('B0UUD2', {'length': 286, 'positions': {('64', '260')}})
# ('B1IX53', {'length': 283, 'positions': {('88', '265')}})
# ('B1JFM7', {'length': 290, 'positions': {('76', '257')}})
# ('B1LML3', {'length': 283, 'positions': {('88', '265')}})
# ('B1XA89', {'length': 283, 'positions': {('88', '265')}})
# ('B2JCI0', {'length': 287, 'positions': {('74', '261')}})
# ('B2TX08', {'length': 283, 'positions': {('88', '265')}})
# ('B3H2H2', {'length': 286, 'positions': {('64', '256')}})
# ('B5YZW5', {'length': 283, 'positions': {('88', '265')}})
# ('B6I4Z5', {'length': 283, 'positions': {('88', '265')}})
# ('B7LCG3', {'length': 283, 'positions': {('88', '265')}})
# ('B7LL66', {'length': 283, 'positions': {('88', '266')}})
# ('B7M6S8', {'length': 283, 'positions': {('88', '265')}})
# ('B7MHS2', {'length': 283, 'positions': {('88', '265')}})
# ('B7MY71', {'length': 283, 'positions': {('88', '265')}})
# ('B7N609', {'length': 283, 'positions': {('88', '265')}})
# ('B7NPV5', {'length': 283, 'positions': {('88', '265')}})
# ('B7UGB9', {'length': 283, 'positions': {('88', '265')}})
# ('B7V753', {'length': 290, 'positions': {('77', '262')}})
# ('C3K4G7', {'length': 290, 'positions': {('69', '256')}})
# ('C4ZVU9', {'length': 283, 'positions': {('88', '265')}})
# ('O00764', {'length': 312, 'positions': {('94', '275')}})
# ('O14242', {'length': 309, 'positions': {('92', '244')}})
# ('O25515', {'length': 270, 'positions': {('15', '262')}})
# ('O31620', {'length': 271, 'positions': {('13', '258')}})
# ('O35331', {'length': 312, 'positions': {('95', '273')}})
# ('O46560', {'length': 322, 'positions': {('104', '284')}})
# ('O48881', {'length': 523, 'positions': {('42', '285')}})
# ('O67772', {'length': 255, 'positions': {('10', '251')}})
# ('O74860', {'length': 340, 'positions': {('66', '241')}})
# ('O83153', {'length': 269, 'positions': {('11', '258')}})
# ('O85786', {'length': 263, 'positions': {('13', '256')}})
# ('O94265', {'length': 506, 'positions': {('12', '275')}})
# ('O94266', {'length': 551, 'positions': {('45', '301')}})
# ('P39610', {'length': 271, 'positions': {('13', '260')}})
# ('P39988', {'length': 312, 'positions': {('78', '234')}})
# ('P40191', {'length': 283, 'positions': {('88', '265')}})
# ('P40192', {'length': 288, 'positions': {('93', '269')}})
# ('P44690', {'length': 288, 'positions': {('71', '264')}})
# ('P44697', {'length': 269, 'positions': {('14', '262')}})
# ('P53727', {'length': 317, 'positions': {('80', '243')}})
# ('P55882', {'length': 266, 'positions': {('13', '260')}})
# ('P56904', {'length': 266, 'positions': {('12', '258')}})
# ('P61422', {'length': 490, 'positions': {('235', '479')}})
# ('P66914', {'length': 265, 'positions': {('13', '258')}})
# ('P66915', {'length': 276, 'positions': {('14', '260')}})
# ('P76422', {'length': 266, 'positions': {('13', '260')}})
# ('P77150', {'length': 287, 'positions': {('67', '256')}})
# ('P82197', {'length': 312, 'positions': {('94', '274')}})
# ('P99124', {'length': 276, 'positions': {('14', '260')}})
# ('P9WG76', {'length': 265, 'positions': {('13', '258')}})
# ('P9WG77', {'length': 265, 'positions': {('13', '258')}})
# ('Q02DJ3', {'length': 288, 'positions': {('77', '263')}})
# ('Q06490', {'length': 572, 'positions': {('55', '307')}})
# ('Q08224', {'length': 551, 'positions': {('33', '283')}})
# ('Q08975', {'length': 551, 'positions': {('33', '283')}})
# ('Q0BSF0', {'length': 286, 'positions': {('90', '262')}})
# ('Q0I3D2', {'length': 286, 'positions': {('64', '260')}})
# ('Q0II59', {'length': 312, 'positions': {('94', '274')}})
# ('Q0TF48', {'length': 283, 'positions': {('88', '265')}})
# ('Q0THJ1', {'length': 287, 'positions': {('67', '256')}})
# ('Q141E8', {'length': 288, 'positions': {('75', '262')}})
# ('Q1AYE5', {'length': 290, 'positions': {('112', '265')}})
# ('Q1BXQ7', {'length': 286, 'positions': {('74', '258')}})
# ('Q1C792', {'length': 286, 'positions': {('75', '263')}})
# ('Q1CIM6', {'length': 286, 'positions': {('75', '263')}})
# ('Q1I2L8', {'length': 290, 'positions': {('76', '257')}})
# ('Q1J237', {'length': 299, 'positions': {('83', '262')}})
# ('Q1LFU5', {'length': 288, 'positions': {('89', '268')}})
# ('Q1R8V2', {'length': 283, 'positions': {('88', '265')}})
# ('Q1RBF9', {'length': 287, 'positions': {('67', '256')}})
# ('Q2L1P5', {'length': 296, 'positions': {('90', '266')}})
# ('Q2QWK9', {'length': 548, 'positions': {('66', '310')}})
# ('Q2SXQ4', {'length': 287, 'positions': {('64', '258')}})
# ('Q320Z3', {'length': 287, 'positions': {('67', '256')}})
# ('Q32DD5', {'length': 283, 'positions': {('88', '265')}})
# ('Q32FD7', {'length': 287, 'positions': {('67', '256')}})
# ('Q39I40', {'length': 286, 'positions': {('66', '258')}})
# ('Q3JQA6', {'length': 287, 'positions': {('64', '258')}})
# ('Q3K4B8', {'length': 290, 'positions': {('71', '256')}})
# ('Q3YZC3', {'length': 283, 'positions': {('88', '265')}})
# ('Q3Z1Z2', {'length': 287, 'positions': {('67', '256')}})
# ('Q48BL6', {'length': 288, 'positions': {('68', '263')}})
# ('Q4K3F6', {'length': 290, 'positions': {('70', '256')}})
# ('Q4ZL75', {'length': 288, 'positions': {('69', '263')}})
# ('Q51892', {'length': 289, 'positions': {('67', '263')}})
# ('Q52975', {'length': 90, 'positions': {('27', '72')}})
# ('Q55EK9', {'length': 302, 'positions': {('92', '265')}})
# ('Q57688', {'length': 417, 'positions': {('10', '235')}})
# ('Q57LS3', {'length': 288, 'positions': {('93', '269')}})
# ('Q57PI7', {'length': 286, 'positions': {('72', '256')}})
# ('Q5E345', {'length': 289, 'positions': {('75', '264')}})
# ('Q5HI96', {'length': 276, 'positions': {('13', '259')}})
# ('Q5HRG7', {'length': 276, 'positions': {('13', '259')}})
# ('Q5M731', {'length': 522, 'positions': {('40', '283')}})
# ('Q5PIK8', {'length': 286, 'positions': {('72', '256')}})
# ('Q5PNC8', {'length': 288, 'positions': {('93', '269')}})
# ('Q62LP6', {'length': 287, 'positions': {('64', '258')}})
# ('Q63SC2', {'length': 287, 'positions': {('64', '258')}})
# ('Q65UE8', {'length': 286, 'positions': {('68', '262')}})
# ('Q66A50', {'length': 286, 'positions': {('75', '263')}})
# ('Q6AFC1', {'length': 283, 'positions': {('91', '258')}})
# ('Q6D5V1', {'length': 286, 'positions': {('75', '253')}})
# ('Q6G7L7', {'length': 276, 'positions': {('14', '260')}})
# ('Q6GEY2', {'length': 276, 'positions': {('14', '260')}})
# ('Q6LP62', {'length': 291, 'positions': {('75', '260')}})
# ('Q6NG19', {'length': 283, 'positions': {('91', '255')}})
# ('Q7CIR8', {'length': 286, 'positions': {('75', '263')}})
# ('Q7MGA4', {'length': 290, 'positions': {('75', '260')}})
# ('Q7N3W7', {'length': 287, 'positions': {('74', '262')}})
# ('Q7VYK4', {'length': 283, 'positions': {('91', '272')}})
# ('Q7W6K7', {'length': 283, 'positions': {('90', '272')}})
# ('Q7WII1', {'length': 283, 'positions': {('90', '272')}})
# ('Q83K78', {'length': 283, 'positions': {('88', '265')}})
# ('Q83KY1', {'length': 287, 'positions': {('67', '256')}})
# ('Q87FP6', {'length': 289, 'positions': {('75', '260')}})
# ('Q87TZ6', {'length': 288, 'positions': {('69', '263')}})
# ('Q88C26', {'length': 290, 'positions': {('74', '257')}})
# ('Q8CTQ7', {'length': 276, 'positions': {('13', '259')}})
# ('Q8D4Q2', {'length': 290, 'positions': {('75', '260')}})
# ('Q8FFB5', {'length': 283, 'positions': {('88', '265')}})
# ('Q8FH89', {'length': 287, 'positions': {('67', '256')}})
# ('Q8FTH8', {'length': 739, 'positions': {('232', '479')}})
# ('Q8K183', {'length': 312, 'positions': {('94', '273')}})
# ('Q8NQH1', {'length': 763, 'positions': {('251', '498')}})
# ('Q8NVH3', {'length': 276, 'positions': {('14', '260')}})
# ('Q8W1X2', {'length': 309, 'positions': {('93', '199')}})
# ('Q8X649', {'length': 287, 'positions': {('67', '256')}})
# ('Q8XBL0', {'length': 283, 'positions': {('88', '265')}})
# ('Q8Z4W1', {'length': 288, 'positions': {('93', '269')}})
# ('Q8Z6Q3', {'length': 228, 'positions': {('72', '214')}})
# ('Q8ZPM8', {'length': 286, 'positions': {('72', '256')}})
# ('Q9CNY1', {'length': 286, 'positions': {('68', '253')}})
# ('Q9HT57', {'length': 288, 'positions': {('77', '262')}})
# ('Q9RYX0', {'length': 298, 'positions': {('101', '271')}})
# ('Q9USL6', {'length': 327, 'positions': {('23', '275')}})
# ('Q9WZP7', {'length': 398, 'positions': {('9', '208')}})
# ('Q9ZBL1', {'length': 279, 'positions': {('23', '272')}})
# ('Q9ZBR6', {'length': 269, 'positions': {('20', '262')}})
# ('Q9ZL00', {'length': 269, 'positions': {('14', '261')}})

# %% [markdown]
# #### Useful functions to compute metrics

# %% [markdown]
# CONFIDENTIAL!!! :-)
#
# In $\verb!utils.py!$ there are 5 functions:
#
# - $\verb!computeMetrics!$
# - $\verb!createPositionSet!$
# - $\verb!evaluateSequencesSH2!$
# - $\verb!getSeqLength!$
# - $\verb!evaluatePositionsSH2!$
#
# But for point 9) are needed only:
# - $\verb!computeMetrics!$
# - $\verb!createPositionSet!$
# - $\verb!getSeqLength!$
# - $\verb!evaluatePositionsSH2!$
#
# So I use only them in the following.

# %%
def createPositionSet(position_set):
    """
    position_set = {('88', '265'), ...}
    return a set {88, 89, ..., 265, ...}
    """
    positions = set()
    for pos in position_set: # pos is a tuple of two strings
        p = [i for i in range( int(pos[0]), int(pos[1])+1 )]
        positions = positions.union(p)
    return positions

# %% [markdown]
# This is the original function.
#
# I'm not able to run it because it calls a command line in Linux.
#
# If you can, please try to see if the below function provides the same result as my version.

# %% [markdown]
# I get the following error...
#
# `Error: [blastdbcmd] DB contains no accession info.`

# %%
############### ORIGINAL FUNCTION
'''
def getSeqLength(entry):
    """
    Get sequence length from reference dataset
    """   
    cmd = 'blastdbcmd -entry "{}" -db ../../data/SwissProt_humans_reference_all.fasta'.format(entry)
    results = subprocess.run(
            cmd, shell=True, universal_newlines=True, 
            stdout=subprocess.PIPE
            ).stdout
    results = results.split('\n')
    results.pop(0)
    return len("".join(results))
'''
# Out:
# '\ndef getSeqLength(entry):\n    """\n    Get sequence length from reference dataset\n    """   \n    cmd = \'blastdbcmd -entry "{}" -db ../../data/SwissProt_humans_reference_all.fasta\'.format(entry)\n    results = subprocess.run(\n            cmd, shell=True, universal_newlines=True, \n            stdout=subprocess.PIPE\n            ).stdout\n    results = results.split(\'\n\')\n    results.pop(0)\n    return len("".join(results))\n'

# %%
path = datapath + 'uniprot_sprot.fasta'
all_sequences = SeqIO.parse(path, 'fasta')

# %%
##################### MY VERSION
def getSeqLength(entry, all_sequences):

  """
  Get sequence length from reference dataset
  """ 
#   path = datapath + 'uniprot_sprot.fasta'
#   all_sequences = SeqIO.parse(path, 'fasta')

  list_all_sequences = []
  for sequence in all_sequences:
      name = sequence.id # name is in the form sp|Q6GZX4|001R_FRG3G
      name = name.split('|')[1]
      if name==entry:
        #print(sequence.seq)
        #print(len(sequence.seq))
        length=len(sequence.seq)
  return length

# %%
#-------------------------DEBUG
entry='Q6GZX4'
getSeqLength(entry, all_sequences)
# Out:
# 256

# %%
def evaluatePositions(predicted_positions, ground_truth_positions):
    """
    predicted_positions: {'A0A0H2WZY4': {('162', '278')}, ...}
    ground_truth_positions: {'A1ADT5': {'length': 283, 'positions': {('88', '265')}}, ...}
    
    """
    global_tp, global_fp, global_fn, global_tn = [], [], [], []
    
    # scores per sequence
    log_scores = []

    for id in predicted_positions:
        if id in ground_truth_positions:
            sequence_length = ground_truth_positions[id]['length']
            ground_truth_positions_seq = createPositionSet(ground_truth_positions[id]['positions']) 
            ####################################################################################
            # Here there was an error: there was reference_positions = createPositionSet(reference_positions[seqid]['positions']), 
            # which modifies reference_positions! So we had correct results only for the first protein!
            ####################################################################################
            predicted_positions_seq = createPositionSet(predicted_positions[id])    

            overlapping_positions  = ground_truth_positions_seq & predicted_positions_seq

            true_positive = len(overlapping_positions)
            false_positive = len(predicted_positions_seq - overlapping_positions)
            false_negative = len(ground_truth_positions_seq -  overlapping_positions)
            true_negative  = sequence_length - true_positive - false_positive - false_negative

            global_tp.append(true_positive)
            global_fp.append(false_positive)
            global_fn.append(false_negative)
            global_tn.append(true_negative)
            
            log_scores.append(metrics(true_positive, true_negative, false_positive, false_negative))


        ##############
        # HA SENSO? ci mette una vita per calcolare la lunghezza delle sequence con getSeqLength 
        # e non so se sia utile/sensato comprendere le sequenze senza dominio in questo esercizio
        ##############
        # else:
        #     # false positive sequence
        #     predicted_positions_seq = createPositionSet(predicted_positions[id])

        #     true_positive = 0
        #     false_positive = len(predicted_positions_seq)
        #     false_negative = 0
        #     true_negative = 0
            
        #     lenSeq = getSeqLength(id)
            
        #     log_scores.append(
        #         {
        #             'Precision': 0,
        #             'Sensitivity': 0,
        #             'Specificity': lenSeq / (lenSeq + false_positive),
        #             'F1-score': 0,
        #             'MCC': 0
        #         }
        #     )

        #     list_tp.append(true_positive)
        #     list_fp.append(false_positive)
        #     list_fn.append(false_negative)
        #     list_tn.append(true_negative)
                   
    metrics_global = metrics(true_positive=sum(global_tp), true_negative=sum(global_tn), 
                             false_positive=sum(global_fp), false_negative=sum(global_fn))
    
    conf_matrix = pd.DataFrame(np.array([[sum(global_tp), sum(global_fp)], [sum(global_fn), sum(global_tn)]]), 
                               index=['Positive pred', 'Negative pred'], 
                               columns=['Actual positive', 'Actual negative'])
    
    return metrics_global, log_scores, conf_matrix

# %% [markdown]
# #### Evaluate psi-blast

# %%
metrics_global_psiblast, log_score_psiblast, conf_matrix_psiblast_pos = evaluatePositions(positions_psiblast, ground_truth_positions)

# %%
print('CLASSIFICATION METRICS')
for k in metrics_global_psiblast:
    print(f'{k}: {metrics_global_psiblast[k]:.3}')
print('\nCONFUSION MATRIX')    
conf_matrix_psiblast_pos
# Out:
# CLASSIFICATION METRICS
# Accuracy: 0.887
# Weighted accuracy: 0.848
# Precision: 0.858
# Sensitivity: 0.987
# Specificity: 0.708
# MCC: 0.758
# F-score: 0.918
#
# CONFUSION MATRIX
#                Actual positive  Actual negative
# Positive pred            29215             4820
# Negative pred              384            11692

# %%
log_score_psiblast
# Out:
# [{'Accuracy': 0.9693877551020408,
#   'F-score': 0.9696969696969697,
#   'MCC': 0.938971068066885,
#   'Precision': 0.96,
#   'Sensitivity': 0.9795918367346939,
#   'Specificity': 0.9591836734693877,
#   'Weighted accuracy': 0.9693877551020408},
#  {'Accuracy': 0.9616858237547893,
#   'F-score': 0.9606299212598425,
#   'MCC': 0.9261480246189371,
#   'Precision': 0.9242424242424242,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9280575539568345,
#   'Weighted accuracy': 0.9640287769784173},
#  {'Accuracy': 0.9783491204330176,
#   'F-score': 0.9678714859437753,
#   'MCC': 0.9515628067647408,
#   'Precision': 0.964,
#   'Sensitivity': 0.9717741935483871,
#   'Specificity': 0.9816700610997964,
#   'Weighted accuracy': 0.9767221273240918},
#  {'Accuracy': 0.9285714285714286,
#   'F-score': 0.9620758483033931,
#   'MCC': 0.3554537316015787,
#   'Precision': 0.9525691699604744,
#   'Sensitivity': 0.9717741935483871,
#   'Specificity': 0.3333333333333333,
#   'Weighted accuracy': 0.6525537634408602},
#  {'Accuracy': 0.9548872180451128,
#   'F-score': 0.975103734439834,
#   'MCC': 0.7636272329274842,
#   'Precision': 1.0,
#   'Sensitivity': 0.951417004048583,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.9757085020242915},
#  {'Accuracy': 0.9789674952198852,
#   'F-score': 0.9779559118236473,
#   'MCC': 0.9587163155938935,
#   'Precision': 0.9568627450980393,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9605734767025089,
#   'Weighted accuracy': 0.9802867383512545},
#  {'Accuracy': 0.9323308270676691,
#   'F-score': 0.9641434262948209,
#   'MCC': 0.37411878229121276,
#   'Precision': 0.952755905511811,
#   'Sensitivity': 0.9758064516129032,
#   'Specificity': 0.3333333333333333,
#   'Weighted accuracy': 0.6545698924731183},
#  {'Accuracy': 0.9647058823529412,
#   'F-score': 0.9815950920245398,
#   'MCC': 0.5719350288451417,
#   'Precision': 0.97165991902834,
#   'Sensitivity': 0.9917355371900827,
#   'Specificity': 0.46153846153846156,
#   'Weighted accuracy': 0.7266369993642721},
#  {'Accuracy': 0.9565217391304348,
#   'F-score': 0.9758064516129032,
#   'MCC': 0.7621571633279571,
#   'Precision': 0.9718875502008032,
#   'Sensitivity': 0.979757085020243,
#   'Specificity': 0.7586206896551724,
#   'Weighted accuracy': 0.8691888873377076},
#  {'Accuracy': 0.9565217391304348,
#   'F-score': 0.9758064516129032,
#   'MCC': 0.7621571633279571,
#   'Precision': 0.9718875502008032,
#   'Sensitivity': 0.979757085020243,
#   'Specificity': 0.7586206896551724,
#   'Weighted accuracy': 0.8691888873377076},
#  {'Accuracy': 0.9565217391304348,
#   'F-score': 0.9758064516129032,
#   'MCC': 0.7621571633279571,
#   'Precision': 0.9718875502008032,
#   'Sensitivity': 0.979757085020243,
#   'Specificity': 0.7586206896551724,
#   'Weighted accuracy': 0.8691888873377076},
#  {'Accuracy': 0.9565217391304348,
#   'F-score': 0.9758064516129032,
#   'MCC': 0.7621571633279571,
#   'Precision': 0.9718875502008032,
#   'Sensitivity': 0.979757085020243,
#   'Specificity': 0.7586206896551724,
#   'Weighted accuracy': 0.8691888873377076},
#  {'Accuracy': 0.9727767695099818,
#   'F-score': 0.9710982658959537,
#   'MCC': 0.9455305534567476,
#   'Precision': 0.9618320610687023,
#   'Sensitivity': 0.980544747081712,
#   'Specificity': 0.9659863945578231,
#   'Weighted accuracy': 0.9732655708197675},
#  {'Accuracy': 0.9565217391304348,
#   'F-score': 0.9758064516129032,
#   'MCC': 0.7621571633279571,
#   'Precision': 0.9718875502008032,
#   'Sensitivity': 0.979757085020243,
#   'Specificity': 0.7586206896551724,
#   'Weighted accuracy': 0.8691888873377076},
#  {'Accuracy': 0.9790301441677588,
#   'F-score': 0.9678714859437753,
#   'MCC': 0.952324579201888,
#   'Precision': 0.964,
#   'Sensitivity': 0.9717741935483871,
#   'Specificity': 0.9825242718446602,
#   'Weighted accuracy': 0.9771492326965237},
#  {'Accuracy': 0.9516728624535316,
#   'F-score': 0.9740518962075849,
#   'MCC': 0.6252558826572571,
#   'Precision': 0.9682539682539683,
#   'Sensitivity': 0.9799196787148594,
#   'Specificity': 0.6,
#   'Weighted accuracy': 0.7899598393574296},
#  {'Accuracy': 0.9781021897810219,
#   'F-score': 0.9758064516129032,
#   'MCC': 0.9560451718451766,
#   'Precision': 0.9641434262948207,
#   'Sensitivity': 0.9877551020408163,
#   'Specificity': 0.9702970297029703,
#   'Weighted accuracy': 0.9790260658718932},
#  {'Accuracy': 0.9372693726937269,
#   'F-score': 0.9659318637274549,
#   'MCC': 0.5806687969369173,
#   'Precision': 0.9525691699604744,
#   'Sensitivity': 0.9796747967479674,
#   'Specificity': 0.52,
#   'Weighted accuracy': 0.7498373983739837},
#  {'Accuracy': 0.9481481481481482,
#   'F-score': 0.972,
#   'MCC': 0.6259575823065716,
#   'Precision': 0.9642857142857143,
#   'Sensitivity': 0.9798387096774194,
#   'Specificity': 0.5909090909090909,
#   'Weighted accuracy': 0.7853739002932552},
#  {'Accuracy': 0.9479553903345725,
#   'F-score': 0.972,
#   'MCC': 0.6078171832913454,
#   'Precision': 0.9642857142857143,
#   'Sensitivity': 0.9798387096774194,
#   'Specificity': 0.5714285714285714,
#   'Weighted accuracy': 0.7756336405529953},
#  {'Accuracy': 0.9591078066914498,
#   'F-score': 0.9768421052631578,
#   'MCC': 0.8190806525230344,
#   'Precision': 1.0,
#   'Sensitivity': 0.9547325102880658,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.977366255144033},
#  {'Accuracy': 0.956989247311828,
#   'F-score': 0.976190476190476,
#   'MCC': 0.7566586450877236,
#   'Precision': 0.968503937007874,
#   'Sensitivity': 0.984,
#   'Specificity': 0.7241379310344828,
#   'Weighted accuracy': 0.8540689655172413},
#  {'Accuracy': 0.965034965034965,
#   'F-score': 0.9604743083003953,
#   'MCC': 0.9291263459179501,
#   'Precision': 0.9604743083003953,
#   'Sensitivity': 0.9604743083003953,
#   'Specificity': 0.9686520376175548,
#   'Weighted accuracy': 0.964563172958975},
#  {'Accuracy': 0.9188191881918819,
#   'F-score': 0.9558232931726908,
#   'MCC': 0.4564813344584963,
#   'Precision': 0.952,
#   'Sensitivity': 0.9596774193548387,
#   'Specificity': 0.4782608695652174,
#   'Weighted accuracy': 0.7189691444600281},
#  {'Accuracy': 0.9166666666666666,
#   'F-score': 0.9535353535353535,
#   'MCC': 0.5501478169025211,
#   'Precision': 0.9516129032258065,
#   'Sensitivity': 0.9554655870445344,
#   'Specificity': 0.5862068965517241,
#   'Weighted accuracy': 0.7708362417981293},
#  {'Accuracy': 0.9673321234119783,
#   'F-score': 0.9642857142857143,
#   'MCC': 0.9342112319595877,
#   'Precision': 0.9604743083003953,
#   'Sensitivity': 0.9681274900398407,
#   'Specificity': 0.9666666666666667,
#   'Weighted accuracy': 0.9673970783532537},
#  {'Accuracy': 0.939622641509434,
#   'F-score': 0.968,
#   'MCC': 0.455483108579117,
#   'Precision': 0.952755905511811,
#   'Sensitivity': 0.983739837398374,
#   'Specificity': 0.3684210526315789,
#   'Weighted accuracy': 0.6760804450149764},
#  {'Accuracy': 0.939622641509434,
#   'F-score': 0.968,
#   'MCC': 0.455483108579117,
#   'Precision': 0.952755905511811,
#   'Sensitivity': 0.983739837398374,
#   'Specificity': 0.3684210526315789,
#   'Weighted accuracy': 0.6760804450149764},
#  {'Accuracy': 0.939622641509434,
#   'F-score': 0.968,
#   'MCC': 0.455483108579117,
#   'Precision': 0.952755905511811,
#   'Sensitivity': 0.983739837398374,
#   'Specificity': 0.3684210526315789,
#   'Weighted accuracy': 0.6760804450149764},
#  {'Accuracy': 0.9166666666666666,
#   'F-score': 0.9535353535353535,
#   'MCC': 0.5501478169025211,
#   'Precision': 0.9516129032258065,
#   'Sensitivity': 0.9554655870445344,
#   'Specificity': 0.5862068965517241,
#   'Weighted accuracy': 0.7708362417981293},
#  {'Accuracy': 0.9166666666666666,
#   'F-score': 0.9535353535353535,
#   'MCC': 0.5501478169025211,
#   'Precision': 0.9516129032258065,
#   'Sensitivity': 0.9554655870445344,
#   'Specificity': 0.5862068965517241,
#   'Weighted accuracy': 0.7708362417981293},
#  {'Accuracy': 0.9429657794676806,
#   'F-score': 0.9698189134808854,
#   'MCC': 0.4820755429160594,
#   'Precision': 0.9525691699604744,
#   'Sensitivity': 0.9877049180327869,
#   'Specificity': 0.3684210526315789,
#   'Weighted accuracy': 0.6780629853321829},
#  {'Accuracy': 0.9673321234119783,
#   'F-score': 0.9642857142857143,
#   'MCC': 0.9342112319595877,
#   'Precision': 0.9604743083003953,
#   'Sensitivity': 0.9681274900398407,
#   'Specificity': 0.9666666666666667,
#   'Weighted accuracy': 0.9673970783532537},
#  {'Accuracy': 0.9724770642201835,
#   'F-score': 0.9825242718446602,
#   'MCC': 0.9209804967013753,
#   'Precision': 0.9656488549618321,
#   'Sensitivity': 1.0,
#   'Specificity': 0.8783783783783784,
#   'Weighted accuracy': 0.9391891891891893},
#  {'Accuracy': 0.9703557312252964,
#   'F-score': 0.9719626168224299,
#   'MCC': 0.9408899372484201,
#   'Precision': 0.959409594095941,
#   'Sensitivity': 0.9848484848484849,
#   'Specificity': 0.9545454545454546,
#   'Weighted accuracy': 0.9696969696969697},
#  {'Accuracy': 0.9591078066914498,
#   'F-score': 0.9773195876288661,
#   'MCC': 0.7919230626120028,
#   'Precision': 1.0,
#   'Sensitivity': 0.9556451612903226,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.9778225806451613},
#  {'Accuracy': 0.964824120603015,
#   'F-score': 0.966183574879227,
#   'MCC': 0.9319324357268327,
#   'Precision': 0.9345794392523364,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9292929292929293,
#   'Weighted accuracy': 0.9646464646464646},
#  {'Accuracy': 0.9544364508393285,
#   'F-score': 0.957683741648107,
#   'MCC': 0.9084330128439788,
#   'Precision': 0.9641255605381166,
#   'Sensitivity': 0.9513274336283186,
#   'Specificity': 0.9581151832460733,
#   'Weighted accuracy': 0.9547213084371959},
#  {'Accuracy': 0.9548611111111112,
#   'F-score': 0.9651474530831099,
#   'MCC': 0.9057482903421269,
#   'Precision': 0.9326424870466321,
#   'Sensitivity': 1.0,
#   'Specificity': 0.8796296296296297,
#   'Weighted accuracy': 0.9398148148148149},
#  {'Accuracy': 0.6996466431095406,
#   'F-score': 0.8072562358276644,
#   'MCC': 0.3590479696430522,
#   'Precision': 0.6768060836501901,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19047619047619047,
#   'Weighted accuracy': 0.5952380952380952},
#  {'Accuracy': 0.6996466431095406,
#   'F-score': 0.8072562358276644,
#   'MCC': 0.3590479696430522,
#   'Precision': 0.6768060836501901,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19047619047619047,
#   'Weighted accuracy': 0.5952380952380952},
#  {'Accuracy': 0.6996466431095406,
#   'F-score': 0.8072562358276644,
#   'MCC': 0.3590479696430522,
#   'Precision': 0.6768060836501901,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19047619047619047,
#   'Weighted accuracy': 0.5952380952380952},
#  {'Accuracy': 0.6996466431095406,
#   'F-score': 0.8072562358276644,
#   'MCC': 0.3590479696430522,
#   'Precision': 0.6768060836501901,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19047619047619047,
#   'Weighted accuracy': 0.5952380952380952},
#  {'Accuracy': 0.6996466431095406,
#   'F-score': 0.8072562358276644,
#   'MCC': 0.3590479696430522,
#   'Precision': 0.6768060836501901,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19047619047619047,
#   'Weighted accuracy': 0.5952380952380952},
#  {'Accuracy': 0.6996466431095406,
#   'F-score': 0.8072562358276644,
#   'MCC': 0.3590479696430522,
#   'Precision': 0.6768060836501901,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19047619047619047,
#   'Weighted accuracy': 0.5952380952380952},
#  {'Accuracy': 0.6996466431095406,
#   'F-score': 0.8072562358276644,
#   'MCC': 0.3590479696430522,
#   'Precision': 0.6768060836501901,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19047619047619047,
#   'Weighted accuracy': 0.5952380952380952},
#  {'Accuracy': 0.6996466431095406,
#   'F-score': 0.8072562358276644,
#   'MCC': 0.3590479696430522,
#   'Precision': 0.6768060836501901,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19047619047619047,
#   'Weighted accuracy': 0.5952380952380952},
#  {'Accuracy': 0.6996466431095406,
#   'F-score': 0.8072562358276644,
#   'MCC': 0.3590479696430522,
#   'Precision': 0.6768060836501901,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19047619047619047,
#   'Weighted accuracy': 0.5952380952380952},
#  {'Accuracy': 0.6996466431095406,
#   'F-score': 0.8072562358276644,
#   'MCC': 0.3590479696430522,
#   'Precision': 0.6768060836501901,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19047619047619047,
#   'Weighted accuracy': 0.5952380952380952},
#  {'Accuracy': 0.6996466431095406,
#   'F-score': 0.8072562358276644,
#   'MCC': 0.3590479696430522,
#   'Precision': 0.6768060836501901,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19047619047619047,
#   'Weighted accuracy': 0.5952380952380952},
#  {'Accuracy': 0.6996466431095406,
#   'F-score': 0.8072562358276644,
#   'MCC': 0.3590479696430522,
#   'Precision': 0.6768060836501901,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19047619047619047,
#   'Weighted accuracy': 0.5952380952380952},
#  {'Accuracy': 0.6996466431095406,
#   'F-score': 0.8072562358276644,
#   'MCC': 0.3590479696430522,
#   'Precision': 0.6768060836501901,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19047619047619047,
#   'Weighted accuracy': 0.5952380952380952},
#  {'Accuracy': 0.6996466431095406,
#   'F-score': 0.8072562358276644,
#   'MCC': 0.3590479696430522,
#   'Precision': 0.6768060836501901,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19047619047619047,
#   'Weighted accuracy': 0.5952380952380952},
#  {'Accuracy': 0.6996466431095406,
#   'F-score': 0.8072562358276644,
#   'MCC': 0.3590479696430522,
#   'Precision': 0.6768060836501901,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19047619047619047,
#   'Weighted accuracy': 0.5952380952380952},
#  {'Accuracy': 0.6996466431095406,
#   'F-score': 0.8072562358276644,
#   'MCC': 0.3590479696430522,
#   'Precision': 0.6768060836501901,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19047619047619047,
#   'Weighted accuracy': 0.5952380952380952},
#  {'Accuracy': 0.6996466431095406,
#   'F-score': 0.8072562358276644,
#   'MCC': 0.3590479696430522,
#   'Precision': 0.6768060836501901,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19047619047619047,
#   'Weighted accuracy': 0.5952380952380952},
#  {'Accuracy': 0.6996466431095406,
#   'F-score': 0.8072562358276644,
#   'MCC': 0.3590479696430522,
#   'Precision': 0.6768060836501901,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19047619047619047,
#   'Weighted accuracy': 0.5952380952380952},
#  {'Accuracy': 0.6996466431095406,
#   'F-score': 0.8072562358276644,
#   'MCC': 0.3590479696430522,
#   'Precision': 0.6768060836501901,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19047619047619047,
#   'Weighted accuracy': 0.5952380952380952},
#  {'Accuracy': 0.6996466431095406,
#   'F-score': 0.8072562358276644,
#   'MCC': 0.3590479696430522,
#   'Precision': 0.6768060836501901,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19047619047619047,
#   'Weighted accuracy': 0.5952380952380952},
#  {'Accuracy': 0.7031802120141343,
#   'F-score': 0.8099547511312218,
#   'MCC': 0.36178201177244507,
#   'Precision': 0.6806083650190115,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19230769230769232,
#   'Weighted accuracy': 0.5961538461538461},
#  {'Accuracy': 0.6996466431095406,
#   'F-score': 0.8072562358276644,
#   'MCC': 0.3590479696430522,
#   'Precision': 0.6768060836501901,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19047619047619047,
#   'Weighted accuracy': 0.5952380952380952},
#  {'Accuracy': 0.7736486486486487,
#   'F-score': 0.8408551068883611,
#   'MCC': 0.5630149293915124,
#   'Precision': 0.7254098360655737,
#   'Sensitivity': 1.0,
#   'Specificity': 0.4369747899159664,
#   'Weighted accuracy': 0.7184873949579832},
#  {'Accuracy': 0.8426573426573427,
#   'F-score': 0.8849104859335039,
#   'MCC': 0.6910509039066577,
#   'Precision': 0.7935779816513762,
#   'Sensitivity': 1.0,
#   'Specificity': 0.6017699115044248,
#   'Weighted accuracy': 0.8008849557522124},
#  {'Accuracy': 0.6996466431095406,
#   'F-score': 0.8072562358276644,
#   'MCC': 0.3590479696430522,
#   'Precision': 0.6768060836501901,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19047619047619047,
#   'Weighted accuracy': 0.5952380952380952},
#  {'Accuracy': 0.6996466431095406,
#   'F-score': 0.8072562358276644,
#   'MCC': 0.3590479696430522,
#   'Precision': 0.6768060836501901,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19047619047619047,
#   'Weighted accuracy': 0.5952380952380952},
#  {'Accuracy': 0.6996466431095406,
#   'F-score': 0.8072562358276644,
#   'MCC': 0.3590479696430522,
#   'Precision': 0.6768060836501901,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19047619047619047,
#   'Weighted accuracy': 0.5952380952380952},
#  {'Accuracy': 0.6996466431095406,
#   'F-score': 0.8072562358276644,
#   'MCC': 0.3590479696430522,
#   'Precision': 0.6768060836501901,
#   'Sensitivity': 1.0,
#   'Specificity': 0.19047619047619047,
#   'Weighted accuracy': 0.5952380952380952},
#  {'Accuracy': 0.9423076923076923,
#   'F-score': 0.9528795811518325,
#   'MCC': 0.8854377448471462,
#   'Precision': 0.91,
#   'Sensitivity': 1.0,
#   'Specificity': 0.8615384615384616,
#   'Weighted accuracy': 0.9307692307692308},
#  {'Accuracy': 0.7569444444444444,
#   'F-score': 0.8471615720524017,
#   'MCC': 0.43315227085696933,
#   'Precision': 0.7348484848484849,
#   'Sensitivity': 1.0,
#   'Specificity': 0.2553191489361702,
#   'Weighted accuracy': 0.6276595744680851},
#  {'Accuracy': 0.7569444444444444,
#   'F-score': 0.8471615720524017,
#   'MCC': 0.43315227085696933,
#   'Precision': 0.7348484848484849,
#   'Sensitivity': 1.0,
#   'Specificity': 0.2553191489361702,
#   'Weighted accuracy': 0.6276595744680851},
#  {'Accuracy': 0.7048611111111112,
#   'F-score': 0.806378132118451,
#   'MCC': 0.39779669641328874,
#   'Precision': 0.6755725190839694,
#   'Sensitivity': 1.0,
#   'Specificity': 0.23423423423423423,
#   'Weighted accuracy': 0.6171171171171171},
#  {'Accuracy': 0.7048611111111112,
#   'F-score': 0.806378132118451,
#   'MCC': 0.39779669641328874,
#   'Precision': 0.6755725190839694,
#   'Sensitivity': 1.0,
#   'Specificity': 0.23423423423423423,
#   'Weighted accuracy': 0.6171171171171171},
#  {'Accuracy': 0.9370629370629371,
#   'F-score': 0.9554455445544554,
#   'MCC': 0.8588683210161676,
#   'Precision': 0.9146919431279621,
#   'Sensitivity': 1.0,
#   'Specificity': 0.8064516129032258,
#   'Weighted accuracy': 0.9032258064516129},
#  {'Accuracy': 0.7048611111111112,
#   'F-score': 0.806378132118451,
#   'MCC': 0.39779669641328874,
#   'Precision': 0.6755725190839694,
#   'Sensitivity': 1.0,
#   'Specificity': 0.23423423423423423,
#   'Weighted accuracy': 0.6171171171171171},
#  {'Accuracy': 0.9965397923875432,
#   'F-score': 0.9973190348525469,
#   'MCC': 0.9924694387926183,
#   'Precision': 0.9946524064171123,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9902912621359223,
#   'Weighted accuracy': 0.9951456310679612},
#  {'Accuracy': 0.951048951048951,
#   'F-score': 0.9637305699481865,
#   'MCC': 0.8943153806124549,
#   'Precision': 0.93,
#   'Sensitivity': 1.0,
#   'Specificity': 0.86,
#   'Weighted accuracy': 0.9299999999999999},
#  {'Accuracy': 0.9370629370629371,
#   'F-score': 0.9554455445544554,
#   'MCC': 0.8588683210161676,
#   'Precision': 0.9146919431279621,
#   'Sensitivity': 1.0,
#   'Specificity': 0.8064516129032258,
#   'Weighted accuracy': 0.9032258064516129},
#  {'Accuracy': 0.937888198757764,
#   'F-score': 0.946524064171123,
#   'MCC': 0.8751909964743667,
#   'Precision': 0.917098445595855,
#   'Sensitivity': 0.9779005524861878,
#   'Specificity': 0.8865248226950354,
#   'Weighted accuracy': 0.9322126875906116},
#  {'Accuracy': 0.9895104895104895,
#   'F-score': 0.9921259842519685,
#   'MCC': 0.9766936123325135,
#   'Precision': 0.984375,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9690721649484536,
#   'Weighted accuracy': 0.9845360824742269},
#  {'Accuracy': 0.9895104895104895,
#   'F-score': 0.9921259842519685,
#   'MCC': 0.9766936123325135,
#   'Precision': 0.984375,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9690721649484536,
#   'Weighted accuracy': 0.9845360824742269},
#  {'Accuracy': 0.9895104895104895,
#   'F-score': 0.9921259842519685,
#   'MCC': 0.9766936123325135,
#   'Precision': 0.984375,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9690721649484536,
#   'Weighted accuracy': 0.9845360824742269},
#  {'Accuracy': 0.9895104895104895,
#   'F-score': 0.9921259842519685,
#   'MCC': 0.9766936123325135,
#   'Precision': 0.984375,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9690721649484536,
#   'Weighted accuracy': 0.9845360824742269},
#  {'Accuracy': 0.7896440129449838,
#   'F-score': 0.8247978436657681,
#   'MCC': 0.6398465985881074,
#   'Precision': 0.7018348623853211,
#   'Sensitivity': 1.0,
#   'Specificity': 0.5833333333333334,
#   'Weighted accuracy': 0.7916666666666667},
#  {'Accuracy': 0.9896551724137931,
#   'F-score': 0.9919999999999999,
#   'MCC': 0.9776188959603358,
#   'Precision': 0.9841269841269841,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9711538461538461,
#   'Weighted accuracy': 0.9855769230769231},
#  {'Accuracy': 0.9896551724137931,
#   'F-score': 0.9919999999999999,
#   'MCC': 0.9776188959603358,
#   'Precision': 0.9841269841269841,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9711538461538461,
#   'Weighted accuracy': 0.9855769230769231},
#  {'Accuracy': 0.7048611111111112,
#   'F-score': 0.806378132118451,
#   'MCC': 0.39779669641328874,
#   'Precision': 0.6755725190839694,
#   'Sensitivity': 1.0,
#   'Specificity': 0.23423423423423423,
#   'Weighted accuracy': 0.6171171171171171},
#  {'Accuracy': 0.9790209790209791,
#   'F-score': 0.9850746268656716,
#   'MCC': 0.951005659660279,
#   'Precision': 0.9705882352941176,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9318181818181818,
#   'Weighted accuracy': 0.9659090909090908},
#  {'Accuracy': 0.7669902912621359,
#   'F-score': 0.7482517482517482,
#   'MCC': 0.6202422762286577,
#   'Precision': 0.5977653631284916,
#   'Sensitivity': 1.0,
#   'Specificity': 0.6435643564356436,
#   'Weighted accuracy': 0.8217821782178218},
#  {'Accuracy': 0.9896193771626297,
#   'F-score': 0.9919999999999999,
#   'MCC': 0.977477923733023,
#   'Precision': 0.9841269841269841,
#   'Sensitivity': 1.0,
#   'Specificity': 0.970873786407767,
#   'Weighted accuracy': 0.9854368932038835},
#  {'Accuracy': 0.9358974358974359,
#   'F-score': 0.946524064171123,
#   'MCC': 0.8695136024893839,
#   'Precision': 0.917098445595855,
#   'Sensitivity': 0.9779005524861878,
#   'Specificity': 0.8778625954198473,
#   'Weighted accuracy': 0.9278815739530175},
#  {'Accuracy': 0.8344370860927153,
#   'F-score': 0.845679012345679,
#   'MCC': 0.6778065382388924,
#   'Precision': 0.9133333333333333,
#   'Sensitivity': 0.7873563218390804,
#   'Specificity': 0.8984375,
#   'Weighted accuracy': 0.8428969109195402},
#  {'Accuracy': 0.9653979238754326,
#   'F-score': 0.9744897959183674,
#   'MCC': 0.9208464361021117,
#   'Precision': 0.9794871794871794,
#   'Sensitivity': 0.9695431472081218,
#   'Specificity': 0.9565217391304348,
#   'Weighted accuracy': 0.9630324431692783},
#  {'Accuracy': 0.9326923076923077,
#   'F-score': 0.9445910290237467,
#   'MCC': 0.868149877916432,
#   'Precision': 0.895,
#   'Sensitivity': 1.0,
#   'Specificity': 0.8421052631578947,
#   'Weighted accuracy': 0.9210526315789473},
#  {'Accuracy': 0.9752650176678446,
#   'F-score': 0.9812332439678284,
#   'MCC': 0.9464337494538447,
#   'Precision': 0.9631578947368421,
#   'Sensitivity': 1.0,
#   'Specificity': 0.93,
#   'Weighted accuracy': 0.9650000000000001},
#  {'Accuracy': 0.9752650176678446,
#   'F-score': 0.9812332439678284,
#   'MCC': 0.9464337494538447,
#   'Precision': 0.9631578947368421,
#   'Sensitivity': 1.0,
#   'Specificity': 0.93,
#   'Weighted accuracy': 0.9650000000000001},
#  {'Accuracy': 0.951048951048951,
#   'F-score': 0.9656862745098039,
#   'MCC': 0.887007953060025,
#   'Precision': 0.933649289099526,
#   'Sensitivity': 1.0,
#   'Specificity': 0.8426966292134831,
#   'Weighted accuracy': 0.9213483146067416},
#  {'Accuracy': 0.951048951048951,
#   'F-score': 0.9656862745098039,
#   'MCC': 0.887007953060025,
#   'Precision': 0.933649289099526,
#   'Sensitivity': 1.0,
#   'Specificity': 0.8426966292134831,
#   'Weighted accuracy': 0.9213483146067416},
#  {'Accuracy': 0.9440559440559441,
#   'F-score': 0.960591133004926,
#   'MCC': 0.8727422753680631,
#   'Precision': 0.9241706161137441,
#   'Sensitivity': 1.0,
#   'Specificity': 0.8241758241758241,
#   'Weighted accuracy': 0.9120879120879121},
#  {'Accuracy': 0.986159169550173,
#   'F-score': 0.9895287958115183,
#   'MCC': 0.9692378020260586,
#   'Precision': 0.984375,
#   'Sensitivity': 0.9947368421052631,
#   'Specificity': 0.9696969696969697,
#   'Weighted accuracy': 0.9822169059011164},
#  {'Accuracy': 0.9676470588235294,
#   'F-score': 0.9693593314763231,
#   'MCC': 0.9359170713266571,
#   'Precision': 0.9508196721311475,
#   'Sensitivity': 0.9886363636363636,
#   'Specificity': 0.9451219512195121,
#   'Weighted accuracy': 0.9668791574279378},
#  {'Accuracy': 0.8268551236749117,
#   'F-score': 0.8707124010554089,
#   'MCC': 0.6714576515252901,
#   'Precision': 0.7710280373831776,
#   'Sensitivity': 1.0,
#   'Specificity': 0.5847457627118644,
#   'Weighted accuracy': 0.7923728813559322},
#  {'Accuracy': 0.9358974358974359,
#   'F-score': 0.946524064171123,
#   'MCC': 0.8695136024893839,
#   'Precision': 0.917098445595855,
#   'Sensitivity': 0.9779005524861878,
#   'Specificity': 0.8778625954198473,
#   'Weighted accuracy': 0.9278815739530175},
#  {'Accuracy': 0.9358974358974359,
#   'F-score': 0.9473684210526316,
#   'MCC': 0.8738628975053029,
#   'Precision': 0.9,
#   'Sensitivity': 1.0,
#   'Specificity': 0.8484848484848485,
#   'Weighted accuracy': 0.9242424242424243},
#  {'Accuracy': 0.9081272084805654,
#   'F-score': 0.9281767955801106,
#   'MCC': 0.8186530026099001,
#   'Precision': 0.865979381443299,
#   'Sensitivity': 1.0,
#   'Specificity': 0.7739130434782608,
#   'Weighted accuracy': 0.8869565217391304},
#  {'Accuracy': 0.9717314487632509,
#   'F-score': 0.978494623655914,
#   'MCC': 0.9391602027338926,
#   'Precision': 0.9578947368421052,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9207920792079208,
#   'Weighted accuracy': 0.9603960396039604},
#  {'Accuracy': 0.9300699300699301,
#   'F-score': 0.9487179487179488,
#   'MCC': 0.8507280573022644,
#   'Precision': 0.9024390243902439,
#   'Sensitivity': 1.0,
#   'Specificity': 0.801980198019802,
#   'Weighted accuracy': 0.900990099009901},
#  {'Accuracy': 0.9300699300699301,
#   'F-score': 0.9487179487179488,
#   'MCC': 0.8507280573022644,
#   'Precision': 0.9024390243902439,
#   'Sensitivity': 1.0,
#   'Specificity': 0.801980198019802,
#   'Weighted accuracy': 0.900990099009901},
#  {'Accuracy': 0.9896907216494846,
#   'F-score': 0.9919999999999999,
#   'MCC': 0.9777571632541407,
#   'Precision': 0.9841269841269841,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9714285714285714,
#   'Weighted accuracy': 0.9857142857142858},
#  {'Accuracy': 0.9078947368421053,
#   'F-score': 0.9315960912052117,
#   'MCC': 0.8102641402928284,
#   'Precision': 0.8719512195121951,
#   'Sensitivity': 1.0,
#   'Specificity': 0.7529411764705882,
#   'Weighted accuracy': 0.8764705882352941},
#  {'Accuracy': 0.8641114982578397,
#   'F-score': 0.9060240963855422,
#   'MCC': 0.7084741746321302,
#   'Precision': 0.8281938325991189,
#   'Sensitivity': 1.0,
#   'Specificity': 0.6060606060606061,
#   'Weighted accuracy': 0.803030303030303},
#  {'Accuracy': 0.9300699300699301,
#   'F-score': 0.9487179487179488,
#   'MCC': 0.8507280573022644,
#   'Precision': 0.9024390243902439,
#   'Sensitivity': 1.0,
#   'Specificity': 0.801980198019802,
#   'Weighted accuracy': 0.900990099009901},
#  {'Accuracy': 0.9930555555555556,
#   'F-score': 0.9947089947089947,
#   'MCC': 0.9847254493138256,
#   'Precision': 0.9894736842105263,
#   'Sensitivity': 1.0,
#   'Specificity': 0.98,
#   'Weighted accuracy': 0.99},
#  {'Accuracy': 0.9793103448275862,
#   'F-score': 0.9842931937172774,
#   'MCC': 0.9550224709144208,
#   'Precision': 0.9690721649484536,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9411764705882353,
#   'Weighted accuracy': 0.9705882352941176},
#  {'Accuracy': 0.9337979094076655,
#   'F-score': 0.9501312335958004,
#   'MCC': 0.851713603509974,
#   'Precision': 0.9476439790575916,
#   'Sensitivity': 0.9526315789473684,
#   'Specificity': 0.8969072164948454,
#   'Weighted accuracy': 0.9247693977211069},
#  {'Accuracy': 0.9337979094076655,
#   'F-score': 0.9501312335958004,
#   'MCC': 0.851713603509974,
#   'Precision': 0.9476439790575916,
#   'Sensitivity': 0.9526315789473684,
#   'Specificity': 0.8969072164948454,
#   'Weighted accuracy': 0.9247693977211069},
#  {'Accuracy': 0.9337979094076655,
#   'F-score': 0.9501312335958004,
#   'MCC': 0.851713603509974,
#   'Precision': 0.9476439790575916,
#   'Sensitivity': 0.9526315789473684,
#   'Specificity': 0.8969072164948454,
#   'Weighted accuracy': 0.9247693977211069},
#  {'Accuracy': 0.9337979094076655,
#   'F-score': 0.9501312335958004,
#   'MCC': 0.851713603509974,
#   'Precision': 0.9476439790575916,
#   'Sensitivity': 0.9526315789473684,
#   'Specificity': 0.8969072164948454,
#   'Weighted accuracy': 0.9247693977211069},
#  {'Accuracy': 0.9337979094076655,
#   'F-score': 0.9501312335958004,
#   'MCC': 0.851713603509974,
#   'Precision': 0.9476439790575916,
#   'Sensitivity': 0.9526315789473684,
#   'Specificity': 0.8969072164948454,
#   'Weighted accuracy': 0.9247693977211069},
#  {'Accuracy': 0.9337979094076655,
#   'F-score': 0.9501312335958004,
#   'MCC': 0.851713603509974,
#   'Precision': 0.9476439790575916,
#   'Sensitivity': 0.9526315789473684,
#   'Specificity': 0.8969072164948454,
#   'Weighted accuracy': 0.9247693977211069},
#  {'Accuracy': 0.8557046979865772,
#   'F-score': 0.8883116883116884,
#   'MCC': 0.7269908604907148,
#   'Precision': 0.7990654205607477,
#   'Sensitivity': 1.0,
#   'Specificity': 0.6614173228346457,
#   'Weighted accuracy': 0.8307086614173229},
#  {'Accuracy': 0.9337979094076655,
#   'F-score': 0.9501312335958004,
#   'MCC': 0.851713603509974,
#   'Precision': 0.9476439790575916,
#   'Sensitivity': 0.9526315789473684,
#   'Specificity': 0.8969072164948454,
#   'Weighted accuracy': 0.9247693977211069},
#  {'Accuracy': 0.9337979094076655,
#   'F-score': 0.9501312335958004,
#   'MCC': 0.851713603509974,
#   'Precision': 0.9476439790575916,
#   'Sensitivity': 0.9526315789473684,
#   'Specificity': 0.8969072164948454,
#   'Weighted accuracy': 0.9247693977211069},
#  {'Accuracy': 0.9337979094076655,
#   'F-score': 0.9501312335958004,
#   'MCC': 0.851713603509974,
#   'Precision': 0.9476439790575916,
#   'Sensitivity': 0.9526315789473684,
#   'Specificity': 0.8969072164948454,
#   'Weighted accuracy': 0.9247693977211069},
#  {'Accuracy': 0.9413793103448276,
#   'F-score': 0.9551451187335093,
#   'MCC': 0.876651040481312,
#   'Precision': 0.9187817258883249,
#   'Sensitivity': 0.9945054945054945,
#   'Specificity': 0.8518518518518519,
#   'Weighted accuracy': 0.9231786731786732},
#  {'Accuracy': 0.9407665505226481,
#   'F-score': 0.9569620253164557,
#   'MCC': 0.8708167288884996,
#   'Precision': 0.9174757281553398,
#   'Sensitivity': 1.0,
#   'Specificity': 0.826530612244898,
#   'Weighted accuracy': 0.9132653061224489},
#  {'Accuracy': 0.8896321070234113,
#   'F-score': 0.916030534351145,
#   'MCC': 0.7814877878152917,
#   'Precision': 0.8450704225352113,
#   'Sensitivity': 1.0,
#   'Specificity': 0.7226890756302521,
#   'Weighted accuracy': 0.8613445378151261},
#  {'Accuracy': 0.9444444444444444,
#   'F-score': 0.960591133004926,
#   'MCC': 0.8747419738805089,
#   'Precision': 0.9241706161137441,
#   'Sensitivity': 1.0,
#   'Specificity': 0.8279569892473119,
#   'Weighted accuracy': 0.913978494623656},
#  {'Accuracy': 0.9166666666666666,
#   'F-score': 0.9396984924623115,
#   'MCC': 0.8219856793405618,
#   'Precision': 0.8862559241706162,
#   'Sensitivity': 1.0,
#   'Specificity': 0.7623762376237624,
#   'Weighted accuracy': 0.8811881188118812},
#  {'Accuracy': 1.0,
#   'F-score': 1.0,
#   'MCC': 1.0,
#   'Precision': 1.0,
#   'Sensitivity': 1.0,
#   'Specificity': 1.0,
#   'Weighted accuracy': 1.0},
#  {'Accuracy': 0.7727272727272727,
#   'F-score': 0.854586129753915,
#   'MCC': 0.46396599388560245,
#   'Precision': 0.7519685039370079,
#   'Sensitivity': 0.9896373056994818,
#   'Specificity': 0.3225806451612903,
#   'Weighted accuracy': 0.656108975430386},
#  {'Accuracy': 0.7447552447552448,
#   'F-score': 0.8337129840546698,
#   'MCC': 0.4339632969718949,
#   'Precision': 0.7204724409448819,
#   'Sensitivity': 0.9891891891891892,
#   'Specificity': 0.297029702970297,
#   'Weighted accuracy': 0.6431094460797431},
#  {'Accuracy': 0.96875,
#   'F-score': 0.9775561097256857,
#   'MCC': 0.9287444631526431,
#   'Precision': 0.9560975609756097,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9021739130434783,
#   'Weighted accuracy': 0.9510869565217391},
#  {'Accuracy': 0.9413793103448276,
#   'F-score': 0.9551451187335093,
#   'MCC': 0.876651040481312,
#   'Precision': 0.9187817258883249,
#   'Sensitivity': 0.9945054945054945,
#   'Specificity': 0.8518518518518519,
#   'Weighted accuracy': 0.9231786731786732},
#  {'Accuracy': 0.9444444444444444,
#   'F-score': 0.960591133004926,
#   'MCC': 0.8747419738805089,
#   'Precision': 0.9241706161137441,
#   'Sensitivity': 1.0,
#   'Specificity': 0.8279569892473119,
#   'Weighted accuracy': 0.913978494623656},
#  {'Accuracy': 0.7804878048780488,
#   'F-score': 0.8596881959910913,
#   'MCC': 0.4779546308321375,
#   'Precision': 0.7598425196850394,
#   'Sensitivity': 0.9897435897435898,
#   'Specificity': 0.33695652173913043,
#   'Weighted accuracy': 0.6633500557413601},
#  {'Accuracy': 0.9413793103448276,
#   'F-score': 0.9551451187335093,
#   'MCC': 0.876651040481312,
#   'Precision': 0.9187817258883249,
#   'Sensitivity': 0.9945054945054945,
#   'Specificity': 0.8518518518518519,
#   'Weighted accuracy': 0.9231786731786732},
#  {'Accuracy': 0.9131944444444444,
#   'F-score': 0.9370277078085643,
#   'MCC': 0.8157564590622695,
#   'Precision': 0.8815165876777251,
#   'Sensitivity': 1.0,
#   'Specificity': 0.7549019607843137,
#   'Weighted accuracy': 0.8774509803921569},
#  {'Accuracy': 0.9137931034482759,
#   'F-score': 0.9370277078085643,
#   'MCC': 0.8182991884351691,
#   'Precision': 0.8815165876777251,
#   'Sensitivity': 1.0,
#   'Specificity': 0.7596153846153846,
#   'Weighted accuracy': 0.8798076923076923},
#  {'Accuracy': 0.9027777777777778,
#   'F-score': 0.9289340101522843,
#   'MCC': 0.7975079669482755,
#   'Precision': 0.8672985781990521,
#   'Sensitivity': 1.0,
#   'Specificity': 0.7333333333333333,
#   'Weighted accuracy': 0.8666666666666667},
#  {'Accuracy': 0.7586206896551724,
#   'F-score': 0.8394495412844036,
#   'MCC': 0.4904000555024748,
#   'Precision': 0.7261904761904762,
#   'Sensitivity': 0.9945652173913043,
#   'Specificity': 0.3490566037735849,
#   'Weighted accuracy': 0.6718109105824446},
#  {'Accuracy': 0.7586206896551724,
#   'F-score': 0.8394495412844036,
#   'MCC': 0.4904000555024748,
#   'Precision': 0.7261904761904762,
#   'Sensitivity': 0.9945652173913043,
#   'Specificity': 0.3490566037735849,
#   'Weighted accuracy': 0.6718109105824446},
#  {'Accuracy': 0.9758620689655172,
#   'F-score': 0.9816272965879265,
#   'MCC': 0.9478441684744069,
#   'Precision': 0.9639175257731959,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9320388349514563,
#   'Weighted accuracy': 0.9660194174757282},
#  {'Accuracy': 0.9724137931034482,
#   'F-score': 0.9789473684210526,
#   'MCC': 0.9407507083819675,
#   'Precision': 0.9587628865979382,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9230769230769231,
#   'Weighted accuracy': 0.9615384615384616},
#  {'Accuracy': 0.7804878048780488,
#   'F-score': 0.8596881959910913,
#   'MCC': 0.4779546308321375,
#   'Precision': 0.7598425196850394,
#   'Sensitivity': 0.9897435897435898,
#   'Specificity': 0.33695652173913043,
#   'Weighted accuracy': 0.6633500557413601},
#  {'Accuracy': 0.7804878048780488,
#   'F-score': 0.8596881959910913,
#   'MCC': 0.4779546308321375,
#   'Precision': 0.7598425196850394,
#   'Sensitivity': 0.9897435897435898,
#   'Specificity': 0.33695652173913043,
#   'Weighted accuracy': 0.6633500557413601},
#  {'Accuracy': 0.7804878048780488,
#   'F-score': 0.8596881959910913,
#   'MCC': 0.4779546308321375,
#   'Precision': 0.7598425196850394,
#   'Sensitivity': 0.9897435897435898,
#   'Specificity': 0.33695652173913043,
#   'Weighted accuracy': 0.6633500557413601},
#  {'Accuracy': 0.8793103448275862,
#   'F-score': 0.8979591836734693,
#   'MCC': 0.7778944823740949,
#   'Precision': 0.8148148148148148,
#   'Sensitivity': 1.0,
#   'Specificity': 0.7426470588235294,
#   'Weighted accuracy': 0.8713235294117647},
#  {'Accuracy': 0.8974358974358975,
#   'F-score': 0.9053254437869822,
#   'MCC': 0.8042554858789666,
#   'Precision': 0.8453038674033149,
#   'Sensitivity': 0.9745222929936306,
#   'Specificity': 0.8193548387096774,
#   'Weighted accuracy': 0.896938565851654},
#  {'Accuracy': 0.8769716088328076,
#   'F-score': 0.893732970027248,
#   'MCC': 0.7758550929636908,
#   'Precision': 0.8078817733990148,
#   'Sensitivity': 1.0,
#   'Specificity': 0.7450980392156863,
#   'Weighted accuracy': 0.8725490196078431},
#  {'Accuracy': 0.8,
#   'F-score': 0.8363636363636363,
#   'MCC': 0.6517023163154394,
#   'Precision': 0.71875,
#   'Sensitivity': 1.0,
#   'Specificity': 0.5909090909090909,
#   'Weighted accuracy': 0.7954545454545454}]

# %% [markdown]
# #### Evaluate hmm

# %%
metrics_global_hmm, log_score_hmm, conf_matrix_hmm_pos = evaluatePositions(positions_hmm, ground_truth_positions)

# %%
print('CLASSIFICATION METRICS')
for k in metrics_global_hmm:
    print(f'{k}: {metrics_global_hmm[k]:.3}')
print('\nCONFUSION MATRIX')    
conf_matrix_hmm_pos
# Out:
# CLASSIFICATION METRICS
# Accuracy: 0.902
# Weighted accuracy: 0.911
# Precision: 0.965
# Sensitivity: 0.88
# Specificity: 0.942
# MCC: 0.8
# F-score: 0.92
#
# CONFUSION MATRIX
#                Actual positive  Actual negative
# Positive pred            25998              955
# Negative pred             3555            15513

# %%
log_score_hmm
# Out:
# [{'Accuracy': 0.9591836734693877,
#   'F-score': 0.9591836734693877,
#   'MCC': 0.9183673469387755,
#   'Precision': 0.9591836734693877,
#   'Sensitivity': 0.9591836734693877,
#   'Specificity': 0.9591836734693877,
#   'Weighted accuracy': 0.9591836734693877},
#  {'Accuracy': 0.9726277372262774,
#   'F-score': 0.9695740365111561,
#   'MCC': 0.9447578734764585,
#   'Precision': 0.9637096774193549,
#   'Sensitivity': 0.9755102040816327,
#   'Specificity': 0.9702970297029703,
#   'Weighted accuracy': 0.9729036168923015},
#  {'Accuracy': 0.9285714285714286,
#   'F-score': 0.9617706237424547,
#   'MCC': 0.420987849267374,
#   'Precision': 0.956,
#   'Sensitivity': 0.9676113360323887,
#   'Specificity': 0.42105263157894735,
#   'Weighted accuracy': 0.6943319838056681},
#  {'Accuracy': 0.9256505576208178,
#   'F-score': 0.9595141700404859,
#   'MCC': 0.5078242011050007,
#   'Precision': 0.9673469387755103,
#   'Sensitivity': 0.9518072289156626,
#   'Specificity': 0.6,
#   'Weighted accuracy': 0.7759036144578313},
#  {'Accuracy': 0.9712643678160919,
#   'F-score': 0.9694501018329938,
#   'MCC': 0.9423899321549715,
#   'Precision': 0.9635627530364372,
#   'Sensitivity': 0.9754098360655737,
#   'Specificity': 0.9676258992805755,
#   'Weighted accuracy': 0.9715178676730747},
#  {'Accuracy': 0.933579335793358,
#   'F-score': 0.9629629629629629,
#   'MCC': 0.6466283673610393,
#   'Precision': 0.975,
#   'Sensitivity': 0.9512195121951219,
#   'Specificity': 0.76,
#   'Weighted accuracy': 0.855609756097561},
#  {'Accuracy': 0.9742895805142084,
#   'F-score': 0.9617706237424546,
#   'MCC': 0.9424070802106638,
#   'Precision': 0.9598393574297188,
#   'Sensitivity': 0.9637096774193549,
#   'Specificity': 0.9796334012219959,
#   'Weighted accuracy': 0.9716715393206754},
#  {'Accuracy': 0.9182156133828996,
#   'F-score': 0.9543568464730291,
#   'MCC': 0.563551297578243,
#   'Precision': 0.9623430962343096,
#   'Sensitivity': 0.9465020576131687,
#   'Specificity': 0.6538461538461539,
#   'Weighted accuracy': 0.8001741057296613},
#  {'Accuracy': 0.9320754716981132,
#   'F-score': 0.9634146341463414,
#   'MCC': 0.48973042362002567,
#   'Precision': 0.9634146341463414,
#   'Sensitivity': 0.9634146341463414,
#   'Specificity': 0.5263157894736842,
#   'Weighted accuracy': 0.7448652118100128},
#  {'Accuracy': 0.9320754716981132,
#   'F-score': 0.9634146341463414,
#   'MCC': 0.48973042362002567,
#   'Precision': 0.9634146341463414,
#   'Sensitivity': 0.9634146341463414,
#   'Specificity': 0.5263157894736842,
#   'Weighted accuracy': 0.7448652118100128},
#  {'Accuracy': 0.9320754716981132,
#   'F-score': 0.9634146341463414,
#   'MCC': 0.48973042362002567,
#   'Precision': 0.9634146341463414,
#   'Sensitivity': 0.9634146341463414,
#   'Specificity': 0.5263157894736842,
#   'Weighted accuracy': 0.7448652118100128},
#  {'Accuracy': 0.97131931166348,
#   'F-score': 0.9694501018329938,
#   'MCC': 0.942487463122914,
#   'Precision': 0.9635627530364372,
#   'Sensitivity': 0.9754098360655737,
#   'Specificity': 0.967741935483871,
#   'Weighted accuracy': 0.9715758857747223},
#  {'Accuracy': 0.9311594202898551,
#   'F-score': 0.9611451942740287,
#   'MCC': 0.6624936787268987,
#   'Precision': 0.9710743801652892,
#   'Sensitivity': 0.951417004048583,
#   'Specificity': 0.7586206896551724,
#   'Weighted accuracy': 0.8550188468518777},
#  {'Accuracy': 0.9311594202898551,
#   'F-score': 0.9611451942740287,
#   'MCC': 0.6624936787268987,
#   'Precision': 0.9710743801652892,
#   'Sensitivity': 0.951417004048583,
#   'Specificity': 0.7586206896551724,
#   'Weighted accuracy': 0.8550188468518777},
#  {'Accuracy': 0.9398496240601504,
#   'F-score': 0.9676113360323886,
#   'MCC': 0.5475351537456119,
#   'Precision': 0.9715447154471545,
#   'Sensitivity': 0.9637096774193549,
#   'Specificity': 0.6111111111111112,
#   'Weighted accuracy': 0.7874103942652331},
#  {'Accuracy': 0.9311594202898551,
#   'F-score': 0.9611451942740287,
#   'MCC': 0.6624936787268987,
#   'Precision': 0.9710743801652892,
#   'Sensitivity': 0.951417004048583,
#   'Specificity': 0.7586206896551724,
#   'Weighted accuracy': 0.8550188468518777},
#  {'Accuracy': 0.9311594202898551,
#   'F-score': 0.9611451942740287,
#   'MCC': 0.6624936787268987,
#   'Precision': 0.9710743801652892,
#   'Sensitivity': 0.951417004048583,
#   'Specificity': 0.7586206896551724,
#   'Weighted accuracy': 0.8550188468518777},
#  {'Accuracy': 0.9311594202898551,
#   'F-score': 0.9611451942740287,
#   'MCC': 0.6624936787268987,
#   'Precision': 0.9710743801652892,
#   'Sensitivity': 0.951417004048583,
#   'Specificity': 0.7586206896551724,
#   'Weighted accuracy': 0.8550188468518777},
#  {'Accuracy': 0.942652329749104,
#   'F-score': 0.9678714859437753,
#   'MCC': 0.7017343047641027,
#   'Precision': 0.9717741935483871,
#   'Sensitivity': 0.964,
#   'Specificity': 0.7586206896551724,
#   'Weighted accuracy': 0.8613103448275862},
#  {'Accuracy': 0.9360902255639098,
#   'F-score': 0.9656565656565657,
#   'MCC': 0.50643773940983,
#   'Precision': 0.9676113360323887,
#   'Sensitivity': 0.9637096774193549,
#   'Specificity': 0.5555555555555556,
#   'Weighted accuracy': 0.7596326164874552},
#  {'Accuracy': 0.9219330855018587,
#   'F-score': 0.9574036511156186,
#   'MCC': 0.49224685765426424,
#   'Precision': 0.963265306122449,
#   'Sensitivity': 0.9516129032258065,
#   'Specificity': 0.5714285714285714,
#   'Weighted accuracy': 0.761520737327189},
#  {'Accuracy': 0.9568627450980393,
#   'F-score': 0.9774127310061601,
#   'MCC': 0.5042729056592992,
#   'Precision': 0.9714285714285714,
#   'Sensitivity': 0.9834710743801653,
#   'Specificity': 0.46153846153846156,
#   'Weighted accuracy': 0.7225047679593135},
#  {'Accuracy': 0.9222222222222223,
#   'F-score': 0.9574036511156186,
#   'MCC': 0.5120371642505676,
#   'Precision': 0.963265306122449,
#   'Sensitivity': 0.9516129032258065,
#   'Specificity': 0.5909090909090909,
#   'Weighted accuracy': 0.7712609970674487},
#  {'Accuracy': 0.9750982961992136,
#   'F-score': 0.9616161616161616,
#   'MCC': 0.943191779433065,
#   'Precision': 0.9635627530364372,
#   'Sensitivity': 0.9596774193548387,
#   'Specificity': 0.9825242718446602,
#   'Weighted accuracy': 0.9711008455997494},
#  {'Accuracy': 0.9391634980988594,
#   'F-score': 0.9673469387755101,
#   'MCC': 0.5239427878835615,
#   'Precision': 0.9634146341463414,
#   'Sensitivity': 0.9713114754098361,
#   'Specificity': 0.5263157894736842,
#   'Weighted accuracy': 0.7488136324417601},
#  {'Accuracy': 0.9673321234119783,
#   'F-score': 0.9641434262948207,
#   'MCC': 0.9341434262948207,
#   'Precision': 0.9641434262948207,
#   'Sensitivity': 0.9641434262948207,
#   'Specificity': 0.97,
#   'Weighted accuracy': 0.9670717131474104},
#  {'Accuracy': 0.9673321234119783,
#   'F-score': 0.9641434262948207,
#   'MCC': 0.9341434262948207,
#   'Precision': 0.9641434262948207,
#   'Sensitivity': 0.9641434262948207,
#   'Specificity': 0.97,
#   'Weighted accuracy': 0.9670717131474104},
#  {'Accuracy': 0.9727767695099818,
#   'F-score': 0.9709864603481625,
#   'MCC': 0.9454035400713914,
#   'Precision': 0.9653846153846154,
#   'Sensitivity': 0.9766536964980544,
#   'Specificity': 0.9693877551020408,
#   'Weighted accuracy': 0.9730207258000476},
#  {'Accuracy': 0.9667832167832168,
#   'F-score': 0.9623762376237625,
#   'MCC': 0.9326483478098918,
#   'Precision': 0.9642857142857143,
#   'Sensitivity': 0.9604743083003953,
#   'Specificity': 0.9717868338557993,
#   'Weighted accuracy': 0.9661305710780973},
#  {'Accuracy': 0.9372693726937269,
#   'F-score': 0.9653767820773932,
#   'MCC': 0.6361392044854617,
#   'Precision': 0.9753086419753086,
#   'Sensitivity': 0.9556451612903226,
#   'Specificity': 0.7391304347826086,
#   'Weighted accuracy': 0.8473877980364657},
#  {'Accuracy': 0.9311594202898551,
#   'F-score': 0.9611451942740287,
#   'MCC': 0.6624936787268987,
#   'Precision': 0.9710743801652892,
#   'Sensitivity': 0.951417004048583,
#   'Specificity': 0.7586206896551724,
#   'Weighted accuracy': 0.8550188468518777},
#  {'Accuracy': 0.9311594202898551,
#   'F-score': 0.9611451942740287,
#   'MCC': 0.6624936787268987,
#   'Precision': 0.9710743801652892,
#   'Sensitivity': 0.951417004048583,
#   'Specificity': 0.7586206896551724,
#   'Weighted accuracy': 0.8550188468518777},
#  {'Accuracy': 0.9311594202898551,
#   'F-score': 0.9611451942740287,
#   'MCC': 0.6624936787268987,
#   'Precision': 0.9710743801652892,
#   'Sensitivity': 0.951417004048583,
#   'Specificity': 0.7586206896551724,
#   'Weighted accuracy': 0.8550188468518777},
#  {'Accuracy': 0.9442379182156134,
#   'F-score': 0.9695740365111561,
#   'MCC': 0.6380776998447897,
#   'Precision': 0.9755102040816327,
#   'Sensitivity': 0.9637096774193549,
#   'Specificity': 0.7142857142857143,
#   'Weighted accuracy': 0.8389976958525346},
#  {'Accuracy': 0.9357798165137615,
#   'F-score': 0.9601518026565464,
#   'MCC': 0.8132181334006366,
#   'Precision': 0.9233576642335767,
#   'Sensitivity': 1.0,
#   'Specificity': 0.7162162162162162,
#   'Weighted accuracy': 0.8581081081081081},
#  {'Accuracy': 0.9565217391304348,
#   'F-score': 0.9583333333333334,
#   'MCC': 0.9128787878787878,
#   'Precision': 0.9583333333333334,
#   'Sensitivity': 0.9583333333333334,
#   'Specificity': 0.9545454545454546,
#   'Weighted accuracy': 0.956439393939394},
#  {'Accuracy': 0.9640287769784173,
#   'F-score': 0.9668874172185431,
#   'MCC': 0.9275285872444646,
#   'Precision': 0.9647577092511013,
#   'Sensitivity': 0.9690265486725663,
#   'Specificity': 0.9581151832460733,
#   'Weighted accuracy': 0.9635708659593198},
#  {'Accuracy': 0.9723618090452262,
#   'F-score': 0.9732360097323601,
#   'MCC': 0.9461543236770329,
#   'Precision': 0.9478672985781991,
#   'Sensitivity': 1.0,
#   'Specificity': 0.9444444444444444,
#   'Weighted accuracy': 0.9722222222222222},
#  {'Accuracy': 0.9459459459459459,
#   'F-score': 0.9567567567567568,
#   'MCC': 0.8909495449048506,
#   'Precision': 0.917098445595855,
#   'Sensitivity': 1.0,
#   'Specificity': 0.865546218487395,
#   'Weighted accuracy': 0.9327731092436975},
#  {'Accuracy': 0.950530035335689,
#   'F-score': 0.9619565217391305,
#   'MCC': 0.8953468698233825,
#   'Precision': 0.9315789473684211,
#   'Sensitivity': 0.9943820224719101,
#   'Specificity': 0.8761904761904762,
#   'Weighted accuracy': 0.9352862493311931},
#  {'Accuracy': 0.950530035335689,
#   'F-score': 0.9619565217391305,
#   'MCC': 0.8953468698233825,
#   'Precision': 0.9315789473684211,
#   'Sensitivity': 0.9943820224719101,
#   'Specificity': 0.8761904761904762,
#   'Weighted accuracy': 0.9352862493311931},
#  {'Accuracy': 0.950530035335689,
#   'F-score': 0.9619565217391305,
#   'MCC': 0.8953468698233825,
#   'Precision': 0.9315789473684211,
#   'Sensitivity': 0.9943820224719101,
#   'Specificity': 0.8761904761904762,
#   'Weighted accuracy': 0.9352862493311931},
#  {'Accuracy': 0.950530035335689,
#   'F-score': 0.9619565217391305,
#   'MCC': 0.8953468698233825,
#   'Precision': 0.9315789473684211,
#   'Sensitivity': 0.9943820224719101,
#   'Specificity': 0.8761904761904762,
#   'Weighted accuracy': 0.9352862493311931},
#  {'Accuracy': 0.950530035335689,
#   'F-score': 0.9619565217391305,
#   'MCC': 0.8953468698233825,
#   'Precision': 0.9315789473684211,
#   'Sensitivity': 0.9943820224719101,
#   'Specificity': 0.8761904761904762,
#   'Weighted accuracy': 0.9352862493311931},
#  {'Accuracy': 0.950530035335689,
#   'F-score': 0.9619565217391305,
#   'MCC': 0.8953468698233825,
#   'Precision': 0.9315789473684211,
#   'Sensitivity': 0.9943820224719101,
#   'Specificity': 0.8761904761904762,
#   'Weighted accuracy': 0.9352862493311931},
#  {'Accuracy': 0.950530035335689,
#   'F-score': 0.9619565217391305,
#   'MCC': 0.8953468698233825,
#   'Precision': 0.9315789473684211,
#   'Sensitivity': 0.9943820224719101,
#   'Specificity': 0.8761904761904762,
#   'Weighted accuracy': 0.9352862493311931},
#  {'Accuracy': 0.950530035335689,
#   'F-score': 0.9619565217391305,
#   'MCC': 0.8953468698233825,
#   'Precision': 0.9315789473684211,
#   'Sensitivity': 0.9943820224719101,
#   'Specificity': 0.8761904761904762,
#   'Weighted accuracy': 0.9352862493311931},
#  {'Accuracy': 0.950530035335689,
#   'F-score': 0.9619565217391305,
#   'MCC': 0.8953468698233825,
#   'Precision': 0.9315789473684211,
#   'Sensitivity': 0.9943820224719101,
#   'Specificity': 0.8761904761904762,
#   'Weighted accuracy': 0.9352862493311931},
#  {'Accuracy': 0.950530035335689,
#   'F-score': 0.9619565217391305,
#   'MCC': 0.8953468698233825,
#   'Precision': 0.9315789473684211,
#   'Sensitivity': 0.9943820224719101,
#   'Specificity': 0.8761904761904762,
#   'Weighted accuracy': 0.9352862493311931},
#  {'Accuracy': 0.950530035335689,
#   'F-score': 0.9619565217391305,
#   'MCC': 0.8953468698233825,
#   'Precision': 0.9315789473684211,
#   'Sensitivity': 0.9943820224719101,
#   'Specificity': 0.8761904761904762,
#   'Weighted accuracy': 0.9352862493311931},
#  {'Accuracy': 0.950530035335689,
#   'F-score': 0.9619565217391305,
#   'MCC': 0.8953468698233825,
#   'Precision': 0.9315789473684211,
#   'Sensitivity': 0.9943820224719101,
#   'Specificity': 0.8761904761904762,
#   'Weighted accuracy': 0.9352862493311931},
#  {'Accuracy': 0.950530035335689,
#   'F-score': 0.9619565217391305,
#   'MCC': 0.8953468698233825,
#   'Precision': 0.9315789473684211,
#   'Sensitivity': 0.9943820224719101,
#   'Specificity': 0.8761904761904762,
#   'Weighted accuracy': 0.9352862493311931},
#  {'Accuracy': 0.950530035335689,
#   'F-score': 0.9619565217391305,
#   'MCC': 0.8953468698233825,
#   'Precision': 0.9315789473684211,
#   'Sensitivity': 0.9943820224719101,
#   'Specificity': 0.8761904761904762,
#   'Weighted accuracy': 0.9352862493311931},
#  {'Accuracy': 0.950530035335689,
#   'F-score': 0.9619565217391305,
#   'MCC': 0.8953468698233825,
#   'Precision': 0.9315789473684211,
#   'Sensitivity': 0.9943820224719101,
#   'Specificity': 0.8761904761904762,
#   'Weighted accuracy': 0.9352862493311931},
#  {'Accuracy': 0.950530035335689,
#   'F-score': 0.9619565217391305,
#   'MCC': 0.8953468698233825,
#   'Precision': 0.9315789473684211,
#   'Sensitivity': 0.9943820224719101,
#   'Specificity': 0.8761904761904762,
#   'Weighted accuracy': 0.9352862493311931},
#  {'Accuracy': 0.950530035335689,
#   'F-score': 0.9619565217391305,
#   'MCC': 0.8953468698233825,
#   'Precision': 0.9315789473684211,
#   'Sensitivity': 0.9943820224719101,
#   'Specificity': 0.8761904761904762,
#   'Weighted accuracy': 0.9352862493311931},
#  {'Accuracy': 0.950530035335689,
#   'F-score': 0.9619565217391305,
#   'MCC': 0.8953468698233825,
#   'Precision': 0.9315789473684211,
#   'Sensitivity': 0.9943820224719101,
#   'Specificity': 0.8761904761904762,
#   'Weighted accuracy': 0.9352862493311931},
#  {'Accuracy': 0.950530035335689,
#   'F-score': 0.9619565217391305,
#   'MCC': 0.8953468698233825,
#   'Precision': 0.9315789473684211,
#   'Sensitivity': 0.9943820224719101,
#   'Specificity': 0.8761904761904762,
#   'Weighted accuracy': 0.9352862493311931},
#  {'Accuracy': 0.950530035335689,
#   'F-score': 0.9619565217391305,
#   'MCC': 0.8953468698233825,
#   'Precision': 0.9315789473684211,
#   'Sensitivity': 0.9943820224719101,
#   'Specificity': 0.8761904761904762,
#   'Weighted accuracy': 0.9352862493311931},
#  {'Accuracy': 0.9540636042402827,
#   'F-score': 0.964769647696477,
#   'MCC': 0.9022523272310968,
#   'Precision': 0.9368421052631579,
#   'Sensitivity': 0.994413407821229,
#   'Specificity': 0.8846153846153846,
#   'Weighted accuracy': 0.9395143962183068},
#  {'Accuracy': 0.950530035335689,
#   'F-score': 0.9619565217391305,
#   'MCC': 0.8953468698233825,
#   'Precision': 0.9315789473684211,
#   'Sensitivity': 0.9943820224719101,
#   'Specificity': 0.8761904761904762,
#   'Weighted accuracy': 0.9352862493311931},
#  {'Accuracy': 0.950530035335689,
#   'F-score': 0.9619565217391305,
#   'MCC': 0.8953468698233825,
#   'Precision': 0.9315789473684211,
#   'Sensitivity': 0.9943820224719101,
#   'Specificity': 0.8761904761904762,
#   'Weighted accuracy': 0.9352862493311931},
#  {'Accuracy': 0.950530035335689,
#   'F-score': 0.9619565217391305,
#   'MCC': 0.8953468698233825,
#   'Precision': 0.9315789473684211,
#   'Sensitivity': 0.9943820224719101,
#   'Specificity': 0.8761904761904762,
#   'Weighted accuracy': 0.9352862493311931},
#  {'Accuracy': 0.950530035335689,
#   'F-score': 0.9619565217391305,
#   'MCC': 0.8953468698233825,
#   'Precision': 0.9315789473684211,
#   'Sensitivity': 0.9943820224719101,
#   'Specificity': 0.8761904761904762,
#   'Weighted accuracy': 0.9352862493311931},
#  {'Accuracy': 0.950530035335689,
#   'F-score': 0.9619565217391305,
#   'MCC': 0.8953468698233825,
#   'Precision': 0.9315789473684211,
#   'Sensitivity': 0.9943820224719101,
#   'Specificity': 0.8761904761904762,
#   'Weighted accuracy': 0.9352862493311931},
#  {'Accuracy': 0.9652777777777778,
#   'F-score': 0.9723756906077348,
#   'MCC': 0.9273473985666031,
#   'Precision': 0.9513513513513514,
#   'Sensitivity': 0.9943502824858758,
#   'Specificity': 0.918918918918919,
#   'Weighted accuracy': 0.9566346007023974},
#  {'Accuracy': 0.9652777777777778,
#   'F-score': 0.9723756906077348,
#   'MCC': 0.9273473985666031,
#   'Precision': 0.9513513513513514,
#   'Sensitivity': 0.9943502824858758,
#   'Specificity': 0.918918918918919,
#   'Weighted accuracy': 0.9566346007023974},
#  {'Accuracy': 0.9652777777777778,
#   'F-score': 0.9723756906077348,
#   'MCC': 0.9273473985666031,
#   'Precision': 0.9513513513513514,
#   'Sensitivity': 0.9943502824858758,
#   'Specificity': 0.918918918918919,
#   'Weighted accuracy': 0.9566346007023974},
#  {'Accuracy': 0.9652777777777778,
#   'F-score': 0.9723756906077348,
#   'MCC': 0.9273473985666031,
#   'Precision': 0.9513513513513514,
#   'Sensitivity': 0.9943502824858758,
#   'Specificity': 0.918918918918919,
#   'Weighted accuracy': 0.9566346007023974},
#  {'Accuracy': 0.9618055555555556,
#   'F-score': 0.9703504043126685,
#   'MCC': 0.9200121404464917,
#   'Precision': 0.9424083769633508,
#   'Sensitivity': 1.0,
#   'Specificity': 0.8981481481481481,
#   'Weighted accuracy': 0.9490740740740741},
#  {'Accuracy': 0.9513888888888888,
#   'F-score': 0.9642857142857142,
#   'MCC': 0.8886768564924539,
#   'Precision': 0.9545454545454546,
#   'Sensitivity': 0.9742268041237113,
#   'Specificity': 0.9042553191489362,
#   'Weighted accuracy': 0.9392410616363238},
#  {'Accuracy': 0.9090909090909091,
#   'F-score': 0.9329896907216495,
#   'MCC': 0.7917986660742581,
#   'Precision': 0.9282051282051282,
#   'Sensitivity': 0.9378238341968912,
#   'Specificity': 0.8494623655913979,
#   'Weighted accuracy': 0.8936430998941445},
#  {'Accuracy': 0.9090909090909091,
#   'F-score': 0.9329896907216495,
#   'MCC': 0.7917986660742581,
#   'Precision': 0.9282051282051282,
#   'Sensitivity': 0.9378238341968912,
#   'Specificity': 0.8494623655913979,
#   'Weighted accuracy': 0.8936430998941445},
#  {'Accuracy': 0.9125874125874126,
#   'F-score': 0.9343832020997376,
#   'MCC': 0.8057257972907824,
#   'Precision': 0.9128205128205128,
#   'Sensitivity': 0.956989247311828,
#   'Specificity': 0.83,
#   'Weighted accuracy': 0.893494623655914},
#  {'Accuracy': 0.9300699300699301,
#   'F-score': 0.9487179487179487,
#   'MCC': 0.8393001190838966,
#   'Precision': 0.9585492227979274,
#   'Sensitivity': 0.9390862944162437,
#   'Specificity': 0.9101123595505618,
#   'Weighted accuracy': 0.9245993269834027},
#  {'Accuracy': 0.9300699300699301,
#   'F-score': 0.9487179487179487,
#   'MCC': 0.8393001190838966,
#   'Precision': 0.9585492227979274,
#   'Sensitivity': 0.9390862944162437,
#   'Specificity': 0.9101123595505618,
#   'Weighted accuracy': 0.9245993269834027},
#  {'Accuracy': 0.9513888888888888,
#   'F-score': 0.9642857142857142,
#   'MCC': 0.8886768564924539,
#   'Precision': 0.9545454545454546,
#   'Sensitivity': 0.9742268041237113,
#   'Specificity': 0.9042553191489362,
#   'Weighted accuracy': 0.9392410616363238},
#  {'Accuracy': 0.9896551724137931,
#   'F-score': 0.991869918699187,
#   'MCC': 0.9778986657226137,
#   'Precision': 1.0,
#   'Sensitivity': 0.9838709677419355,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.9919354838709677},
#  {'Accuracy': 0.9896551724137931,
#   'F-score': 0.991869918699187,
#   'MCC': 0.9778986657226137,
#   'Precision': 1.0,
#   'Sensitivity': 0.9838709677419355,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.9919354838709677},
#  {'Accuracy': 0.9896193771626297,
#   'F-score': 0.991869918699187,
#   'MCC': 0.9777655971624908,
#   'Precision': 1.0,
#   'Sensitivity': 0.9838709677419355,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.9919354838709677},
#  {'Accuracy': 0.9826989619377162,
#   'F-score': 0.9863760217983651,
#   'MCC': 0.9633620852865149,
#   'Precision': 1.0,
#   'Sensitivity': 0.9731182795698925,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.9865591397849462},
#  {'Accuracy': 0.8975265017667845,
#   'F-score': 0.9149560117302054,
#   'MCC': 0.7866717752812372,
#   'Precision': 0.9017341040462428,
#   'Sensitivity': 0.9285714285714286,
#   'Specificity': 0.8521739130434782,
#   'Weighted accuracy': 0.8903726708074534},
#  {'Accuracy': 0.9222614840989399,
#   'F-score': 0.935672514619883,
#   'MCC': 0.8410628297471346,
#   'Precision': 0.903954802259887,
#   'Sensitivity': 0.9696969696969697,
#   'Specificity': 0.8559322033898306,
#   'Weighted accuracy': 0.9128145865434001},
#  {'Accuracy': 0.6853146853146853,
#   'F-score': 0.7058823529411764,
#   'MCC': 0.5192907868894986,
#   'Precision': 1.0,
#   'Sensitivity': 0.5454545454545454,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7727272727272727},
#  {'Accuracy': 0.9965635738831615,
#   'F-score': 0.9973045822102425,
#   'MCC': 0.9925927734358407,
#   'Precision': 1.0,
#   'Sensitivity': 0.9946236559139785,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.9973118279569892},
#  {'Accuracy': 0.9093851132686084,
#   'F-score': 0.9161676646706587,
#   'MCC': 0.8328161024100634,
#   'Precision': 0.8453038674033149,
#   'Sensitivity': 1.0,
#   'Specificity': 0.8205128205128205,
#   'Weighted accuracy': 0.9102564102564102},
#  {'Accuracy': 0.9370629370629371,
#   'F-score': 0.949438202247191,
#   'MCC': 0.8686791786915266,
#   'Precision': 0.9234972677595629,
#   'Sensitivity': 0.976878612716763,
#   'Specificity': 0.8761061946902655,
#   'Weighted accuracy': 0.9264924037035143},
#  {'Accuracy': 0.7532051282051282,
#   'F-score': 0.7317073170731707,
#   'MCC': 0.601929265428846,
#   'Precision': 1.0,
#   'Sensitivity': 0.5769230769230769,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7884615384615384},
#  {'Accuracy': 0.7284768211920529,
#   'F-score': 0.6917293233082707,
#   'MCC': 0.5676944219910174,
#   'Precision': 1.0,
#   'Sensitivity': 0.5287356321839081,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.764367816091954},
#  {'Accuracy': 0.9858657243816255,
#   'F-score': 0.989010989010989,
#   'MCC': 0.9693255534864986,
#   'Precision': 0.994475138121547,
#   'Sensitivity': 0.9836065573770492,
#   'Specificity': 0.99,
#   'Weighted accuracy': 0.9868032786885246},
#  {'Accuracy': 0.9858657243816255,
#   'F-score': 0.989010989010989,
#   'MCC': 0.9693255534864986,
#   'Precision': 0.994475138121547,
#   'Sensitivity': 0.9836065573770492,
#   'Specificity': 0.99,
#   'Weighted accuracy': 0.9868032786885246},
#  {'Accuracy': 0.6993006993006993,
#   'F-score': 0.7171052631578948,
#   'MCC': 0.5360804954032455,
#   'Precision': 1.0,
#   'Sensitivity': 0.558974358974359,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7794871794871795},
#  {'Accuracy': 0.9303135888501742,
#   'F-score': 0.9438202247191011,
#   'MCC': 0.8622234551485248,
#   'Precision': 1.0,
#   'Sensitivity': 0.8936170212765957,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.9468085106382979},
#  {'Accuracy': 0.71280276816609,
#   'F-score': 0.7205387205387205,
#   'MCC': 0.5534737035701577,
#   'Precision': 1.0,
#   'Sensitivity': 0.5631578947368421,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.781578947368421},
#  {'Accuracy': 0.9773462783171522,
#   'F-score': 0.9665071770334929,
#   'MCC': 0.9500276021324449,
#   'Precision': 0.9901960784313726,
#   'Sensitivity': 0.9439252336448598,
#   'Specificity': 0.995049504950495,
#   'Weighted accuracy': 0.9694873692976774},
#  {'Accuracy': 0.7243589743589743,
#   'F-score': 0.6884057971014492,
#   'MCC': 0.5628961731429084,
#   'Precision': 1.0,
#   'Sensitivity': 0.5248618784530387,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7624309392265194},
#  {'Accuracy': 0.7132867132867133,
#   'F-score': 0.722972972972973,
#   'MCC': 0.5538859366439783,
#   'Precision': 1.0,
#   'Sensitivity': 0.5661375661375662,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.783068783068783},
#  {'Accuracy': 0.7132867132867133,
#   'F-score': 0.722972972972973,
#   'MCC': 0.5538859366439783,
#   'Precision': 1.0,
#   'Sensitivity': 0.5661375661375662,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.783068783068783},
#  {'Accuracy': 0.7132867132867133,
#   'F-score': 0.722972972972973,
#   'MCC': 0.5538859366439783,
#   'Precision': 1.0,
#   'Sensitivity': 0.5661375661375662,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.783068783068783},
#  {'Accuracy': 0.7132867132867133,
#   'F-score': 0.722972972972973,
#   'MCC': 0.5538859366439783,
#   'Precision': 1.0,
#   'Sensitivity': 0.5661375661375662,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.783068783068783},
#  {'Accuracy': 0.7403846153846154,
#   'F-score': 0.7075812274368231,
#   'MCC': 0.5833181048848486,
#   'Precision': 1.0,
#   'Sensitivity': 0.547486033519553,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7737430167597765},
#  {'Accuracy': 0.9340277777777778,
#   'F-score': 0.9467787114845938,
#   'MCC': 0.869142420088493,
#   'Precision': 1.0,
#   'Sensitivity': 0.898936170212766,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.949468085106383},
#  {'Accuracy': 0.7243589743589743,
#   'F-score': 0.6884057971014492,
#   'MCC': 0.5628961731429084,
#   'Precision': 1.0,
#   'Sensitivity': 0.5248618784530387,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7624309392265194},
#  {'Accuracy': 0.6955017301038062,
#   'F-score': 0.7124183006535948,
#   'MCC': 0.5317870986875418,
#   'Precision': 1.0,
#   'Sensitivity': 0.5532994923857868,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7766497461928934},
#  {'Accuracy': 0.958041958041958,
#   'F-score': 0.9664804469273743,
#   'MCC': 0.9142367029949549,
#   'Precision': 1.0,
#   'Sensitivity': 0.9351351351351351,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.9675675675675676},
#  {'Accuracy': 0.958041958041958,
#   'F-score': 0.9664804469273743,
#   'MCC': 0.9142367029949549,
#   'Precision': 1.0,
#   'Sensitivity': 0.9351351351351351,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.9675675675675676},
#  {'Accuracy': 0.958041958041958,
#   'F-score': 0.9664804469273743,
#   'MCC': 0.9142367029949549,
#   'Precision': 1.0,
#   'Sensitivity': 0.9351351351351351,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.9675675675675676},
#  {'Accuracy': 0.7329192546583851,
#   'F-score': 0.6884057971014492,
#   'MCC': 0.5709776948584736,
#   'Precision': 1.0,
#   'Sensitivity': 0.5248618784530387,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7624309392265194},
#  {'Accuracy': 0.7403846153846154,
#   'F-score': 0.7096774193548387,
#   'MCC': 0.5838193816777029,
#   'Precision': 1.0,
#   'Sensitivity': 0.55,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.775},
#  {'Accuracy': 0.8,
#   'F-score': 0.7622377622377621,
#   'MCC': 0.6549901181680284,
#   'Precision': 0.990909090909091,
#   'Sensitivity': 0.6193181818181818,
#   'Specificity': 0.9939024390243902,
#   'Weighted accuracy': 0.8066103104212861},
#  {'Accuracy': 0.8421052631578947,
#   'F-score': 0.856,
#   'MCC': 0.7250044092279636,
#   'Precision': 1.0,
#   'Sensitivity': 0.7482517482517482,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.8741258741258742},
#  {'Accuracy': 0.794425087108014,
#   'F-score': 0.8161993769470405,
#   'MCC': 0.6547604150218781,
#   'Precision': 1.0,
#   'Sensitivity': 0.6894736842105263,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.8447368421052632},
#  {'Accuracy': 0.9823321554770318,
#   'F-score': 0.9862258953168045,
#   'MCC': 0.9616242405747798,
#   'Precision': 0.988950276243094,
#   'Sensitivity': 0.9835164835164835,
#   'Specificity': 0.9801980198019802,
#   'Weighted accuracy': 0.9818572516592319},
#  {'Accuracy': 0.7282229965156795,
#   'F-score': 0.7417218543046357,
#   'MCC': 0.5716089940731016,
#   'Precision': 1.0,
#   'Sensitivity': 0.5894736842105263,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7947368421052632},
#  {'Accuracy': 0.7177700348432056,
#   'F-score': 0.7290969899665551,
#   'MCC': 0.5591293815270421,
#   'Precision': 1.0,
#   'Sensitivity': 0.5736842105263158,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7868421052631579},
#  {'Accuracy': 0.7177700348432056,
#   'F-score': 0.7290969899665551,
#   'MCC': 0.5591293815270421,
#   'Precision': 1.0,
#   'Sensitivity': 0.5736842105263158,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7868421052631579},
#  {'Accuracy': 0.7177700348432056,
#   'F-score': 0.7290969899665551,
#   'MCC': 0.5591293815270421,
#   'Precision': 1.0,
#   'Sensitivity': 0.5736842105263158,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7868421052631579},
#  {'Accuracy': 0.7177700348432056,
#   'F-score': 0.7290969899665551,
#   'MCC': 0.5591293815270421,
#   'Precision': 1.0,
#   'Sensitivity': 0.5736842105263158,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7868421052631579},
#  {'Accuracy': 0.7177700348432056,
#   'F-score': 0.7290969899665551,
#   'MCC': 0.5591293815270421,
#   'Precision': 1.0,
#   'Sensitivity': 0.5736842105263158,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7868421052631579},
#  {'Accuracy': 0.7177700348432056,
#   'F-score': 0.7290969899665551,
#   'MCC': 0.5591293815270421,
#   'Precision': 1.0,
#   'Sensitivity': 0.5736842105263158,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7868421052631579},
#  {'Accuracy': 0.7142857142857143,
#   'F-score': 0.7248322147651006,
#   'MCC': 0.5550018476252057,
#   'Precision': 1.0,
#   'Sensitivity': 0.5684210526315789,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7842105263157895},
#  {'Accuracy': 0.7212543554006968,
#   'F-score': 0.7315436241610739,
#   'MCC': 0.5634889235450589,
#   'Precision': 1.0,
#   'Sensitivity': 0.5767195767195767,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7883597883597884},
#  {'Accuracy': 0.959866220735786,
#   'F-score': 0.9673913043478262,
#   'MCC': 0.9167447720217646,
#   'Precision': 0.9468085106382979,
#   'Sensitivity': 0.9888888888888889,
#   'Specificity': 0.9159663865546218,
#   'Weighted accuracy': 0.9524276377217553},
#  {'Accuracy': 0.9482758620689655,
#   'F-score': 0.9526813880126184,
#   'MCC': 0.897505974264659,
#   'Precision': 0.9263803680981595,
#   'Sensitivity': 0.9805194805194806,
#   'Specificity': 0.9117647058823529,
#   'Weighted accuracy': 0.9461420932009168},
#  {'Accuracy': 0.9724137931034482,
#   'F-score': 0.9781420765027322,
#   'MCC': 0.9408651060124221,
#   'Precision': 0.9728260869565217,
#   'Sensitivity': 0.9835164835164835,
#   'Specificity': 0.9537037037037037,
#   'Weighted accuracy': 0.9686100936100936},
#  {'Accuracy': 0.6946308724832215,
#   'F-score': 0.6738351254480286,
#   'MCC': 0.45210763030815376,
#   'Precision': 0.8703703703703703,
#   'Sensitivity': 0.5497076023391813,
#   'Specificity': 0.889763779527559,
#   'Weighted accuracy': 0.7197356909333701},
#  {'Accuracy': 0.9545454545454546,
#   'F-score': 0.9651474530831099,
#   'MCC': 0.9045782468493195,
#   'Precision': 1.0,
#   'Sensitivity': 0.9326424870466321,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.966321243523316},
#  {'Accuracy': 0.9477351916376306,
#   'F-score': 0.9600000000000001,
#   'MCC': 0.8908836153524896,
#   'Precision': 1.0,
#   'Sensitivity': 0.9230769230769231,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.9615384615384616},
#  {'Accuracy': 0.7552447552447552,
#   'F-score': 0.7569444444444444,
#   'MCC': 0.6067251380262944,
#   'Precision': 1.0,
#   'Sensitivity': 0.6089385474860335,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.8044692737430168},
#  {'Accuracy': 0.9826388888888888,
#   'F-score': 0.986449864498645,
#   'MCC': 0.9629919239881668,
#   'Precision': 1.0,
#   'Sensitivity': 0.9732620320855615,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.9866310160427807},
#  {'Accuracy': 0.9862068965517241,
#   'F-score': 0.9889502762430938,
#   'MCC': 0.9707080058142151,
#   'Precision': 0.9944444444444445,
#   'Sensitivity': 0.9835164835164835,
#   'Specificity': 0.9907407407407407,
#   'Weighted accuracy': 0.987128612128612},
#  {'Accuracy': 0.9825174825174825,
#   'F-score': 0.9863013698630138,
#   'MCC': 0.9628489089247825,
#   'Precision': 1.0,
#   'Sensitivity': 0.972972972972973,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.9864864864864865},
#  {'Accuracy': 0.9477351916376306,
#   'F-score': 0.9600000000000001,
#   'MCC': 0.8908836153524896,
#   'Precision': 1.0,
#   'Sensitivity': 0.9230769230769231,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.9615384615384616},
#  {'Accuracy': 0.9477351916376306,
#   'F-score': 0.9600000000000001,
#   'MCC': 0.8908836153524896,
#   'Precision': 1.0,
#   'Sensitivity': 0.9230769230769231,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.9615384615384616},
#  {'Accuracy': 0.9862068965517241,
#   'F-score': 0.9891304347826088,
#   'MCC': 0.9706977294910235,
#   'Precision': 1.0,
#   'Sensitivity': 0.978494623655914,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.989247311827957},
#  {'Accuracy': 0.9861111111111112,
#   'F-score': 0.9891304347826088,
#   'MCC': 0.9703454530397595,
#   'Precision': 1.0,
#   'Sensitivity': 0.978494623655914,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.989247311827957},
#  {'Accuracy': 0.7241379310344828,
#   'F-score': 0.7297297297297298,
#   'MCC': 0.5674104696809684,
#   'Precision': 1.0,
#   'Sensitivity': 0.574468085106383,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7872340425531915},
#  {'Accuracy': 0.9895833333333334,
#   'F-score': 0.9917808219178081,
#   'MCC': 0.9775904448764046,
#   'Precision': 0.9945054945054945,
#   'Sensitivity': 0.9890710382513661,
#   'Specificity': 0.9904761904761905,
#   'Weighted accuracy': 0.9897736143637783},
#  {'Accuracy': 0.9305993690851735,
#   'F-score': 0.937142857142857,
#   'MCC': 0.8688711643783236,
#   'Precision': 0.8817204301075269,
#   'Sensitivity': 1.0,
#   'Specificity': 0.8562091503267973,
#   'Weighted accuracy': 0.9281045751633987},
#  {'Accuracy': 0.7379310344827587,
#   'F-score': 0.7397260273972603,
#   'MCC': 0.5846826475751932,
#   'Precision': 1.0,
#   'Sensitivity': 0.5869565217391305,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7934782608695652},
#  {'Accuracy': 0.9477351916376306,
#   'F-score': 0.9600000000000001,
#   'MCC': 0.8908836153524896,
#   'Precision': 1.0,
#   'Sensitivity': 0.9230769230769231,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.9615384615384616},
#  {'Accuracy': 0.7379310344827587,
#   'F-score': 0.7397260273972603,
#   'MCC': 0.5846826475751932,
#   'Precision': 1.0,
#   'Sensitivity': 0.5869565217391305,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7934782608695652},
#  {'Accuracy': 0.9513888888888888,
#   'F-score': 0.9627659574468085,
#   'MCC': 0.8981969317766874,
#   'Precision': 1.0,
#   'Sensitivity': 0.9282051282051282,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.9641025641025641},
#  {'Accuracy': 0.6979166666666666,
#   'F-score': 0.7147540983606557,
#   'MCC': 0.5346291217279197,
#   'Precision': 1.0,
#   'Sensitivity': 0.5561224489795918,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.778061224489796},
#  {'Accuracy': 0.9862068965517241,
#   'F-score': 0.9889502762430938,
#   'MCC': 0.9707080058142151,
#   'Precision': 0.9944444444444445,
#   'Sensitivity': 0.9835164835164835,
#   'Specificity': 0.9907407407407407,
#   'Weighted accuracy': 0.987128612128612},
#  {'Accuracy': 0.7310344827586207,
#   'F-score': 0.7346938775510204,
#   'MCC': 0.5760184328847832,
#   'Precision': 1.0,
#   'Sensitivity': 0.5806451612903226,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7903225806451613},
#  {'Accuracy': 0.7275862068965517,
#   'F-score': 0.7322033898305084,
#   'MCC': 0.5717076359182796,
#   'Precision': 1.0,
#   'Sensitivity': 0.5775401069518716,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7887700534759359},
#  {'Accuracy': 0.7013888888888888,
#   'F-score': 0.7171052631578948,
#   'MCC': 0.5389033732721555,
#   'Precision': 1.0,
#   'Sensitivity': 0.558974358974359,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.7794871794871795},
#  {'Accuracy': 0.9615384615384616,
#   'F-score': 0.9602649006622517,
#   'MCC': 0.9258524676580455,
#   'Precision': 1.0,
#   'Sensitivity': 0.9235668789808917,
#   'Specificity': 1.0,
#   'Weighted accuracy': 0.9617834394904459}]
